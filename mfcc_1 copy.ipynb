# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
import json
import wave
import time
import pyaudio
import librosa
import pathlib
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import Audio
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, GlobalMaxPooling2D
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, f1_score, recall_score
from sklearn.model_selection import train_test_split

# %%
SEED = 42
BATCH_SIZE = 64
SAMPLE_RATE = 16000
VALIDATION_SPLIT = 0.2

# %%
def load_data(json_path):
    with open(json_path, "r") as fp:
        data = json.load(fp)
    return data

train_data = load_data('train_mfccs.json')
test_data = load_data('test_mfccs.json')

# %%
# Convert lists to numpy arrays
X_train = np.array(train_data["mfcc"])
y_train = np.array(train_data["labels"])
X_test = np.array(test_data["mfcc"])
y_test = np.array(test_data["labels"])

# Split training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
def model(input_shape):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(16, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu', padding='same'),
        layers.GlobalMaxPooling2D(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(len(np.unique(y_train)), activation='softmax')
    ])

    return model

# %%
# Input shape
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# %%
input_shape
# Out:
# (13, 13, 1)

# %%
model = model(input_shape)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 13, 13, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 6, 6, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 3, 3, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 3, 3, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 1, 1, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d_1          │ (None, 128)            │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 114,438 (447.02 KB)
#  Trainable params: 114,438 (447.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile model
learning_rate = 0.001
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Train model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3623 - loss: 1.6321 - val_accuracy: 0.5111 - val_loss: 1.2444
# Epoch 2/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5286 - loss: 1.2281 - val_accuracy: 0.5815 - val_loss: 1.1236
# Epoch 3/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5834 - loss: 1.1027 - val_accuracy: 0.6253 - val_loss: 1.0169
# Epoch 4/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6193 - loss: 1.0136 - val_accuracy: 0.6276 - val_loss: 0.9884
# Epoch 5/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6395 - loss: 0.9432 - val_accuracy: 0.6436 - val_loss: 0.9744
# Epoch 6/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6616 - loss: 0.8953 - val_accuracy: 0.6584 - val_loss: 0.9149
# Epoch 7/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6683 - loss: 0.8614 - val_accuracy: 0.6573 - val_loss: 0.9169
# Epoch 8/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6878 - loss: 0.8214 - val_accuracy: 0.6739 - val_loss: 0.8775
# Epoch 9/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6986 - loss: 0.7852 - val_accuracy: 0.6741 - val_loss: 0.8874
# Epoch 10/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7058 - loss: 0.7635 - val_accuracy: 0.6764 - val_loss: 0.8915
# Epoch 11/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7213 - loss: 0.7356 - val_accuracy: 0.6825 - val_loss: 0.8814
# Epoch 12/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7299 - loss: 0.7075 - val_accuracy: 0.6750 - val_loss: 0.8969
# Epoch 13/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7405 - loss: 0.6803 - val_accuracy: 0.6835 - val_loss: 0.8648
# Epoch 14/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7493 - loss: 0.6495 - val_accuracy: 0.6795 - val_loss: 0.9227
# Epoch 15/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7548 - loss: 0.6433 - val_accuracy: 0.6901 - val_loss: 0.8689
# Epoch 16/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 0.7618 - loss: 0.6173 - val_accuracy: 0.6841 - val_loss: 0.9284
# Epoch 17/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7698 - loss: 0.6055 - val_accuracy: 0.6835 - val_loss: 0.9367
# Epoch 18/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.7698 - loss: 0.6027 - val_accuracy: 0.6887 - val_loss: 0.9339
# Epoch 19/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.7818 - loss: 0.5745 - val_accuracy: 0.6951 - val_loss: 0.9419
# Epoch 20/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7805 - loss: 0.5723 - val_accuracy: 0.6887 - val_loss: 0.9633
# Epoch 21/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7847 - loss: 0.5618 - val_accuracy: 0.6962 - val_loss: 0.9879
# Epoch 22/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.7914 - loss: 0.5431 - val_accuracy: 0.6933 - val_loss: 0.9743
# Epoch 23/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.7994 - loss: 0.5180 - val_accuracy: 0.6937 - val_loss: 0.9531
# Epoch 24/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8013 - loss: 0.5151 - val_accuracy: 0.6887 - val_loss: 0.9710
# Epoch 25/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8048 - loss: 0.5099 - val_accuracy: 0.6922 - val_loss: 1.0085
# Epoch 26/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8046 - loss: 0.5033 - val_accuracy: 0.6918 - val_loss: 1.0390
# Epoch 27/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8163 - loss: 0.4772 - val_accuracy: 0.6883 - val_loss: 1.0524
# Epoch 28/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.8135 - loss: 0.4789 - val_accuracy: 0.6891 - val_loss: 1.0378
# Epoch 29/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.8196 - loss: 0.4648 - val_accuracy: 0.6987 - val_loss: 1.0492
# Epoch 30/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.8208 - loss: 0.4654 - val_accuracy: 0.6885 - val_loss: 1.0394
# Epoch 31/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.8182 - loss: 0.4664 - val_accuracy: 0.6933 - val_loss: 1.0795
# Epoch 32/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8245 - loss: 0.4418 - val_accuracy: 0.6810 - val_loss: 1.1496
# Epoch 33/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8292 - loss: 0.4375 - val_accuracy: 0.6843 - val_loss: 1.1211
# Epoch 34/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8387 - loss: 0.4153 - val_accuracy: 0.6810 - val_loss: 1.1962
# Epoch 35/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - accuracy: 0.8338 - loss: 0.4328 - val_accuracy: 0.6831 - val_loss: 1.2135
# Epoch 36/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8446 - loss: 0.4028 - val_accuracy: 0.6939 - val_loss: 1.2114
# Epoch 37/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8380 - loss: 0.4172 - val_accuracy: 0.6856 - val_loss: 1.1511
# Epoch 38/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.8474 - loss: 0.3920 - val_accuracy: 0.6920 - val_loss: 1.2504
# Epoch 39/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.8411 - loss: 0.4183 - val_accuracy: 0.6860 - val_loss: 1.2397
# Epoch 40/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.8473 - loss: 0.3971 - val_accuracy: 0.6841 - val_loss: 1.2525
# Epoch 41/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.8547 - loss: 0.3848 - val_accuracy: 0.6800 - val_loss: 1.2657
# Epoch 42/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8571 - loss: 0.3721 - val_accuracy: 0.6854 - val_loss: 1.3844
# Epoch 43/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8566 - loss: 0.3726 - val_accuracy: 0.6793 - val_loss: 1.3337
# Epoch 44/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8523 - loss: 0.3773 - val_accuracy: 0.6806 - val_loss: 1.3327
# Epoch 45/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8561 - loss: 0.3792 - val_accuracy: 0.6766 - val_loss: 1.3794
# Epoch 46/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8625 - loss: 0.3547 - val_accuracy: 0.6825 - val_loss: 1.4330
# Epoch 47/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.8713 - loss: 0.3497 - val_accuracy: 0.6852 - val_loss: 1.4666
# Epoch 48/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.8685 - loss: 0.3380 - val_accuracy: 0.6787 - val_loss: 1.4156
# Epoch 49/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.8739 - loss: 0.3392 - val_accuracy: 0.6816 - val_loss: 1.4606
# Epoch 50/50
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.8722 - loss: 0.3285 - val_accuracy: 0.6862 - val_loss: 1.5068

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.2f}')
# Out:
#   8/164 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4866 - loss: 3.6588
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6218 - loss: 2.3178
# Test Accuracy: 0.60

# %%
# Assuming you have the test data prepared as X_test and y_test
# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Calculate accuracy, precision, and F1 score
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes, average='weighted')
f1 = f1_score(y_test, y_pred_classes, average='weighted')

# Print classification report
class_report = classification_report(y_test, y_pred_classes)
print("Classification Report:\n", class_report)
# Out:
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.53      0.55       983
#            1       0.69      0.95      0.80       608
#            2       0.64      0.66      0.65       961
#            3       0.66      0.55      0.60       942
#            4       0.52      0.48      0.50       857
#            5       0.53      0.53      0.53       885
#
#     accuracy                           0.60      5236
#    macro avg       0.60      0.62      0.60      5236
# weighted avg       0.60      0.60      0.59      5236

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score, classification_report


# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)



# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='g', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Function to plot the training history
def plot_training_history(history):
    try:
        acc = history.history['accuracy']
        val_acc = history.history['val_accuracy']
        loss = history.history['loss']
        val_loss = history.history['val_loss']

        epochs = range(len(acc))

        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1)
        plt.plot(epochs, acc, 'r', label='Training accuracy')
        plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs, loss, 'r', label='Training loss')
        plt.plot(epochs, val_loss, 'b', label='Validation loss')
        plt.title('Training and validation loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"An error occurred during plotting the training history: {str(e)}")
        
plot_training_history(history)

# %%
model.save("audio_classification_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def predict(file_path, model):
    # Load the audio file
    signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

    # Extract MFCCs
    mfcc = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=2048, hop_length=512)
    mfcc = mfcc.T

    # Ensure the correct shape
    mfcc = np.expand_dims(mfcc, axis=-1)
    mfcc = np.expand_dims(mfcc, axis=0)

    # Make prediction
    prediction = model.predict(mfcc)
    predicted_index = np.argmax(prediction, axis=1)
    return predicted_index

# Load the model
model = tf.keras.models.load_model('audio_classification_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
train_data_dir = pathlib.Path('Dataset/Train')

emabega_file_path = os.path.join(train_data_dir, 'emabega', 'emabega_001.wav')
ddyo_file_path = os.path.join(train_data_dir, 'ddyo', 'ddyo_001.wav')

# %%
#  Predict
file_path = ddyo_file_path
predicted_class = predict(file_path, model)
print(f'Predicted Class: {predicted_class}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# Predicted Class: [4]

# %%
KERAS_MODEL_PATH = "model/mfcc_model_1.keras"
model.save(KERAS_MODEL_PATH)

# %%
# Function to get the file size
def get_and_convert_file_size(file_path, unit=None):
    size = os.path.getsize(file_path)
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
keras_model_size = get_and_convert_file_size(KERAS_MODEL_PATH, 'KB')
# Out:
# File size: 483.708 Kilobytes

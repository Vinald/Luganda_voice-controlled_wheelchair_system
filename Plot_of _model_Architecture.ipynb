# %% [markdown]
# ## Packages

# %%
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## Model 1 Architecture

# %%
from packages.model import model

# %%
input_shape = (124, 128, 1)  # Example input shape
num_labels = 6 

model_instance = model(input_shape, num_labels)

# %%
plot_model(model_instance, to_file='files/Arch_model_1.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Model 2 Architecture

# %%
from packages.model import model2

# %%
input_shape = (124, 128, 1)
num_labels = 6 

model_instance = model2(input_shape, num_labels)

# %%
plot_model(model_instance, to_file='files/Arch_model_2.png', show_shapes=True, show_layer_names=True)

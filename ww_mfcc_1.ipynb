# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
import json
import wave
import time
import pyaudio
import librosa
import pathlib
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import Audio
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, GlobalMaxPooling2D
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, f1_score, recall_score
from sklearn.model_selection import train_test_split

# %%
SEED = 42
BATCH_SIZE = 32
SAMPLE_RATE = 16000
VALIDATION_SPLIT = 0.2

# %%
def load_data(json_path):
    with open(json_path, "r") as fp:
        data = json.load(fp)
    return data

train_data = load_data('train_mfccs.json')
test_data = load_data('test_mfccs.json')

# %%
# Convert lists to numpy arrays
X_train = np.array(train_data["mfcc"])
y_train = np.array(train_data["labels"])
X_test = np.array(test_data["mfcc"])
y_test = np.array(test_data["labels"])

# Split training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Model definition
def build_model(input_shape):
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(Conv2D(32, (2, 2), activation='relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2), padding='same'))

    model.add(GlobalMaxPooling2D())  # Add GlobalMaxPooling2D layer

    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(len(np.unique(y_train)), activation='softmax'))

    return model

# Input shape
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# Build model
model = build_model(input_shape)

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=50)
# Out:
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.3852 - loss: 1.5646 - val_accuracy: 0.5043 - val_loss: 1.2305
# Epoch 2/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4855 - loss: 1.2460 - val_accuracy: 0.5332 - val_loss: 1.1597
# Epoch 3/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5179 - loss: 1.1891 - val_accuracy: 0.5693 - val_loss: 1.1187
# Epoch 4/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5474 - loss: 1.1380 - val_accuracy: 0.5664 - val_loss: 1.1134
# Epoch 5/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5658 - loss: 1.1078 - val_accuracy: 0.6143 - val_loss: 1.0027
# Epoch 6/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5958 - loss: 1.0462 - val_accuracy: 0.6154 - val_loss: 1.0477
# Epoch 7/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6118 - loss: 1.0220 - val_accuracy: 0.6209 - val_loss: 0.9916
# Epoch 8/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6135 - loss: 1.0211 - val_accuracy: 0.6125 - val_loss: 1.0260
# Epoch 9/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6233 - loss: 0.9907 - val_accuracy: 0.6353 - val_loss: 0.9594
# Epoch 10/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6359 - loss: 0.9694 - val_accuracy: 0.6125 - val_loss: 1.0780
# Epoch 11/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6307 - loss: 0.9820 - val_accuracy: 0.6490 - val_loss: 0.9280
# Epoch 12/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6507 - loss: 0.9223 - val_accuracy: 0.6620 - val_loss: 0.8915
# Epoch 13/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6540 - loss: 0.9171 - val_accuracy: 0.6592 - val_loss: 0.9133
# Epoch 14/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6482 - loss: 0.9272 - val_accuracy: 0.6634 - val_loss: 0.9081
# Epoch 15/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6622 - loss: 0.9014 - val_accuracy: 0.6609 - val_loss: 0.8857
# Epoch 16/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.6601 - loss: 0.8929 - val_accuracy: 0.6702 - val_loss: 0.8995
# Epoch 17/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6689 - loss: 0.8890 - val_accuracy: 0.6521 - val_loss: 0.9120
# Epoch 18/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6737 - loss: 0.8710 - val_accuracy: 0.6706 - val_loss: 0.8870
# Epoch 19/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6664 - loss: 0.8735 - val_accuracy: 0.6651 - val_loss: 0.8933
# Epoch 20/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6683 - loss: 0.8821 - val_accuracy: 0.6627 - val_loss: 0.8937
# Epoch 21/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6713 - loss: 0.8729 - val_accuracy: 0.6740 - val_loss: 0.8575
# Epoch 22/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6761 - loss: 0.8584 - val_accuracy: 0.6587 - val_loss: 0.8999
# Epoch 23/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6754 - loss: 0.8584 - val_accuracy: 0.6667 - val_loss: 0.8915
# Epoch 24/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6753 - loss: 0.8525 - val_accuracy: 0.6768 - val_loss: 0.8698
# Epoch 25/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6832 - loss: 0.8320 - val_accuracy: 0.6746 - val_loss: 0.8594
# Epoch 26/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6830 - loss: 0.8360 - val_accuracy: 0.6788 - val_loss: 0.8726
# Epoch 27/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6855 - loss: 0.8271 - val_accuracy: 0.6790 - val_loss: 0.8564
# Epoch 28/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6897 - loss: 0.8099 - val_accuracy: 0.6834 - val_loss: 0.8765
# Epoch 29/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6914 - loss: 0.8177 - val_accuracy: 0.6720 - val_loss: 0.8678
# Epoch 30/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6979 - loss: 0.8036 - val_accuracy: 0.6737 - val_loss: 0.8909
# Epoch 31/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6922 - loss: 0.8140 - val_accuracy: 0.6813 - val_loss: 0.8548
# Epoch 32/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.6989 - loss: 0.8076 - val_accuracy: 0.6748 - val_loss: 0.8984
# Epoch 33/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6985 - loss: 0.8063 - val_accuracy: 0.6868 - val_loss: 0.8477
# Epoch 34/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6842 - loss: 0.8231 - val_accuracy: 0.6749 - val_loss: 0.9086
# Epoch 35/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6999 - loss: 0.7956 - val_accuracy: 0.6729 - val_loss: 0.9110
# Epoch 36/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6991 - loss: 0.7795 - val_accuracy: 0.6819 - val_loss: 0.8676
# Epoch 37/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6967 - loss: 0.7847 - val_accuracy: 0.6775 - val_loss: 0.8745
# Epoch 38/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.7009 - loss: 0.7824 - val_accuracy: 0.6845 - val_loss: 0.8529
# Epoch 39/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6904 - loss: 0.8059 - val_accuracy: 0.6888 - val_loss: 0.8651
# Epoch 40/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.7014 - loss: 0.7827 - val_accuracy: 0.6830 - val_loss: 0.8676
# Epoch 41/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7011 - loss: 0.7857 - val_accuracy: 0.6676 - val_loss: 0.9192
# Epoch 42/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 431s 631ms/step - accuracy: 0.6957 - loss: 0.7989 - val_accuracy: 0.6812 - val_loss: 0.8687
# Epoch 43/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.6980 - loss: 0.7907 - val_accuracy: 0.6700 - val_loss: 0.9174
# Epoch 44/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6974 - loss: 0.7902 - val_accuracy: 0.6826 - val_loss: 0.8549
# Epoch 45/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7031 - loss: 0.7684 - val_accuracy: 0.6832 - val_loss: 0.8671
# Epoch 46/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7092 - loss: 0.7619 - val_accuracy: 0.6744 - val_loss: 0.9092
# Epoch 47/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7138 - loss: 0.7633 - val_accuracy: 0.6585 - val_loss: 0.9501
# Epoch 48/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6994 - loss: 0.7808 - val_accuracy: 0.6720 - val_loss: 0.8966
# Epoch 49/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.7085 - loss: 0.7665 - val_accuracy: 0.6739 - val_loss: 0.8939
# Epoch 50/50
# 685/685 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7018 - loss: 0.7840 - val_accuracy: 0.6845 - val_loss: 0.8654

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.2f}')
# Out:
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5567 - loss: 1.2933
# Test Accuracy: 0.54

# %%
# Assuming you have the test data prepared as X_test and y_test
# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Calculate accuracy, precision, and F1 score
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes, average='weighted')
f1 = f1_score(y_test, y_pred_classes, average='weighted')

# Print classification report
class_report = classification_report(y_test, y_pred_classes)
print("Classification Report:\n", class_report)
# Out:
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.48      0.49       983
#            1       0.51      0.93      0.66       608
#            2       0.73      0.52      0.61       961
#            3       0.66      0.48      0.55       942
#            4       0.45      0.50      0.47       857
#            5       0.47      0.45      0.46       885
#
#     accuracy                           0.54      5236
#    macro avg       0.55      0.56      0.54      5236
# weighted avg       0.56      0.54      0.53      5236

# %%
# Function to plot the training history
def plot_training_history(history):
    try:
        acc = history.history['accuracy']
        val_acc = history.history['val_accuracy']
        loss = history.history['loss']
        val_loss = history.history['val_loss']

        epochs = range(len(acc))

        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1)
        plt.plot(epochs, acc, 'r', label='Training accuracy')
        plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs, loss, 'r', label='Training loss')
        plt.plot(epochs, val_loss, 'b', label='Validation loss')
        plt.title('Training and validation loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"An error occurred during plotting the training history: {str(e)}")
        
plot_training_history(history)

# %%
model.save("audio_classification_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def predict(file_path, model):
    # Load the audio file
    signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

    # Extract MFCCs
    mfcc = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=2048, hop_length=512)
    mfcc = mfcc.T

    # Ensure the correct shape
    mfcc = np.expand_dims(mfcc, axis=-1)
    mfcc = np.expand_dims(mfcc, axis=0)

    # Make prediction
    prediction = model.predict(mfcc)
    predicted_index = np.argmax(prediction, axis=1)
    return predicted_index

# Load the model
model = tf.keras.models.load_model('audio_classification_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
train_data_dir = pathlib.Path('Dataset/Train')

emabega_file_path = os.path.join(train_data_dir, 'emabega', 'emabega_001.wav')
ddyo_file_path = os.path.join(train_data_dir, 'ddyo', 'ddyo_001.wav')

# %%
#  Predict
file_path = ddyo_file_path
predicted_class = predict(file_path, model)
print(f'Predicted Class: {predicted_class}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# Predicted Class: [4]

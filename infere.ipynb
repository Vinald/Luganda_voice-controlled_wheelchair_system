# %%
import json

def load_data(json_path):
    with open(json_path, "r") as fp:
        data = json.load(fp)
    return data

train_data = load_data('train_mfccs.json')
test_data = load_data('test_mfccs.json')

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Convert lists to numpy arrays
X_train = np.array(train_data["mfcc"])
y_train = np.array(train_data["labels"])
X_test = np.array(test_data["mfcc"])
y_test = np.array(test_data["labels"])

# Split training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# Model definition
def build_model(input_shape):
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(Conv2D(32, (2, 2), activation='relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2), padding='same'))

    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(len(np.unique(y_train)), activation='softmax'))

    return model

# Input shape
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# Build model
model = build_model(input_shape)

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=64, epochs=500)
# Out:
# 2024-05-20 20:56:58.127035: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-20 20:56:58.132816: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-20 20:56:58.204076: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-20 20:56:59.183017: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Epoch 1/500
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3720 - loss: 1.8326 - val_accuracy: 0.4747 - val_loss: 1.2748
# Epoch 2/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4740 - loss: 1.2838 - val_accuracy: 0.4707 - val_loss: 1.5030
# Epoch 3/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4940 - loss: 1.3104 - val_accuracy: 0.5109 - val_loss: 1.1904
# Epoch 4/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5357 - loss: 1.1782 - val_accuracy: 0.5330 - val_loss: 1.1580
# Epoch 5/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5580 - loss: 1.1191 - val_accuracy: 0.5854 - val_loss: 1.0630
# Epoch 6/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5764 - loss: 1.0962 - val_accuracy: 0.5947 - val_loss: 1.0457
# Epoch 7/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5897 - loss: 1.0673 - val_accuracy: 0.5869 - val_loss: 1.0551
# Epoch 8/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6039 - loss: 1.0458 - val_accuracy: 0.6006 - val_loss: 1.0356
# Epoch 9/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6018 - loss: 1.0316 - val_accuracy: 0.6289 - val_loss: 0.9775
# Epoch 10/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6244 - loss: 0.9928 - val_accuracy: 0.6417 - val_loss: 0.9428
# Epoch 11/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6188 - loss: 1.0024 - val_accuracy: 0.6474 - val_loss: 0.9367
# Epoch 12/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6452 - loss: 0.9484 - val_accuracy: 0.6528 - val_loss: 0.9277
# Epoch 13/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6467 - loss: 0.9491 - val_accuracy: 0.6601 - val_loss: 0.9019
# Epoch 14/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6507 - loss: 0.9215 - val_accuracy: 0.6570 - val_loss: 0.9068
# Epoch 15/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6509 - loss: 0.9131 - val_accuracy: 0.6596 - val_loss: 0.9104
# Epoch 16/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6598 - loss: 0.8920 - val_accuracy: 0.6684 - val_loss: 0.8836
# Epoch 17/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6674 - loss: 0.8833 - val_accuracy: 0.6715 - val_loss: 0.8772
# Epoch 18/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6716 - loss: 0.8834 - val_accuracy: 0.6541 - val_loss: 0.8825
# Epoch 19/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6647 - loss: 0.8881 - val_accuracy: 0.6598 - val_loss: 0.8980
# Epoch 20/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6556 - loss: 0.8982 - val_accuracy: 0.6797 - val_loss: 0.8575
# Epoch 21/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6765 - loss: 0.8602 - val_accuracy: 0.6792 - val_loss: 0.8452
# Epoch 22/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6889 - loss: 0.8314 - val_accuracy: 0.6614 - val_loss: 0.9010
# Epoch 23/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6713 - loss: 0.8773 - val_accuracy: 0.6823 - val_loss: 0.8391
# Epoch 24/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6871 - loss: 0.8273 - val_accuracy: 0.6793 - val_loss: 0.8683
# Epoch 25/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6862 - loss: 0.8210 - val_accuracy: 0.6888 - val_loss: 0.8349
# Epoch 26/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6919 - loss: 0.8085 - val_accuracy: 0.6689 - val_loss: 0.8647
# Epoch 27/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6881 - loss: 0.8247 - val_accuracy: 0.6841 - val_loss: 0.8419
# Epoch 28/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6904 - loss: 0.8015 - val_accuracy: 0.6760 - val_loss: 0.8666
# Epoch 29/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7025 - loss: 0.7925 - val_accuracy: 0.6415 - val_loss: 1.0365
# Epoch 30/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6774 - loss: 0.8922 - val_accuracy: 0.6804 - val_loss: 0.8295
# Epoch 31/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7010 - loss: 0.7847 - val_accuracy: 0.6852 - val_loss: 0.8286
# Epoch 32/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7060 - loss: 0.7794 - val_accuracy: 0.6881 - val_loss: 0.8300
# Epoch 33/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7017 - loss: 0.7789 - val_accuracy: 0.6865 - val_loss: 0.8563
# Epoch 34/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7040 - loss: 0.7783 - val_accuracy: 0.6888 - val_loss: 0.8330
# Epoch 35/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7025 - loss: 0.7940 - val_accuracy: 0.6850 - val_loss: 0.8530
# Epoch 36/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7114 - loss: 0.7580 - val_accuracy: 0.6916 - val_loss: 0.8220
# Epoch 37/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7093 - loss: 0.7759 - val_accuracy: 0.6954 - val_loss: 0.8148
# Epoch 38/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7098 - loss: 0.7641 - val_accuracy: 0.6936 - val_loss: 0.8398
# Epoch 39/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7002 - loss: 0.7757 - val_accuracy: 0.6753 - val_loss: 0.8867
# Epoch 40/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7073 - loss: 0.7674 - val_accuracy: 0.6890 - val_loss: 0.8453
# Epoch 41/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7099 - loss: 0.7689 - val_accuracy: 0.6885 - val_loss: 0.8325
# Epoch 42/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7221 - loss: 0.7331 - val_accuracy: 0.6896 - val_loss: 0.8533
# Epoch 43/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7163 - loss: 0.7470 - val_accuracy: 0.6943 - val_loss: 0.8233
# Epoch 44/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6913 - loss: 0.8241 - val_accuracy: 0.6949 - val_loss: 0.8229
# Epoch 45/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7190 - loss: 0.7371 - val_accuracy: 0.6698 - val_loss: 0.8852
# Epoch 46/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7141 - loss: 0.7514 - val_accuracy: 0.6991 - val_loss: 0.8217
# Epoch 47/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7223 - loss: 0.7334 - val_accuracy: 0.6848 - val_loss: 0.8671
# Epoch 48/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7273 - loss: 0.7232 - val_accuracy: 0.6983 - val_loss: 0.8295
# Epoch 49/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7207 - loss: 0.7448 - val_accuracy: 0.6943 - val_loss: 0.8392
# Epoch 50/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7196 - loss: 0.7342 - val_accuracy: 0.6945 - val_loss: 0.8348
# Epoch 51/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7190 - loss: 0.7347 - val_accuracy: 0.6919 - val_loss: 0.8604
# Epoch 52/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7299 - loss: 0.7049 - val_accuracy: 0.6905 - val_loss: 0.8443
# Epoch 53/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7290 - loss: 0.7098 - val_accuracy: 0.6890 - val_loss: 0.8523
# Epoch 54/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7238 - loss: 0.7204 - val_accuracy: 0.7000 - val_loss: 0.8296
# Epoch 55/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7304 - loss: 0.7110 - val_accuracy: 0.6998 - val_loss: 0.8468
# Epoch 56/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7317 - loss: 0.6964 - val_accuracy: 0.6762 - val_loss: 0.9143
# Epoch 57/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6613 - loss: 0.9131 - val_accuracy: 0.6994 - val_loss: 0.8416
# Epoch 58/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7279 - loss: 0.7065 - val_accuracy: 0.6952 - val_loss: 0.8175
# Epoch 59/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7304 - loss: 0.6980 - val_accuracy: 0.7024 - val_loss: 0.8367
# Epoch 60/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7279 - loss: 0.7122 - val_accuracy: 0.7045 - val_loss: 0.8201
# Epoch 61/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7320 - loss: 0.6941 - val_accuracy: 0.7035 - val_loss: 0.8375
# Epoch 62/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7298 - loss: 0.7048 - val_accuracy: 0.6949 - val_loss: 0.8428
# Epoch 63/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7335 - loss: 0.6970 - val_accuracy: 0.7036 - val_loss: 0.8312
# Epoch 64/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7351 - loss: 0.6911 - val_accuracy: 0.6991 - val_loss: 0.8326
# Epoch 65/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7286 - loss: 0.7069 - val_accuracy: 0.7051 - val_loss: 0.8315
# Epoch 66/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7390 - loss: 0.6838 - val_accuracy: 0.6947 - val_loss: 0.8529
# Epoch 67/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7363 - loss: 0.7053 - val_accuracy: 0.6930 - val_loss: 0.8644
# Epoch 68/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7426 - loss: 0.6738 - val_accuracy: 0.7042 - val_loss: 0.8517
# Epoch 69/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7438 - loss: 0.6723 - val_accuracy: 0.6954 - val_loss: 0.8406
# Epoch 70/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7387 - loss: 0.6703 - val_accuracy: 0.6987 - val_loss: 0.8377
# Epoch 71/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7343 - loss: 0.6911 - val_accuracy: 0.6919 - val_loss: 0.8809
# Epoch 72/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7301 - loss: 0.7089 - val_accuracy: 0.6971 - val_loss: 0.8630
# Epoch 73/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7421 - loss: 0.6678 - val_accuracy: 0.7060 - val_loss: 0.8286
# Epoch 74/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7465 - loss: 0.6620 - val_accuracy: 0.7069 - val_loss: 0.8307
# Epoch 75/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7457 - loss: 0.6602 - val_accuracy: 0.6976 - val_loss: 0.8952
# Epoch 76/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7328 - loss: 0.6938 - val_accuracy: 0.7014 - val_loss: 0.8387
# Epoch 77/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7452 - loss: 0.6639 - val_accuracy: 0.6894 - val_loss: 0.9017
# Epoch 78/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7440 - loss: 0.6705 - val_accuracy: 0.6980 - val_loss: 0.8610
# Epoch 79/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7396 - loss: 0.6660 - val_accuracy: 0.7029 - val_loss: 0.8550
# Epoch 80/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7401 - loss: 0.6824 - val_accuracy: 0.7047 - val_loss: 0.8357
# Epoch 81/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7481 - loss: 0.6540 - val_accuracy: 0.6874 - val_loss: 0.9152
# Epoch 82/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7402 - loss: 0.6876 - val_accuracy: 0.6949 - val_loss: 0.8854
# Epoch 83/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7333 - loss: 0.7018 - val_accuracy: 0.7038 - val_loss: 0.8862
# Epoch 84/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7391 - loss: 0.6813 - val_accuracy: 0.7051 - val_loss: 0.8643
# Epoch 85/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7479 - loss: 0.6622 - val_accuracy: 0.6918 - val_loss: 0.9097
# Epoch 86/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7455 - loss: 0.6578 - val_accuracy: 0.7027 - val_loss: 0.8932
# Epoch 87/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7487 - loss: 0.6540 - val_accuracy: 0.7011 - val_loss: 0.8736
# Epoch 88/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7330 - loss: 0.6908 - val_accuracy: 0.6991 - val_loss: 0.8585
# Epoch 89/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7332 - loss: 0.6837 - val_accuracy: 0.6921 - val_loss: 0.9108
# Epoch 90/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7503 - loss: 0.6504 - val_accuracy: 0.7033 - val_loss: 0.8435
# Epoch 91/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7499 - loss: 0.6497 - val_accuracy: 0.7005 - val_loss: 0.8846
# Epoch 92/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7514 - loss: 0.6413 - val_accuracy: 0.6905 - val_loss: 0.8950
# Epoch 93/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7522 - loss: 0.6449 - val_accuracy: 0.7011 - val_loss: 0.8837
# Epoch 94/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7452 - loss: 0.6603 - val_accuracy: 0.7024 - val_loss: 0.9037
# Epoch 95/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7426 - loss: 0.6691 - val_accuracy: 0.6982 - val_loss: 0.8768
# Epoch 96/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6710 - loss: 0.8715 - val_accuracy: 0.7029 - val_loss: 0.8810
# Epoch 97/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7464 - loss: 0.6459 - val_accuracy: 0.7071 - val_loss: 0.8615
# Epoch 98/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7546 - loss: 0.6263 - val_accuracy: 0.7042 - val_loss: 0.8707
# Epoch 99/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7535 - loss: 0.6293 - val_accuracy: 0.7016 - val_loss: 0.8896
# Epoch 100/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7534 - loss: 0.6375 - val_accuracy: 0.7025 - val_loss: 0.9072
# Epoch 101/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7557 - loss: 0.6300 - val_accuracy: 0.6896 - val_loss: 0.9006
# Epoch 102/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7524 - loss: 0.6453 - val_accuracy: 0.6923 - val_loss: 0.9130
# Epoch 103/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7514 - loss: 0.6421 - val_accuracy: 0.7003 - val_loss: 0.9161
# Epoch 104/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7168 - loss: 0.7403 - val_accuracy: 0.6958 - val_loss: 0.8850
# Epoch 105/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7584 - loss: 0.6261 - val_accuracy: 0.6967 - val_loss: 0.8688
# Epoch 106/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7550 - loss: 0.6249 - val_accuracy: 0.6982 - val_loss: 0.8975
# Epoch 107/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7501 - loss: 0.6413 - val_accuracy: 0.7000 - val_loss: 0.8915
# Epoch 108/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7547 - loss: 0.6226 - val_accuracy: 0.7016 - val_loss: 0.8917
# Epoch 109/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7516 - loss: 0.6401 - val_accuracy: 0.7042 - val_loss: 0.9065
# Epoch 110/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7641 - loss: 0.6179 - val_accuracy: 0.6921 - val_loss: 0.9465
# Epoch 111/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7491 - loss: 0.6423 - val_accuracy: 0.6941 - val_loss: 0.9311
# Epoch 112/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7547 - loss: 0.6221 - val_accuracy: 0.6994 - val_loss: 0.8758
# Epoch 113/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7539 - loss: 0.6261 - val_accuracy: 0.6993 - val_loss: 0.8838
# Epoch 114/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7561 - loss: 0.6318 - val_accuracy: 0.6929 - val_loss: 0.9179
# Epoch 115/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7559 - loss: 0.6436 - val_accuracy: 0.6974 - val_loss: 0.9299
# Epoch 116/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7368 - loss: 0.6730 - val_accuracy: 0.6894 - val_loss: 0.9272
# Epoch 117/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7591 - loss: 0.6165 - val_accuracy: 0.7031 - val_loss: 0.9264
# Epoch 118/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7581 - loss: 0.6288 - val_accuracy: 0.7002 - val_loss: 0.8880
# Epoch 119/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7590 - loss: 0.6213 - val_accuracy: 0.7013 - val_loss: 0.9153
# Epoch 120/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7574 - loss: 0.6273 - val_accuracy: 0.7005 - val_loss: 0.9270
# Epoch 121/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7537 - loss: 0.6355 - val_accuracy: 0.6976 - val_loss: 0.9451
# Epoch 122/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7337 - loss: 0.7067 - val_accuracy: 0.6896 - val_loss: 0.9186
# Epoch 123/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7467 - loss: 0.6399 - val_accuracy: 0.7002 - val_loss: 0.9065
# Epoch 124/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7639 - loss: 0.6030 - val_accuracy: 0.6987 - val_loss: 0.9102
# Epoch 125/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7642 - loss: 0.6088 - val_accuracy: 0.7000 - val_loss: 0.9183
# Epoch 126/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7623 - loss: 0.6145 - val_accuracy: 0.7013 - val_loss: 0.9138
# Epoch 127/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7688 - loss: 0.5960 - val_accuracy: 0.6961 - val_loss: 0.9329
# Epoch 128/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7633 - loss: 0.6071 - val_accuracy: 0.6943 - val_loss: 0.9536
# Epoch 129/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7664 - loss: 0.6002 - val_accuracy: 0.6954 - val_loss: 0.9468
# Epoch 130/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7569 - loss: 0.6264 - val_accuracy: 0.6802 - val_loss: 1.0068
# Epoch 131/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7515 - loss: 0.6618 - val_accuracy: 0.6987 - val_loss: 0.9307
# Epoch 132/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7597 - loss: 0.6365 - val_accuracy: 0.6982 - val_loss: 0.9251
# Epoch 133/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7603 - loss: 0.6140 - val_accuracy: 0.6965 - val_loss: 0.9259
# Epoch 134/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7699 - loss: 0.5818 - val_accuracy: 0.7009 - val_loss: 0.9033
# Epoch 135/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7672 - loss: 0.5924 - val_accuracy: 0.6899 - val_loss: 0.9269
# Epoch 136/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7578 - loss: 0.6122 - val_accuracy: 0.7007 - val_loss: 0.9926
# Epoch 137/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7481 - loss: 0.6719 - val_accuracy: 0.6998 - val_loss: 0.9704
# Epoch 138/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7660 - loss: 0.5949 - val_accuracy: 0.7024 - val_loss: 0.9685
# Epoch 139/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7702 - loss: 0.5907 - val_accuracy: 0.6936 - val_loss: 0.9296
# Epoch 140/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7426 - loss: 0.6596 - val_accuracy: 0.7024 - val_loss: 0.9455
# Epoch 141/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7711 - loss: 0.5856 - val_accuracy: 0.6896 - val_loss: 1.0171
# Epoch 142/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7610 - loss: 0.6110 - val_accuracy: 0.6994 - val_loss: 0.9572
# Epoch 143/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7627 - loss: 0.6061 - val_accuracy: 0.6991 - val_loss: 0.9615
# Epoch 144/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7622 - loss: 0.5994 - val_accuracy: 0.6980 - val_loss: 0.9322
# Epoch 145/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7669 - loss: 0.5902 - val_accuracy: 0.7011 - val_loss: 0.9567
# Epoch 146/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7594 - loss: 0.6106 - val_accuracy: 0.7044 - val_loss: 0.9339
# Epoch 147/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7701 - loss: 0.5964 - val_accuracy: 0.7040 - val_loss: 0.9697
# Epoch 148/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.7433 - loss: 0.6633 - val_accuracy: 0.6899 - val_loss: 1.0046
# Epoch 149/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.7624 - loss: 0.6067 - val_accuracy: 0.6954 - val_loss: 0.9831
# Epoch 150/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - accuracy: 0.7725 - loss: 0.5865 - val_accuracy: 0.6967 - val_loss: 1.0176
# Epoch 151/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7555 - loss: 0.6457 - val_accuracy: 0.7002 - val_loss: 0.9646
# Epoch 152/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7730 - loss: 0.5876 - val_accuracy: 0.6936 - val_loss: 0.9989
# Epoch 153/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7740 - loss: 0.5824 - val_accuracy: 0.6925 - val_loss: 0.9758
# Epoch 154/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7696 - loss: 0.5935 - val_accuracy: 0.6954 - val_loss: 0.9526
# Epoch 155/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7697 - loss: 0.5976 - val_accuracy: 0.7038 - val_loss: 0.9766
# Epoch 156/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7729 - loss: 0.5764 - val_accuracy: 0.6894 - val_loss: 1.0130
# Epoch 157/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.7594 - loss: 0.6161 - val_accuracy: 0.6850 - val_loss: 0.9595
# Epoch 158/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7685 - loss: 0.5849 - val_accuracy: 0.6987 - val_loss: 0.9696
# Epoch 159/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.7616 - loss: 0.6232 - val_accuracy: 0.6980 - val_loss: 0.9328
# Epoch 160/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7779 - loss: 0.5678 - val_accuracy: 0.7005 - val_loss: 0.9930
# Epoch 161/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7747 - loss: 0.5820 - val_accuracy: 0.7031 - val_loss: 1.0013
# Epoch 162/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7668 - loss: 0.5852 - val_accuracy: 0.6983 - val_loss: 0.9754
# Epoch 163/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.7727 - loss: 0.5701 - val_accuracy: 0.6861 - val_loss: 0.9637
# Epoch 164/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.7605 - loss: 0.6079 - val_accuracy: 0.7040 - val_loss: 0.9749
# Epoch 165/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7731 - loss: 0.5759 - val_accuracy: 0.6972 - val_loss: 1.0059
# Epoch 166/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.7508 - loss: 0.6537 - val_accuracy: 0.7007 - val_loss: 1.0043
# Epoch 167/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7777 - loss: 0.5658 - val_accuracy: 0.7013 - val_loss: 0.9984
# Epoch 168/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7689 - loss: 0.5866 - val_accuracy: 0.6961 - val_loss: 0.9561
# Epoch 169/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7778 - loss: 0.5663 - val_accuracy: 0.6965 - val_loss: 0.9655
# Epoch 170/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7756 - loss: 0.5805 - val_accuracy: 0.7038 - val_loss: 0.9881
# Epoch 171/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.7707 - loss: 0.5889 - val_accuracy: 0.7009 - val_loss: 0.9754
# Epoch 172/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7730 - loss: 0.5741 - val_accuracy: 0.6965 - val_loss: 0.9974
# Epoch 173/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.7631 - loss: 0.5969 - val_accuracy: 0.6940 - val_loss: 0.9701
# Epoch 174/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7750 - loss: 0.5708 - val_accuracy: 0.6960 - val_loss: 0.9911
# Epoch 175/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7800 - loss: 0.5652 - val_accuracy: 0.7016 - val_loss: 0.9510
# Epoch 176/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7730 - loss: 0.5717 - val_accuracy: 0.7007 - val_loss: 0.9684
# Epoch 177/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7772 - loss: 0.5668 - val_accuracy: 0.6958 - val_loss: 0.9925
# Epoch 178/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.7811 - loss: 0.5606 - val_accuracy: 0.6980 - val_loss: 0.9818
# Epoch 179/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7565 - loss: 0.6398 - val_accuracy: 0.6987 - val_loss: 0.9897
# Epoch 180/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.7687 - loss: 0.5865 - val_accuracy: 0.6943 - val_loss: 1.0272
# Epoch 181/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7713 - loss: 0.5844 - val_accuracy: 0.6927 - val_loss: 0.9955
# Epoch 182/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7771 - loss: 0.5704 - val_accuracy: 0.7009 - val_loss: 1.0790
# Epoch 183/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.7782 - loss: 0.5629 - val_accuracy: 0.6982 - val_loss: 1.0046
# Epoch 184/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7793 - loss: 0.5649 - val_accuracy: 0.7011 - val_loss: 1.0497
# Epoch 185/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.7684 - loss: 0.5844 - val_accuracy: 0.6941 - val_loss: 1.0088
# Epoch 186/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7766 - loss: 0.5707 - val_accuracy: 0.6949 - val_loss: 1.0173
# Epoch 187/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7726 - loss: 0.5824 - val_accuracy: 0.7002 - val_loss: 1.0285
# Epoch 188/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7743 - loss: 0.5800 - val_accuracy: 0.6980 - val_loss: 0.9948
# Epoch 189/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7736 - loss: 0.5831 - val_accuracy: 0.6897 - val_loss: 1.0938
# Epoch 190/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7221 - loss: 0.7372 - val_accuracy: 0.6978 - val_loss: 0.9675
# Epoch 191/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.7778 - loss: 0.5647 - val_accuracy: 0.6903 - val_loss: 0.9736
# Epoch 192/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7805 - loss: 0.5548 - val_accuracy: 0.6958 - val_loss: 1.0371
# Epoch 193/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7839 - loss: 0.5550 - val_accuracy: 0.7036 - val_loss: 1.0516
# Epoch 194/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7775 - loss: 0.5541 - val_accuracy: 0.6972 - val_loss: 1.0312
# Epoch 195/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7692 - loss: 0.5848 - val_accuracy: 0.6965 - val_loss: 1.0725
# Epoch 196/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7718 - loss: 0.5846 - val_accuracy: 0.6910 - val_loss: 1.0411
# Epoch 197/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7761 - loss: 0.5748 - val_accuracy: 0.7040 - val_loss: 0.9835
# Epoch 198/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7748 - loss: 0.5802 - val_accuracy: 0.6914 - val_loss: 1.0272
# Epoch 199/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7764 - loss: 0.5661 - val_accuracy: 0.7029 - val_loss: 0.9645
# Epoch 200/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7787 - loss: 0.5486 - val_accuracy: 0.6994 - val_loss: 0.9999
# Epoch 201/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7826 - loss: 0.5495 - val_accuracy: 0.6947 - val_loss: 1.0496
# Epoch 202/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7326 - loss: 0.7274 - val_accuracy: 0.7020 - val_loss: 0.9995
# Epoch 203/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7798 - loss: 0.5518 - val_accuracy: 0.6930 - val_loss: 1.0442
# Epoch 204/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7789 - loss: 0.5565 - val_accuracy: 0.6978 - val_loss: 1.1006
# Epoch 205/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7786 - loss: 0.5571 - val_accuracy: 0.6921 - val_loss: 1.0061
# Epoch 206/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7769 - loss: 0.5572 - val_accuracy: 0.7018 - val_loss: 1.0450
# Epoch 207/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.7766 - loss: 0.5615 - val_accuracy: 0.6961 - val_loss: 1.0220
# Epoch 208/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.7806 - loss: 0.5445 - val_accuracy: 0.6969 - val_loss: 1.0547
# Epoch 209/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.7802 - loss: 0.5584 - val_accuracy: 0.7035 - val_loss: 1.0826
# Epoch 210/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7855 - loss: 0.5455 - val_accuracy: 0.6976 - val_loss: 1.0507
# Epoch 211/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7843 - loss: 0.5447 - val_accuracy: 0.6897 - val_loss: 1.0303
# Epoch 212/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7724 - loss: 0.5945 - val_accuracy: 0.6982 - val_loss: 1.0472
# Epoch 213/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7764 - loss: 0.5720 - val_accuracy: 0.6994 - val_loss: 1.0564
# Epoch 214/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7823 - loss: 0.5543 - val_accuracy: 0.6941 - val_loss: 1.0290
# Epoch 215/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.7808 - loss: 0.5643 - val_accuracy: 0.7029 - val_loss: 1.0698
# Epoch 216/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7786 - loss: 0.5498 - val_accuracy: 0.6969 - val_loss: 1.0490
# Epoch 217/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7845 - loss: 0.5473 - val_accuracy: 0.6927 - val_loss: 1.0738
# Epoch 218/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7822 - loss: 0.5483 - val_accuracy: 0.6876 - val_loss: 1.0310
# Epoch 219/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7798 - loss: 0.5573 - val_accuracy: 0.6947 - val_loss: 1.0872
# Epoch 220/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7861 - loss: 0.5503 - val_accuracy: 0.7049 - val_loss: 1.0933
# Epoch 221/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7840 - loss: 0.5488 - val_accuracy: 0.6932 - val_loss: 1.1119
# Epoch 222/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7775 - loss: 0.5677 - val_accuracy: 0.6899 - val_loss: 1.0108
# Epoch 223/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7873 - loss: 0.5441 - val_accuracy: 0.6896 - val_loss: 1.0363
# Epoch 224/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7832 - loss: 0.5479 - val_accuracy: 0.6994 - val_loss: 1.1321
# Epoch 225/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7652 - loss: 0.6208 - val_accuracy: 0.7027 - val_loss: 1.0704
# Epoch 226/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7871 - loss: 0.5375 - val_accuracy: 0.6872 - val_loss: 1.1647
# Epoch 227/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7803 - loss: 0.5783 - val_accuracy: 0.7014 - val_loss: 1.0737
# Epoch 228/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7819 - loss: 0.5529 - val_accuracy: 0.6916 - val_loss: 1.0628
# Epoch 229/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7798 - loss: 0.5640 - val_accuracy: 0.6965 - val_loss: 1.0255
# Epoch 230/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7825 - loss: 0.5503 - val_accuracy: 0.6881 - val_loss: 1.1711
# Epoch 231/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7806 - loss: 0.5544 - val_accuracy: 0.6881 - val_loss: 1.0731
# Epoch 232/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7365 - loss: 0.7063 - val_accuracy: 0.6967 - val_loss: 1.0412
# Epoch 233/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7868 - loss: 0.5385 - val_accuracy: 0.7027 - val_loss: 1.0744
# Epoch 234/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7881 - loss: 0.5340 - val_accuracy: 0.6994 - val_loss: 1.0641
# Epoch 235/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7841 - loss: 0.5529 - val_accuracy: 0.6969 - val_loss: 1.0522
# Epoch 236/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7922 - loss: 0.5261 - val_accuracy: 0.6989 - val_loss: 1.1330
# Epoch 237/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7886 - loss: 0.5335 - val_accuracy: 0.7033 - val_loss: 1.1217
# Epoch 238/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7763 - loss: 0.5688 - val_accuracy: 0.6976 - val_loss: 1.0566
# Epoch 239/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7788 - loss: 0.5545 - val_accuracy: 0.6945 - val_loss: 1.1250
# Epoch 240/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7885 - loss: 0.5328 - val_accuracy: 0.6866 - val_loss: 1.1363
# Epoch 241/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7401 - loss: 0.7168 - val_accuracy: 0.6950 - val_loss: 1.0583
# Epoch 242/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7872 - loss: 0.5376 - val_accuracy: 0.6983 - val_loss: 1.1212
# Epoch 243/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7851 - loss: 0.5534 - val_accuracy: 0.6819 - val_loss: 1.0577
# Epoch 244/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.7906 - loss: 0.5276 - val_accuracy: 0.6974 - val_loss: 1.0749
# Epoch 245/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7862 - loss: 0.5454 - val_accuracy: 0.6802 - val_loss: 1.0357
# Epoch 246/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7876 - loss: 0.5438 - val_accuracy: 0.7036 - val_loss: 1.0827
# Epoch 247/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7889 - loss: 0.5372 - val_accuracy: 0.6994 - val_loss: 1.0455
# Epoch 248/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7814 - loss: 0.5482 - val_accuracy: 0.6899 - val_loss: 1.1224
# Epoch 249/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.7865 - loss: 0.5344 - val_accuracy: 0.6830 - val_loss: 1.0816
# Epoch 250/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7892 - loss: 0.5471 - val_accuracy: 0.6887 - val_loss: 1.0054
# Epoch 251/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.7833 - loss: 0.5392 - val_accuracy: 0.7014 - val_loss: 1.0652
# Epoch 252/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.7905 - loss: 0.5334 - val_accuracy: 0.6980 - val_loss: 1.0844
# Epoch 253/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.7867 - loss: 0.5332 - val_accuracy: 0.6930 - val_loss: 1.0698
# Epoch 254/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.7891 - loss: 0.5262 - val_accuracy: 0.6901 - val_loss: 1.0930
# Epoch 255/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7892 - loss: 0.5348 - val_accuracy: 0.6969 - val_loss: 1.0707
# Epoch 256/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7873 - loss: 0.5288 - val_accuracy: 0.6901 - val_loss: 1.0862
# Epoch 257/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7832 - loss: 0.5494 - val_accuracy: 0.7007 - val_loss: 1.0681
# Epoch 258/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7930 - loss: 0.5118 - val_accuracy: 0.6861 - val_loss: 1.1121
# Epoch 259/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7889 - loss: 0.5450 - val_accuracy: 0.6876 - val_loss: 1.0681
# Epoch 260/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7567 - loss: 0.6213 - val_accuracy: 0.6866 - val_loss: 1.0735
# Epoch 261/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7650 - loss: 0.6014 - val_accuracy: 0.6918 - val_loss: 1.0766
# Epoch 262/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7865 - loss: 0.5341 - val_accuracy: 0.6943 - val_loss: 1.1096
# Epoch 263/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7773 - loss: 0.5581 - val_accuracy: 0.6845 - val_loss: 1.0768
# Epoch 264/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7843 - loss: 0.5438 - val_accuracy: 0.6901 - val_loss: 1.1227
# Epoch 265/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7887 - loss: 0.5218 - val_accuracy: 0.6958 - val_loss: 1.0755
# Epoch 266/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7633 - loss: 0.6214 - val_accuracy: 0.6897 - val_loss: 1.1210
# Epoch 267/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7899 - loss: 0.5284 - val_accuracy: 0.6892 - val_loss: 1.0435
# Epoch 268/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7843 - loss: 0.5333 - val_accuracy: 0.6919 - val_loss: 1.0710
# Epoch 269/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7888 - loss: 0.5245 - val_accuracy: 0.6989 - val_loss: 1.1462
# Epoch 270/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.7918 - loss: 0.5375 - val_accuracy: 0.6919 - val_loss: 1.0552
# Epoch 271/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7922 - loss: 0.5164 - val_accuracy: 0.6932 - val_loss: 1.1058
# Epoch 272/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7940 - loss: 0.5252 - val_accuracy: 0.6958 - val_loss: 1.2054
# Epoch 273/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7870 - loss: 0.5292 - val_accuracy: 0.6980 - val_loss: 1.1689
# Epoch 274/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7914 - loss: 0.5267 - val_accuracy: 0.6934 - val_loss: 1.1353
# Epoch 275/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7887 - loss: 0.5348 - val_accuracy: 0.6916 - val_loss: 1.1529
# Epoch 276/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7926 - loss: 0.5215 - val_accuracy: 0.6936 - val_loss: 1.0825
# Epoch 277/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7819 - loss: 0.5578 - val_accuracy: 0.6961 - val_loss: 1.1142
# Epoch 278/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7885 - loss: 0.5339 - val_accuracy: 0.6967 - val_loss: 1.1167
# Epoch 279/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7857 - loss: 0.5463 - val_accuracy: 0.6881 - val_loss: 1.0767
# Epoch 280/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7896 - loss: 0.5302 - val_accuracy: 0.6929 - val_loss: 1.0969
# Epoch 281/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7897 - loss: 0.5275 - val_accuracy: 0.6919 - val_loss: 1.1880
# Epoch 282/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7917 - loss: 0.5360 - val_accuracy: 0.6908 - val_loss: 1.1557
# Epoch 283/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7960 - loss: 0.5097 - val_accuracy: 0.6965 - val_loss: 1.1494
# Epoch 284/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7990 - loss: 0.5058 - val_accuracy: 0.6899 - val_loss: 1.1926
# Epoch 285/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7971 - loss: 0.5156 - val_accuracy: 0.6941 - val_loss: 1.2295
# Epoch 286/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7904 - loss: 0.5311 - val_accuracy: 0.6945 - val_loss: 1.1532
# Epoch 287/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7952 - loss: 0.5114 - val_accuracy: 0.6950 - val_loss: 1.1696
# Epoch 288/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7895 - loss: 0.5223 - val_accuracy: 0.6972 - val_loss: 1.1760
# Epoch 289/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.7961 - loss: 0.5114 - val_accuracy: 0.6907 - val_loss: 1.1047
# Epoch 290/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7913 - loss: 0.5176 - val_accuracy: 0.6815 - val_loss: 1.1244
# Epoch 291/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7828 - loss: 0.5542 - val_accuracy: 0.6914 - val_loss: 1.1232
# Epoch 292/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7874 - loss: 0.5287 - val_accuracy: 0.6940 - val_loss: 1.2156
# Epoch 293/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7970 - loss: 0.5129 - val_accuracy: 0.6907 - val_loss: 1.1777
# Epoch 294/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7979 - loss: 0.5047 - val_accuracy: 0.6823 - val_loss: 1.1920
# Epoch 295/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7846 - loss: 0.5504 - val_accuracy: 0.6804 - val_loss: 1.2226
# Epoch 296/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7754 - loss: 0.5814 - val_accuracy: 0.6969 - val_loss: 1.1812
# Epoch 297/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7961 - loss: 0.5141 - val_accuracy: 0.6958 - val_loss: 1.1059
# Epoch 298/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7954 - loss: 0.5118 - val_accuracy: 0.6938 - val_loss: 1.1829
# Epoch 299/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.7966 - loss: 0.5098 - val_accuracy: 0.6950 - val_loss: 1.0614
# Epoch 300/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7949 - loss: 0.5108 - val_accuracy: 0.7011 - val_loss: 1.1143
# Epoch 301/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7966 - loss: 0.5108 - val_accuracy: 0.6936 - val_loss: 1.1630
# Epoch 302/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7793 - loss: 0.5625 - val_accuracy: 0.6837 - val_loss: 1.1144
# Epoch 303/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7720 - loss: 0.5936 - val_accuracy: 0.6925 - val_loss: 1.0989
# Epoch 304/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7872 - loss: 0.5376 - val_accuracy: 0.6872 - val_loss: 1.1338
# Epoch 305/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7687 - loss: 0.5922 - val_accuracy: 0.6950 - val_loss: 1.1457
# Epoch 306/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7964 - loss: 0.5119 - val_accuracy: 0.7014 - val_loss: 1.2167
# Epoch 307/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7935 - loss: 0.5143 - val_accuracy: 0.7009 - val_loss: 1.1654
# Epoch 308/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7990 - loss: 0.5029 - val_accuracy: 0.6841 - val_loss: 1.2175
# Epoch 309/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7889 - loss: 0.5239 - val_accuracy: 0.6958 - val_loss: 1.1043
# Epoch 310/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7922 - loss: 0.5155 - val_accuracy: 0.6848 - val_loss: 1.1578
# Epoch 311/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.7894 - loss: 0.5181 - val_accuracy: 0.6887 - val_loss: 1.1964
# Epoch 312/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7942 - loss: 0.5125 - val_accuracy: 0.6899 - val_loss: 1.1834
# Epoch 313/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7924 - loss: 0.5146 - val_accuracy: 0.6802 - val_loss: 1.1903
# Epoch 314/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7954 - loss: 0.5091 - val_accuracy: 0.6813 - val_loss: 1.1597
# Epoch 315/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8008 - loss: 0.5042 - val_accuracy: 0.6890 - val_loss: 1.1775
# Epoch 316/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7904 - loss: 0.5403 - val_accuracy: 0.7018 - val_loss: 1.1557
# Epoch 317/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7956 - loss: 0.5052 - val_accuracy: 0.6969 - val_loss: 1.1964
# Epoch 318/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7944 - loss: 0.5076 - val_accuracy: 0.6932 - val_loss: 1.1574
# Epoch 319/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7990 - loss: 0.5045 - val_accuracy: 0.6839 - val_loss: 1.1877
# Epoch 320/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7907 - loss: 0.5443 - val_accuracy: 0.6960 - val_loss: 1.0907
# Epoch 321/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7965 - loss: 0.5051 - val_accuracy: 0.6932 - val_loss: 1.1691
# Epoch 322/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8022 - loss: 0.4934 - val_accuracy: 0.7007 - val_loss: 1.2155
# Epoch 323/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7912 - loss: 0.5263 - val_accuracy: 0.6947 - val_loss: 1.1288
# Epoch 324/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.8019 - loss: 0.4974 - val_accuracy: 0.6943 - val_loss: 1.1483
# Epoch 325/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7992 - loss: 0.4953 - val_accuracy: 0.6994 - val_loss: 1.1811
# Epoch 326/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7981 - loss: 0.4975 - val_accuracy: 0.6762 - val_loss: 1.1955
# Epoch 327/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7919 - loss: 0.5198 - val_accuracy: 0.6963 - val_loss: 1.2131
# Epoch 328/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7975 - loss: 0.5048 - val_accuracy: 0.6961 - val_loss: 1.1318
# Epoch 329/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7888 - loss: 0.5183 - val_accuracy: 0.6870 - val_loss: 1.1689
# Epoch 330/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7881 - loss: 0.5402 - val_accuracy: 0.6887 - val_loss: 1.1494
# Epoch 331/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7985 - loss: 0.5100 - val_accuracy: 0.6877 - val_loss: 1.1527
# Epoch 332/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7866 - loss: 0.5361 - val_accuracy: 0.6910 - val_loss: 1.0980
# Epoch 333/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.7905 - loss: 0.5184 - val_accuracy: 0.6921 - val_loss: 1.1743
# Epoch 334/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8023 - loss: 0.4880 - val_accuracy: 0.6908 - val_loss: 1.1915
# Epoch 335/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7857 - loss: 0.5333 - val_accuracy: 0.6950 - val_loss: 1.1415
# Epoch 336/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8018 - loss: 0.4912 - val_accuracy: 0.6855 - val_loss: 1.1561
# Epoch 337/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.8016 - loss: 0.4991 - val_accuracy: 0.6938 - val_loss: 1.1350
# Epoch 338/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7959 - loss: 0.5068 - val_accuracy: 0.6896 - val_loss: 1.2137
# Epoch 339/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8014 - loss: 0.4993 - val_accuracy: 0.6945 - val_loss: 1.2195
# Epoch 340/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7894 - loss: 0.5453 - val_accuracy: 0.6965 - val_loss: 1.2283
# Epoch 341/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7916 - loss: 0.5216 - val_accuracy: 0.6894 - val_loss: 1.1883
# Epoch 342/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.7850 - loss: 0.5435 - val_accuracy: 0.6954 - val_loss: 1.1543
# Epoch 343/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.8004 - loss: 0.4888 - val_accuracy: 0.6897 - val_loss: 1.1147
# Epoch 344/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7977 - loss: 0.5066 - val_accuracy: 0.6923 - val_loss: 1.2341
# Epoch 345/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7944 - loss: 0.5160 - val_accuracy: 0.6821 - val_loss: 1.1843
# Epoch 346/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7988 - loss: 0.5039 - val_accuracy: 0.6919 - val_loss: 1.2273
# Epoch 347/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.7987 - loss: 0.4957 - val_accuracy: 0.6881 - val_loss: 1.1611
# Epoch 348/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7972 - loss: 0.5095 - val_accuracy: 0.6912 - val_loss: 1.1960
# Epoch 349/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8022 - loss: 0.4912 - val_accuracy: 0.6938 - val_loss: 1.1813
# Epoch 350/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7732 - loss: 0.5820 - val_accuracy: 0.6954 - val_loss: 1.1544
# Epoch 351/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7916 - loss: 0.5069 - val_accuracy: 0.6938 - val_loss: 1.2242
# Epoch 352/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7931 - loss: 0.5197 - val_accuracy: 0.6976 - val_loss: 1.2745
# Epoch 353/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7939 - loss: 0.5144 - val_accuracy: 0.6940 - val_loss: 1.2225
# Epoch 354/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.7968 - loss: 0.5039 - val_accuracy: 0.6912 - val_loss: 1.2171
# Epoch 355/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7908 - loss: 0.5193 - val_accuracy: 0.6887 - val_loss: 1.2001
# Epoch 356/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.7937 - loss: 0.5049 - val_accuracy: 0.6881 - val_loss: 1.2179
# Epoch 357/500
# ...
# Epoch 381/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.8079 - loss: 0.4800 - val_accuracy: 0.6912 - val_loss: 1.2704
# Epoch 382/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8012 - loss: 0.4921 - val_accuracy: 0.6914 - val_loss: 1.2979
# Epoch 383/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7952 - loss: 0.5093 - val_accuracy: 0.6852 - val_loss: 1.2259
# Epoch 384/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8048 - loss: 0.4851 - val_accuracy: 0.6899 - val_loss: 1.2661
# Epoch 385/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8010 - loss: 0.4993 - val_accuracy: 0.6963 - val_loss: 1.2609
# Epoch 386/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7976 - loss: 0.4900 - val_accuracy: 0.6987 - val_loss: 1.3806
# Epoch 387/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7903 - loss: 0.5596 - val_accuracy: 0.6921 - val_loss: 1.2682
# Epoch 388/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8065 - loss: 0.4830 - val_accuracy: 0.6901 - val_loss: 1.3067
# Epoch 389/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8062 - loss: 0.4915 - val_accuracy: 0.6940 - val_loss: 1.2508
# Epoch 390/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7936 - loss: 0.5168 - val_accuracy: 0.6927 - val_loss: 1.3205
# Epoch 391/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7952 - loss: 0.5110 - val_accuracy: 0.6945 - val_loss: 1.1926
# Epoch 392/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8061 - loss: 0.4804 - val_accuracy: 0.6887 - val_loss: 1.2663
# Epoch 393/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8082 - loss: 0.4668 - val_accuracy: 0.6921 - val_loss: 1.2185
# Epoch 394/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7869 - loss: 0.5442 - val_accuracy: 0.6887 - val_loss: 1.2823
# Epoch 395/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8003 - loss: 0.4894 - val_accuracy: 0.6912 - val_loss: 1.3275
# Epoch 396/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7900 - loss: 0.5427 - val_accuracy: 0.6976 - val_loss: 1.2285
# Epoch 397/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8031 - loss: 0.4814 - val_accuracy: 0.6919 - val_loss: 1.2569
# Epoch 398/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8056 - loss: 0.4766 - val_accuracy: 0.6896 - val_loss: 1.2433
# Epoch 399/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8030 - loss: 0.4867 - val_accuracy: 0.6950 - val_loss: 1.3586
# Epoch 400/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8003 - loss: 0.4808 - val_accuracy: 0.6903 - val_loss: 1.3126
# Epoch 401/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7956 - loss: 0.5040 - val_accuracy: 0.6863 - val_loss: 1.1967
# Epoch 402/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7999 - loss: 0.5001 - val_accuracy: 0.6801 - val_loss: 1.1672
# Epoch 403/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8067 - loss: 0.4795 - val_accuracy: 0.6965 - val_loss: 1.3262
# Epoch 404/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8026 - loss: 0.4895 - val_accuracy: 0.6971 - val_loss: 1.2359
# Epoch 405/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8040 - loss: 0.4839 - val_accuracy: 0.6976 - val_loss: 1.3016
# Epoch 406/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7953 - loss: 0.5139 - val_accuracy: 0.6888 - val_loss: 1.2597
# Epoch 407/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7987 - loss: 0.4906 - val_accuracy: 0.6974 - val_loss: 1.2080
# Epoch 408/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8023 - loss: 0.4864 - val_accuracy: 0.6821 - val_loss: 1.2899
# Epoch 409/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8022 - loss: 0.4908 - val_accuracy: 0.6925 - val_loss: 1.2820
# Epoch 410/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8081 - loss: 0.4773 - val_accuracy: 0.6870 - val_loss: 1.2960
# Epoch 411/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8032 - loss: 0.4878 - val_accuracy: 0.6845 - val_loss: 1.1898
# Epoch 412/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7980 - loss: 0.4982 - val_accuracy: 0.6912 - val_loss: 1.1399
# Epoch 413/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8048 - loss: 0.4860 - val_accuracy: 0.6925 - val_loss: 1.3301
# Epoch 414/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7995 - loss: 0.4990 - val_accuracy: 0.6894 - val_loss: 1.2543
# Epoch 415/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8046 - loss: 0.4747 - val_accuracy: 0.6810 - val_loss: 1.3434
# Epoch 416/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7929 - loss: 0.5288 - val_accuracy: 0.6771 - val_loss: 1.2989
# Epoch 417/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7856 - loss: 0.5492 - val_accuracy: 0.6930 - val_loss: 1.2504
# Epoch 418/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8109 - loss: 0.4629 - val_accuracy: 0.6828 - val_loss: 1.3486
# Epoch 419/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8059 - loss: 0.4806 - val_accuracy: 0.6938 - val_loss: 1.1878
# Epoch 420/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.8011 - loss: 0.4916 - val_accuracy: 0.6832 - val_loss: 1.1568
# Epoch 421/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8014 - loss: 0.4948 - val_accuracy: 0.6852 - val_loss: 1.1707
# Epoch 422/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7940 - loss: 0.5248 - val_accuracy: 0.6923 - val_loss: 1.2220
# Epoch 423/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.8044 - loss: 0.4814 - val_accuracy: 0.6930 - val_loss: 1.2925
# Epoch 424/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8062 - loss: 0.4840 - val_accuracy: 0.6929 - val_loss: 1.3435
# Epoch 425/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8044 - loss: 0.4840 - val_accuracy: 0.6883 - val_loss: 1.3264
# Epoch 426/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8128 - loss: 0.4677 - val_accuracy: 0.6921 - val_loss: 1.3570
# Epoch 427/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8045 - loss: 0.4703 - val_accuracy: 0.6830 - val_loss: 1.3514
# Epoch 428/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8063 - loss: 0.4747 - val_accuracy: 0.6976 - val_loss: 1.3097
# Epoch 429/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.8050 - loss: 0.4721 - val_accuracy: 0.6839 - val_loss: 1.3870
# Epoch 430/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.8052 - loss: 0.4958 - val_accuracy: 0.6940 - val_loss: 1.2956
# Epoch 431/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.8066 - loss: 0.4858 - val_accuracy: 0.6808 - val_loss: 1.3308
# Epoch 432/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7939 - loss: 0.5137 - val_accuracy: 0.6887 - val_loss: 1.3270
# Epoch 433/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7865 - loss: 0.5514 - val_accuracy: 0.6918 - val_loss: 1.2947
# Epoch 434/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8096 - loss: 0.4634 - val_accuracy: 0.6929 - val_loss: 1.4235
# Epoch 435/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8043 - loss: 0.4835 - val_accuracy: 0.6954 - val_loss: 1.4157
# Epoch 436/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8020 - loss: 0.4854 - val_accuracy: 0.6897 - val_loss: 1.3039
# Epoch 437/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8091 - loss: 0.4735 - val_accuracy: 0.6894 - val_loss: 1.3306
# Epoch 438/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8020 - loss: 0.4880 - val_accuracy: 0.6876 - val_loss: 1.2362
# Epoch 439/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7929 - loss: 0.5249 - val_accuracy: 0.6845 - val_loss: 1.3152
# Epoch 440/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8051 - loss: 0.4820 - val_accuracy: 0.6901 - val_loss: 1.1308
# Epoch 441/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.7980 - loss: 0.5033 - val_accuracy: 0.6940 - val_loss: 1.2683
# Epoch 442/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7987 - loss: 0.5049 - val_accuracy: 0.6892 - val_loss: 1.3495
# Epoch 443/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8008 - loss: 0.4791 - val_accuracy: 0.6932 - val_loss: 1.3638
# Epoch 444/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8135 - loss: 0.4662 - val_accuracy: 0.6899 - val_loss: 1.3634
# Epoch 445/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8047 - loss: 0.4823 - val_accuracy: 0.6866 - val_loss: 1.2957
# Epoch 446/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8101 - loss: 0.4727 - val_accuracy: 0.6865 - val_loss: 1.3086
# Epoch 447/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8043 - loss: 0.4850 - val_accuracy: 0.6877 - val_loss: 1.2748
# Epoch 448/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8060 - loss: 0.4850 - val_accuracy: 0.6846 - val_loss: 1.3766
# Epoch 449/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8085 - loss: 0.4899 - val_accuracy: 0.6883 - val_loss: 1.3281
# Epoch 450/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8108 - loss: 0.4739 - val_accuracy: 0.6868 - val_loss: 1.2996
# Epoch 451/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8007 - loss: 0.5006 - val_accuracy: 0.6921 - val_loss: 1.3642
# Epoch 452/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8010 - loss: 0.4904 - val_accuracy: 0.6885 - val_loss: 1.4073
# Epoch 453/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8101 - loss: 0.4660 - val_accuracy: 0.6894 - val_loss: 1.4271
# Epoch 454/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7941 - loss: 0.5139 - val_accuracy: 0.6930 - val_loss: 1.3934
# Epoch 455/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7818 - loss: 0.5682 - val_accuracy: 0.6894 - val_loss: 1.3108
# Epoch 456/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8054 - loss: 0.4906 - val_accuracy: 0.6865 - val_loss: 1.3682
# Epoch 457/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.8097 - loss: 0.4786 - val_accuracy: 0.6912 - val_loss: 1.1575
# Epoch 458/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8070 - loss: 0.4744 - val_accuracy: 0.6945 - val_loss: 1.3055
# Epoch 459/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7997 - loss: 0.4909 - val_accuracy: 0.6912 - val_loss: 1.3906
# Epoch 460/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.8042 - loss: 0.4852 - val_accuracy: 0.6868 - val_loss: 1.3938
# Epoch 461/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8048 - loss: 0.4773 - val_accuracy: 0.6896 - val_loss: 1.3565
# Epoch 462/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8114 - loss: 0.4622 - val_accuracy: 0.6890 - val_loss: 1.2553
# Epoch 463/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7933 - loss: 0.5276 - val_accuracy: 0.6874 - val_loss: 1.2929
# Epoch 464/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.8119 - loss: 0.4683 - val_accuracy: 0.6905 - val_loss: 1.3577
# Epoch 465/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.8085 - loss: 0.4764 - val_accuracy: 0.6850 - val_loss: 1.4127
# Epoch 466/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.8062 - loss: 0.4859 - val_accuracy: 0.6894 - val_loss: 1.3248
# Epoch 467/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8056 - loss: 0.4811 - val_accuracy: 0.6912 - val_loss: 1.2485
# Epoch 468/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8110 - loss: 0.4702 - val_accuracy: 0.6905 - val_loss: 1.3740
# Epoch 469/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8111 - loss: 0.4700 - val_accuracy: 0.6952 - val_loss: 1.4377
# Epoch 470/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8116 - loss: 0.4577 - val_accuracy: 0.6812 - val_loss: 1.3207
# Epoch 471/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8005 - loss: 0.5026 - val_accuracy: 0.6870 - val_loss: 1.4191
# Epoch 472/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.8064 - loss: 0.4756 - val_accuracy: 0.6843 - val_loss: 1.2680
# Epoch 473/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.8110 - loss: 0.4674 - val_accuracy: 0.6813 - val_loss: 1.3163
# Epoch 474/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7805 - loss: 0.5910 - val_accuracy: 0.6919 - val_loss: 1.3790
# Epoch 475/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8090 - loss: 0.4669 - val_accuracy: 0.6843 - val_loss: 1.2873
# Epoch 476/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.8115 - loss: 0.4673 - val_accuracy: 0.6817 - val_loss: 1.4418
# Epoch 477/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7834 - loss: 0.5786 - val_accuracy: 0.6877 - val_loss: 1.2847
# Epoch 478/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.8166 - loss: 0.4591 - val_accuracy: 0.6903 - val_loss: 1.3348
# Epoch 479/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.8096 - loss: 0.4561 - val_accuracy: 0.6872 - val_loss: 1.3924
# Epoch 480/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8101 - loss: 0.4614 - val_accuracy: 0.6837 - val_loss: 1.4288
# Epoch 481/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8173 - loss: 0.4569 - val_accuracy: 0.6782 - val_loss: 1.4107
# Epoch 482/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8057 - loss: 0.4822 - val_accuracy: 0.6855 - val_loss: 1.4587
# Epoch 483/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8010 - loss: 0.4913 - val_accuracy: 0.6927 - val_loss: 1.4137
# Epoch 484/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8011 - loss: 0.4962 - val_accuracy: 0.6896 - val_loss: 1.4955
# Epoch 485/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8101 - loss: 0.4728 - val_accuracy: 0.6850 - val_loss: 1.3758
# Epoch 486/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8077 - loss: 0.4862 - val_accuracy: 0.6852 - val_loss: 1.3574
# Epoch 487/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8107 - loss: 0.4677 - val_accuracy: 0.6892 - val_loss: 1.3303
# Epoch 488/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8031 - loss: 0.4887 - val_accuracy: 0.6810 - val_loss: 1.4012
# Epoch 489/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8046 - loss: 0.4716 - val_accuracy: 0.6877 - val_loss: 1.3490
# Epoch 490/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8008 - loss: 0.4912 - val_accuracy: 0.6885 - val_loss: 1.2322
# Epoch 491/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7999 - loss: 0.4910 - val_accuracy: 0.6815 - val_loss: 1.3212
# Epoch 492/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8113 - loss: 0.4628 - val_accuracy: 0.6819 - val_loss: 1.3228
# Epoch 493/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8105 - loss: 0.4646 - val_accuracy: 0.6903 - val_loss: 1.3143
# Epoch 494/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8163 - loss: 0.4505 - val_accuracy: 0.6888 - val_loss: 1.4084
# Epoch 495/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8012 - loss: 0.5073 - val_accuracy: 0.6872 - val_loss: 1.2871
# Epoch 496/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 13s 25ms/step - accuracy: 0.8095 - loss: 0.4672 - val_accuracy: 0.6810 - val_loss: 1.3840
# Epoch 497/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8095 - loss: 0.4712 - val_accuracy: 0.6901 - val_loss: 1.4620
# Epoch 498/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8109 - loss: 0.4660 - val_accuracy: 0.6830 - val_loss: 1.3814
# Epoch 499/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.8137 - loss: 0.4530 - val_accuracy: 0.6804 - val_loss: 1.5117
# Epoch 500/500
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8088 - loss: 0.4846 - val_accuracy: 0.6887 - val_loss: 1.4152

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.2f}')
# Out:
# 110/164 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5613 - loss: 2.2800
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5672 - loss: 2.2161
# Test Accuracy: 0.56

# %%
model.save("audio_classification_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def predict(file_path, model):
    # Load the audio file
    signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

    # Extract MFCCs
    mfcc = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=2048, hop_length=512)
    mfcc = mfcc.T

    # Ensure the correct shape
    mfcc = np.expand_dims(mfcc, axis=-1)
    mfcc = np.expand_dims(mfcc, axis=0)

    # Make prediction
    prediction = model.predict(mfcc)
    predicted_index = np.argmax(prediction, axis=1)
    return predicted_index

# Load the model
model = tf.keras.models.load_model('audio_classification_model.h5')

# Predict
file_path = 'path_to_new_audio.wav'
predicted_class = predict(file_path, model)
print(f'Predicted Class: {predicted_class}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /tmp/ipykernel_5722/3099885134.py:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~/Desktop/allenv/lib/python3.11/site-packages/librosa/core/audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/librosa/core/audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/soundfile.py:658, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     656 self._info = _create_info_struct(file, mode, samplerate, channels,
#     657                                  format, subtype, endian)
# --> 658 self._file = self._open(file, mode_int, closefd)
#     659 if set(mode).issuperset('r+') and self.seekable():
#     660     # Move write position to 0 (like in Python file objects)
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/soundfile.py:1216, in SoundFile._open(self, file, mode_int, closefd)
#    1215     err = _snd.sf_error(file_ptr)
# -> 1216     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1217 if mode_int == _snd.SFM_WRITE:
#    1218     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1219     # when opening a named pipe in SFM_WRITE mode.
#    1220     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening 'path_to_new_audio.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 23
#      21 # Predict
#      22 file_path = 'path_to_new_audio.wav'
# ---> 23 predicted_class = predict(file_path, model)
#      24 print(f'Predicted Class: {predicted_class}')
#
# Cell In[8], line 3, in predict(file_path, model)
#       1 def predict(file_path, model):
#       2     # Load the audio file
# ----> 3     signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
#       5     # Extract MFCCs
#       6     mfcc = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=2048, hop_length=512)
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/librosa/core/audio.py:184, in load(path, sr, mono, offset, duration, dtype, res_type)
#     180 if isinstance(path, (str, pathlib.PurePath)):
#     181     warnings.warn(
#     182         "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     183     )
# --> 184     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     185 else:
#     186     raise exc
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/librosa/util/decorators.py:59, in deprecated.<locals>.__wrapper(func, *args, **kwargs)
#      50 """Warn the user, and then proceed."""
#      51 warnings.warn(
#      52     "{:s}.{:s}\n\tDeprecated as of librosa version {:s}."
#      53     "\n\tIt will be removed in librosa version {:s}.".format(
#    (...)
#      57     stacklevel=3,  # Would be 2, but the decorator adds a level
#      58 )
# ---> 59 return func(*args, **kwargs)
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/librosa/core/audio.py:240, in __audioread_load(path, offset, duration, dtype)
#     237     reader = path
#     238 else:
#     239     # If the input was not an audioread object, try to open it
# --> 240     reader = audioread.audio_open(path)
#     242 with reader as input_file:
#     243     sr_native = input_file.samplerate
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/audioread/__init__.py:127, in audio_open(path, backends)
#     125 for BackendClass in backends:
#     126     try:
# --> 127         return BackendClass(path)
#     128     except DecodeError:
#     129         pass
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/audioread/rawread.py:59, in RawAudioFile.__init__(self, filename)
#      58 def __init__(self, filename):
# ---> 59     self._fh = open(filename, 'rb')
#      61     try:
#      62         self._file = aifc.open(self._fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_new_audio.wav'

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import sys
import json
import wave
import time
import pyaudio
import librosa
import pathlib
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import Audio
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %% [markdown]
# ## Constants

# %%
SEED = 42
BATCH_SIZE = 32
SAMPLE_RATE = 16000
VALIDATION_SPLIT = 0.2

# %% [markdown]
# # Inference

# %% [markdown]
# ## Loading the model

# %%
try:
    model = tf.keras.models.load_model('model/spec_model_1.keras')
    print("Model loaded successfully.")
except Exception as e:
    print("Error loading model: ", e)
# Out:
# Model loaded successfully.

# %% [markdown]
# ## Record and return audio file

# %%
def record_audio(filename, duration, rate=16000, channels=1, chunk_size=1024):
    p = pyaudio.PyAudio()

    # open stream
    stream = p.open(format=pyaudio.paInt16,
                    channels=channels,
                    rate=rate,
                    input=True,
                    frames_per_buffer=chunk_size)

    print("Recording...")

    frames = []

    # record for duration
    for i in range(0, int(rate / chunk_size * duration)):
        data = stream.read(chunk_size)
        frames.append(data)

    print("Finished recording.")

    # stop and close stream
    stream.stop_stream()
    stream.close()

    # terminate pyaudio object
    p.terminate()

    # save audio file
    wf = wave.open(filename, 'wb')
    wf.setnchannels(channels)
    wf.setsampwidth(p.get_sample_size(pyaudio.paInt16))
    wf.setframerate(rate)
    wf.writeframes(b''.join(frames))
    wf.close()

    return filename

# %%
# Function to print audio properties
def print_audio_properties(file_path):
    if not os.path.isfile(file_path):
        print(f"File {file_path} does not exist.")
        return

    try:
        audio_signal, sample_rate = librosa.load(file_path, sr=None)
        with wave.open(file_path, 'rb') as audio:
            num_channels = audio.getnchannels()
            frame_rate = audio.getframerate()
            num_frames = audio.getnframes()
            duration = num_frames / float(frame_rate)

            print(f"\nAudio Properties for {os.path.basename(file_path)}")
            print(f"Number of channels:  {num_channels}")
            print(f"Sample rate (Hz):    {sample_rate}")
            print(f"Number of frames:    {num_frames}")
            print(f"Duration (s):        {duration}")
            print()
        
        # Play the audio files
        audio = Audio(file_path)
        display(audio)
    except Exception as e:
        print(f"An error occurred while processing the file: {e}")
    return

# %% [markdown]
# ## Feactures

# %%
FRAME_LENGTH = 255
FRAME_STEP = 128
N_MELS = 128

# %%
def get_mel_spectrogram(waveform, sample_rate=SAMPLE_RATE, n_mels=N_MELS):
    stft = tf.signal.stft(waveform, frame_length=FRAME_LENGTH, frame_step=FRAME_STEP)
    spectrogram = tf.abs(stft)
    mel_spectrogram = tf.signal.linear_to_mel_weight_matrix(
        num_mel_bins=n_mels,
        num_spectrogram_bins=spectrogram.shape[-1],
        sample_rate=sample_rate
    )
    mel_spectrogram = tf.tensordot(spectrogram, mel_spectrogram, 1)
    mel_spectrogram = tf.math.log(mel_spectrogram + 1e-6)
    mel_spectrogram = tf.reshape(mel_spectrogram, (-1, 124, 128, 1))

    return mel_spectrogram

# %% [markdown]
# ## Labels

# %%
# Function to get the labels
def get_label_names():
    label_names = ['ddyo', 'emabega', 'kkono', 'mumaaso', 'unknown', 'yimirira'] 
    return label_names

# %% [markdown]
# ## Prediction

# %%
def predict_audio(file_path, model, sample_rate):
    x = tf.io.read_file(str(file_path))
    x, _ = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000)
    x = tf.squeeze(x, axis=-1)
    waveform = x
    x = get_mel_spectrogram(x, sample_rate)

    max_frames = 124
    pad_size = max_frames - x.shape[1]
    if pad_size > 0:
        x = tf.pad(x, [[0, 0], [0, pad_size], [0, 0], [0, 0]])
    else:
        x = x[:, :max_frames, :, :]

    predictions = model.predict(x)
    predicted_label_index = tf.argmax(predictions[0])
    label_names = get_label_names()
    predicted_label = label_names[predicted_label_index]

    return predicted_label, tf.nn.softmax(predictions[0])[predicted_label_index]

# %%
# Record
audio_file = record_audio('output.wav', 3)

# Print audio properties
print_audio_properties(audio_file)

# Predict
predicted_label, probability = predict_audio(audio_file, model, SAMPLE_RATE)
print(f"Predicted label: {predicted_label}, Probability: {probability}")
# Out:
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.front.0:CARD=0'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM front
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM surround21
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM surround21
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.surround40.0:CARD=0'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM surround40
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM surround41
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM surround50
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM surround51
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.surround71.0:CARD=0'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM surround71
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM iec958
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM spdif
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:5181:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5704:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM spdif
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.hdmi
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.hdmi
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.modem
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.modem
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline
# Cannot connect to server socket err = No such file or directory
# Cannot connect to server request channel
# jack server is not running or cannot be started
# JackShmReadWritePtr::~JackShmReadWritePtr - Init not done for -1, skipping unlock
# JackShmReadWritePtr::~JackShmReadWritePtr - Init not done for -1, skipping unlock
# Recording...
# Finished recording.
#
# Audio Properties for output.wav
# Number of channels:  1
# Sample rate (Hz):    16000
# Number of frames:    47104
# Duration (s):        2.944
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted label: kkono, Probability: 0.30271080136299133

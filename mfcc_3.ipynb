# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
import json
import wave
import time
import pyaudio
import librosa
import pathlib
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import Audio
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, GlobalMaxPooling2D
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, f1_score, recall_score
from sklearn.model_selection import train_test_split

# %%
SEED = 42
BATCH_SIZE = 32
SAMPLE_RATE = 16000
VALIDATION_SPLIT = 0.2

# %%
def load_data(json_path):
    with open(json_path, "r") as fp:
        data = json.load(fp)
    return data

train_data = load_data('train_mfccs_10.json')
test_data = load_data('test_mfccs.json')

# %%
# Convert lists to numpy arrays
X_train = np.array(train_data["mfcc"])
y_train = np.array(train_data["labels"])
X_test = np.array(test_data["mfcc"])
y_test = np.array(test_data["labels"])

# Split training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Model definition
def build_model(input_shape):
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(Conv2D(32, (1, 1), activation='relu'))  # Use 1x1 filters here
    model.add(MaxPooling2D((2, 2), strides=(2, 2), padding='same'))

    model.add(GlobalMaxPooling2D())  # Add GlobalMaxPooling2D layer

    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(len(np.unique(y_train)), activation='softmax'))

    return model

# Input shape
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# Build model
model = build_model(input_shape)

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=100)
# Out:
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.3692 - loss: 1.6877 - val_accuracy: 0.4409 - val_loss: 1.3306
# Epoch 2/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4316 - loss: 1.3542 - val_accuracy: 0.4542 - val_loss: 1.3073
# Epoch 3/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4472 - loss: 1.3304 - val_accuracy: 0.4705 - val_loss: 1.3030
# Epoch 4/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4547 - loss: 1.3092 - val_accuracy: 0.4662 - val_loss: 1.3286
# Epoch 5/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4663 - loss: 1.3014 - val_accuracy: 0.4644 - val_loss: 1.2853
# Epoch 6/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4742 - loss: 1.2910 - val_accuracy: 0.4832 - val_loss: 1.2566
# Epoch 7/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4831 - loss: 1.2760 - val_accuracy: 0.4946 - val_loss: 1.2779
# Epoch 8/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4891 - loss: 1.2754 - val_accuracy: 0.5014 - val_loss: 1.2462
# Epoch 9/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4953 - loss: 1.2526 - val_accuracy: 0.4951 - val_loss: 1.2417
# Epoch 10/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4952 - loss: 1.2544 - val_accuracy: 0.4865 - val_loss: 1.2732
# Epoch 11/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5017 - loss: 1.2508 - val_accuracy: 0.5004 - val_loss: 1.2507
# Epoch 12/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5002 - loss: 1.2472 - val_accuracy: 0.5120 - val_loss: 1.2331
# Epoch 13/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5073 - loss: 1.2464 - val_accuracy: 0.5092 - val_loss: 1.2248
# Epoch 14/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5064 - loss: 1.2433 - val_accuracy: 0.5108 - val_loss: 1.2292
# Epoch 15/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5072 - loss: 1.2350 - val_accuracy: 0.5042 - val_loss: 1.2220
# Epoch 16/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5104 - loss: 1.2282 - val_accuracy: 0.5175 - val_loss: 1.2204
# Epoch 17/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5109 - loss: 1.2250 - val_accuracy: 0.5202 - val_loss: 1.2039
# Epoch 18/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5141 - loss: 1.2227 - val_accuracy: 0.5243 - val_loss: 1.2038
# Epoch 19/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5126 - loss: 1.2211 - val_accuracy: 0.5157 - val_loss: 1.2127
# Epoch 20/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5171 - loss: 1.2139 - val_accuracy: 0.5251 - val_loss: 1.1937
# Epoch 21/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5180 - loss: 1.2245 - val_accuracy: 0.5338 - val_loss: 1.1801
# Epoch 22/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5320 - loss: 1.2009 - val_accuracy: 0.5261 - val_loss: 1.2074
# Epoch 23/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5228 - loss: 1.2124 - val_accuracy: 0.5333 - val_loss: 1.1890
# Epoch 24/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5259 - loss: 1.2060 - val_accuracy: 0.5290 - val_loss: 1.1889
# Epoch 25/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5238 - loss: 1.2036 - val_accuracy: 0.5369 - val_loss: 1.1885
# Epoch 26/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5299 - loss: 1.2004 - val_accuracy: 0.5259 - val_loss: 1.2007
# Epoch 27/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5278 - loss: 1.1955 - val_accuracy: 0.5387 - val_loss: 1.1799
# Epoch 28/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5342 - loss: 1.1919 - val_accuracy: 0.5260 - val_loss: 1.1863
# Epoch 29/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5314 - loss: 1.1891 - val_accuracy: 0.5421 - val_loss: 1.1741
# Epoch 30/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5341 - loss: 1.1900 - val_accuracy: 0.5419 - val_loss: 1.1641
# Epoch 31/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5348 - loss: 1.1832 - val_accuracy: 0.5124 - val_loss: 1.2129
# Epoch 32/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5333 - loss: 1.1900 - val_accuracy: 0.5344 - val_loss: 1.1794
# Epoch 33/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5354 - loss: 1.1834 - val_accuracy: 0.5309 - val_loss: 1.1773
# Epoch 34/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5404 - loss: 1.1749 - val_accuracy: 0.5299 - val_loss: 1.1834
# Epoch 35/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5386 - loss: 1.1774 - val_accuracy: 0.5478 - val_loss: 1.1554
# Epoch 36/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5405 - loss: 1.1681 - val_accuracy: 0.5317 - val_loss: 1.1761
# Epoch 37/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5457 - loss: 1.1667 - val_accuracy: 0.5383 - val_loss: 1.1729
# Epoch 38/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.5431 - loss: 1.1662 - val_accuracy: 0.5417 - val_loss: 1.1638
# Epoch 39/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5462 - loss: 1.1708 - val_accuracy: 0.5462 - val_loss: 1.1545
# Epoch 40/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5432 - loss: 1.1671 - val_accuracy: 0.5504 - val_loss: 1.1587
# Epoch 41/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5457 - loss: 1.1682 - val_accuracy: 0.5454 - val_loss: 1.1580
# Epoch 42/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5366 - loss: 1.1901 - val_accuracy: 0.5447 - val_loss: 1.1554
# Epoch 43/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5409 - loss: 1.1671 - val_accuracy: 0.5450 - val_loss: 1.1540
# Epoch 44/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5447 - loss: 1.1660 - val_accuracy: 0.5396 - val_loss: 1.1812
# Epoch 45/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5441 - loss: 1.1626 - val_accuracy: 0.5505 - val_loss: 1.1428
# Epoch 46/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5497 - loss: 1.1570 - val_accuracy: 0.5314 - val_loss: 1.1886
# Epoch 47/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5477 - loss: 1.1595 - val_accuracy: 0.5538 - val_loss: 1.1484
# Epoch 48/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5512 - loss: 1.1542 - val_accuracy: 0.5482 - val_loss: 1.1609
# Epoch 49/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5417 - loss: 1.1621 - val_accuracy: 0.5466 - val_loss: 1.1545
# Epoch 50/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5469 - loss: 1.1539 - val_accuracy: 0.5514 - val_loss: 1.1478
# Epoch 51/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5496 - loss: 1.1562 - val_accuracy: 0.5457 - val_loss: 1.1671
# Epoch 52/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5442 - loss: 1.1674 - val_accuracy: 0.5439 - val_loss: 1.1548
# Epoch 53/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5485 - loss: 1.1593 - val_accuracy: 0.5495 - val_loss: 1.1451
# Epoch 54/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5448 - loss: 1.1562 - val_accuracy: 0.5429 - val_loss: 1.1547
# Epoch 55/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5442 - loss: 1.1624 - val_accuracy: 0.5447 - val_loss: 1.1448
# Epoch 56/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5485 - loss: 1.1569 - val_accuracy: 0.5464 - val_loss: 1.1470
# Epoch 57/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5543 - loss: 1.1504 - val_accuracy: 0.5459 - val_loss: 1.1553
# Epoch 58/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5524 - loss: 1.1531 - val_accuracy: 0.5453 - val_loss: 1.1437
# Epoch 59/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5543 - loss: 1.1426 - val_accuracy: 0.5356 - val_loss: 1.1926
# Epoch 60/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5504 - loss: 1.1477 - val_accuracy: 0.5315 - val_loss: 1.1691
# Epoch 61/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5478 - loss: 1.1502 - val_accuracy: 0.5470 - val_loss: 1.1385
# Epoch 62/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5509 - loss: 1.1513 - val_accuracy: 0.5512 - val_loss: 1.1616
# Epoch 63/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5537 - loss: 1.1462 - val_accuracy: 0.5515 - val_loss: 1.1426
# Epoch 64/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5579 - loss: 1.1444 - val_accuracy: 0.5489 - val_loss: 1.1402
# Epoch 65/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5533 - loss: 1.1496 - val_accuracy: 0.5424 - val_loss: 1.1690
# Epoch 66/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5511 - loss: 1.1498 - val_accuracy: 0.5449 - val_loss: 1.1538
# Epoch 67/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5518 - loss: 1.1487 - val_accuracy: 0.5553 - val_loss: 1.1300
# Epoch 68/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5544 - loss: 1.1448 - val_accuracy: 0.5515 - val_loss: 1.1385
# Epoch 69/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5563 - loss: 1.1446 - val_accuracy: 0.5477 - val_loss: 1.1419
# Epoch 70/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5528 - loss: 1.1468 - val_accuracy: 0.5482 - val_loss: 1.1367
# Epoch 71/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5501 - loss: 1.1442 - val_accuracy: 0.5550 - val_loss: 1.1315
# Epoch 72/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5585 - loss: 1.1410 - val_accuracy: 0.5506 - val_loss: 1.1418
# Epoch 73/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5494 - loss: 1.1514 - val_accuracy: 0.5331 - val_loss: 1.1771
# Epoch 74/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5564 - loss: 1.1419 - val_accuracy: 0.5540 - val_loss: 1.1293
# Epoch 75/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.5533 - loss: 1.1414 - val_accuracy: 0.5447 - val_loss: 1.1479
# Epoch 76/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5587 - loss: 1.1395 - val_accuracy: 0.5431 - val_loss: 1.1608
# Epoch 77/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.5546 - loss: 1.1448 - val_accuracy: 0.5470 - val_loss: 1.1397
# Epoch 78/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.5564 - loss: 1.1334 - val_accuracy: 0.5526 - val_loss: 1.1320
# Epoch 79/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.5505 - loss: 1.1518 - val_accuracy: 0.5468 - val_loss: 1.1425
# Epoch 80/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.5614 - loss: 1.1324 - val_accuracy: 0.5495 - val_loss: 1.1404
# Epoch 81/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.5526 - loss: 1.1525 - val_accuracy: 0.5551 - val_loss: 1.1286
# Epoch 82/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5582 - loss: 1.1344 - val_accuracy: 0.5488 - val_loss: 1.1518
# Epoch 83/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5525 - loss: 1.1468 - val_accuracy: 0.5535 - val_loss: 1.1364
# Epoch 84/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5555 - loss: 1.1299 - val_accuracy: 0.5524 - val_loss: 1.1280
# Epoch 85/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5577 - loss: 1.1318 - val_accuracy: 0.5400 - val_loss: 1.1643
# Epoch 86/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5537 - loss: 1.1484 - val_accuracy: 0.5584 - val_loss: 1.1285
# Epoch 87/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5528 - loss: 1.1448 - val_accuracy: 0.5486 - val_loss: 1.1313
# Epoch 88/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5568 - loss: 1.1323 - val_accuracy: 0.5428 - val_loss: 1.1581
# Epoch 89/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5584 - loss: 1.1355 - val_accuracy: 0.5627 - val_loss: 1.1255
# Epoch 90/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5581 - loss: 1.1398 - val_accuracy: 0.5548 - val_loss: 1.1266
# Epoch 91/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5533 - loss: 1.1411 - val_accuracy: 0.5445 - val_loss: 1.1683
# Epoch 92/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5564 - loss: 1.1375 - val_accuracy: 0.5501 - val_loss: 1.1360
# Epoch 93/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5530 - loss: 1.1457 - val_accuracy: 0.5556 - val_loss: 1.1307
# Epoch 94/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5598 - loss: 1.1291 - val_accuracy: 0.5438 - val_loss: 1.1663
# Epoch 95/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5559 - loss: 1.1406 - val_accuracy: 0.5525 - val_loss: 1.1500
# Epoch 96/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5578 - loss: 1.1333 - val_accuracy: 0.5507 - val_loss: 1.1313
# Epoch 97/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5519 - loss: 1.1450 - val_accuracy: 0.5492 - val_loss: 1.1357
# Epoch 98/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5558 - loss: 1.1381 - val_accuracy: 0.5436 - val_loss: 1.1610
# Epoch 99/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5620 - loss: 1.1321 - val_accuracy: 0.5459 - val_loss: 1.1378
# Epoch 100/100
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5606 - loss: 1.1372 - val_accuracy: 0.5504 - val_loss: 1.1316

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.2f}')
# Out:
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4358 - loss: 1.6236
# Test Accuracy: 0.41

# %%
# Assuming you have the test data prepared as X_test and y_test
# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Calculate accuracy, precision, and F1 score
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes, average='weighted')
f1 = f1_score(y_test, y_pred_classes, average='weighted')

# Print classification report
class_report = classification_report(y_test, y_pred_classes)
print("Classification Report:\n", class_report)
# Out:
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.34      0.33      0.33       983
#            1       0.36      0.89      0.51       608
#            2       0.44      0.49      0.46       961
#            3       0.62      0.34      0.44       942
#            4       0.37      0.19      0.25       857
#            5       0.41      0.34      0.37       885
#
#     accuracy                           0.41      5236
#    macro avg       0.42      0.43      0.40      5236
# weighted avg       0.43      0.41      0.39      5236

# %%
# Function to plot the training history
def plot_training_history(history):
    try:
        acc = history.history['accuracy']
        val_acc = history.history['val_accuracy']
        loss = history.history['loss']
        val_loss = history.history['val_loss']

        epochs = range(len(acc))

        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1)
        plt.plot(epochs, acc, 'r', label='Training accuracy')
        plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs, loss, 'r', label='Training loss')
        plt.plot(epochs, val_loss, 'b', label='Validation loss')
        plt.title('Training and validation loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"An error occurred during plotting the training history: {str(e)}")
        
plot_training_history(history)

# %%
model.save("audio_classification_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def predict(file_path, model):
    # Load the audio file
    signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

    # Extract MFCCs
    mfcc = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=2048, hop_length=512)
    mfcc = mfcc.T

    # Ensure the correct shape
    mfcc = np.expand_dims(mfcc, axis=-1)
    mfcc = np.expand_dims(mfcc, axis=0)

    # Make prediction
    prediction = model.predict(mfcc)
    predicted_index = np.argmax(prediction, axis=1)
    return predicted_index

# Load the model
model = tf.keras.models.load_model('audio_classification_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
train_data_dir = pathlib.Path('Dataset/Train')

emabega_file_path = os.path.join(train_data_dir, 'emabega', 'emabega_001.wav')
ddyo_file_path = os.path.join(train_data_dir, 'ddyo', 'ddyo_001.wav')

# %%
#  Predict
file_path = ddyo_file_path
predicted_class = predict(file_path, model)
print(f'Predicted Class: {predicted_class}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Predicted Class: [4]

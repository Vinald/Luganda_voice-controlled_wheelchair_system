# %% [markdown]
# # Packages

# %% [markdown]
# ## Global Packages

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import sys
import json
import math
import wave
import shutil
import pathlib
import librosa
import numpy as np
import pandas as pd
import seaborn as sns
import soundfile as sf
import librosa.display
import tensorflow as tf
# import sounddevice as sd
import matplotlib.pyplot as plt
from IPython.display import Audio, display
from tensorflow.keras import layers, models
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Constants

# %%
SEED = 42
BATCH_SIZE = 64
SAMPLE_RATE = 16000
VALIDATION_SPLIT = 0.2


# MFCC parameters
N_MFCC = 13
N_FFT = 2048
HOP_LENGTH = 512
TRACK_DURATION = 2
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %% [markdown]
# # Path to the datasets
#
# The dataset's audio clips are of 6 classes and stored in 6 folders corresponding to each speech command:
# - `ddyo`- `kkono` - `mu maaso` - `emabega` - `yimirira` - `unknown`

# %%
train_data_dir = pathlib.Path('Dataset/Train')
test_data_dir = pathlib.Path('Dataset/Test')

train_data_needs_preprocessing = pathlib.Path('Dataset/Train_need_preprocessing')
test_data_needs_preprocessing = pathlib.Path('Dataset/Test_need_preprocessing')

TRAIN_JSON_PATH = pathlib.Path('Dataset/json/mfcc_train_data.json')
TEST_JSON_PATH = pathlib.Path('Dataset/json/mfcc_test_data.json')

# %% [markdown]
# # Labels

# %%
def list_directory_contents(directory, label):
    contents = np.array(tf.io.gfile.listdir(str(directory)))
    print(f'{label} commands labels: {contents}')
    return contents

# %%
train_commands = list_directory_contents(train_data_dir, 'Train')
test_commands = list_directory_contents(test_data_dir, 'Test')
# Out:
# Train commands labels: ['ddyo' 'mumaaso' 'unknown' 'kkono' 'emabega' 'yimirira']
# Test commands labels: ['ddyo' 'mumaaso' 'unknown' 'kkono' 'emabega' 'yimirira']

# %% [markdown]
# # Load sample audio files

# %%
emabega_file_path = os.path.join(train_data_dir, 'emabega', 'emabega.wav')
ddyo_file_path = os.path.join(train_data_dir, 'ddyo', 'ddyo.wav')
yimirira_file_path = os.path.join(train_data_dir, 'yimirira', 'yimirira.wav')
kkono_file_path = os.path.join(train_data_dir, 'kkono', 'kkono.wav')
mumasso_file_path = os.path.join(train_data_dir, 'mumaaso', 'mumaaso.wav')
unknown_file_path = os.path.join(train_data_dir, 'unknown', 'unknown_001.wav')

file_paths = [emabega_file_path, ddyo_file_path, yimirira_file_path, kkono_file_path, mumasso_file_path, unknown_file_path]

# %% [markdown]
# # Dataset Preparaption

# %%
# Function to prepare dataset
def prepare_dataset(data_dir, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=2):
    data = {
        "mapping": [],
        "mfcc": [],
        "labels": [],
        "files": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(data_dir)):
        if dirpath is not data_dir:
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            for f in filenames:
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE, duration=TRACK_DURATION)

                if len(signal) >= SAMPLE_RATE:
                    signal = signal[:SAMPLE_RATE]

                    for d in range(num_segments):
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                        mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            data["files"].append(file_path)
                            print("{}, segment:{}".format(file_path, d+1))

    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=6):

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_AUDIO / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all sub-folders
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing the sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print(f"\nProcessing: {semantic_label}")

            # process all audio files in genre sub-dir
            for f in filenames:

                # load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for the current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(y=signal[start:finish],
                                                sr=sample_rate,
                                                n_mfcc=num_mfcc,
                                                n_fft=n_fft,
                                                hop_length=hop_length)

                    mfcc = mfcc.T

                    # store only mfcc feature with the expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print(f"{file_path}, segment:{d+1}")

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

    # return the data dictionary
    return data

data = save_mfcc(TRAIN_DATASET_PATH, JSON_PATH, num_segments=6)

def load_data(data):

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data successfully loaded!")

    return X, y

X, y = load_data(data)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
prepare_dataset(train_data_dir, TRAIN_JSON_PATH)
prepare_dataset(test_data_dir, TEST_JSON_PATH)
# Out:
# Processing: Train
#
# Processing: ddyo
# Dataset/Train/ddyo/ddyo_324.wav, segment:1
# Dataset/Train/ddyo/ddyo_936.wav, segment:1
# Dataset/Train/ddyo/ddyo_1531.wav, segment:1
# Dataset/Train/ddyo/ddyo_1195.wav, segment:1
# Dataset/Train/ddyo/ddyo_1179.wav, segment:1
# Dataset/Train/ddyo/ddyo_704.wav, segment:1
# /home/vx/project/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=0
#   warnings.warn(
# Dataset/Train/ddyo/ddyo_806.wav, segment:1
# Dataset/Train/ddyo/ddyo_252.wav, segment:1
# Dataset/Train/ddyo/ddyo_1549.wav, segment:1
# Dataset/Train/ddyo/ddyo_679.wav, segment:1
# Dataset/Train/ddyo/ddyo_250.wav, segment:1
# Dataset/Train/ddyo/ddyo_294.wav, segment:1
# Dataset/Train/ddyo/ddyo_473.wav, segment:1
# Dataset/Train/ddyo/ddyo_1568.wav, segment:1
# Dataset/Train/ddyo/ddyo_291.wav, segment:1
# Dataset/Train/ddyo/ddyo_416.wav, segment:1
# Dataset/Train/ddyo/ddyo_546.wav, segment:1
# Dataset/Train/ddyo/ddyo_462.wav, segment:1
# Dataset/Train/ddyo/ddyo_1245.wav, segment:1
# Dataset/Train/ddyo/ddyo_1262.wav, segment:1
# Dataset/Train/ddyo/ddyo_1422.wav, segment:1
# Dataset/Train/ddyo/ddyo_1333.wav, segment:1
# Dataset/Train/ddyo/ddyo_204.wav, segment:1
# Dataset/Train/ddyo/ddyo_304.wav, segment:1
# Dataset/Train/ddyo/ddyo_337.wav, segment:1
# Dataset/Train/ddyo/ddyo_288.wav, segment:1
# Dataset/Train/ddyo/ddyo_1327.wav, segment:1
# Dataset/Train/ddyo/ddyo_647.wav, segment:1
# Dataset/Train/ddyo/ddyo_677.wav, segment:1
# Dataset/Train/ddyo/ddyo_1488.wav, segment:1
# Dataset/Train/ddyo/ddyo_1191.wav, segment:1
# Dataset/Train/ddyo/ddyo_124.wav, segment:1
# Dataset/Train/ddyo/ddyo_1348.wav, segment:1
# Dataset/Train/ddyo/ddyo_1146.wav, segment:1
# Dataset/Train/ddyo/ddyo_692.wav, segment:1
# Dataset/Train/ddyo/ddyo_1128.wav, segment:1
# Dataset/Train/ddyo/ddyo_735.wav, segment:1
# Dataset/Train/ddyo/ddyo_780.wav, segment:1
# Dataset/Train/ddyo/ddyo_424.wav, segment:1
# Dataset/Train/ddyo/ddyo_1360.wav, segment:1
# Dataset/Train/ddyo/ddyo_1412.wav, segment:1
# Dataset/Train/ddyo/ddyo_1523.wav, segment:1
# Dataset/Train/ddyo/ddyo_716.wav, segment:1
# Dataset/Train/ddyo/ddyo_309.wav, segment:1
# Dataset/Train/ddyo/ddyo_275.wav, segment:1
# Dataset/Train/ddyo/ddyo_476.wav, segment:1
# Dataset/Train/ddyo/ddyo_381.wav, segment:1
# Dataset/Train/ddyo/ddyo_400.wav, segment:1
# Dataset/Train/ddyo/ddyo_1256.wav, segment:1
# Dataset/Train/ddyo/ddyo_284.wav, segment:1
# Dataset/Train/ddyo/ddyo_208.wav, segment:1
# Dataset/Train/ddyo/ddyo_379.wav, segment:1
# Dataset/Train/ddyo/ddyo_310.wav, segment:1
# Dataset/Train/ddyo/ddyo_1268.wav, segment:1
# Dataset/Train/ddyo/ddyo_200.wav, segment:1
# Dataset/Train/ddyo/ddyo_1078.wav, segment:1
# Dataset/Train/ddyo/ddyo_966.wav, segment:1
# Dataset/Train/ddyo/ddyo_1481.wav, segment:1
# Dataset/Train/ddyo/ddyo_1455.wav, segment:1
# Dataset/Train/ddyo/ddyo_1008.wav, segment:1
# Dataset/Train/ddyo/ddyo_834.wav, segment:1
# Dataset/Train/ddyo/ddyo_055.wav, segment:1
# Dataset/Train/ddyo/ddyo_188.wav, segment:1
# Dataset/Train/ddyo/ddyo_1510.wav, segment:1
# Dataset/Train/ddyo/ddyo_1282.wav, segment:1
# Dataset/Train/ddyo/ddyo_111.wav, segment:1
# Dataset/Train/ddyo/ddyo_590.wav, segment:1
# Dataset/Train/ddyo/ddyo_1071.wav, segment:1
# Dataset/Train/ddyo/ddyo_973.wav, segment:1
# Dataset/Train/ddyo/ddyo_1005.wav, segment:1
# Dataset/Train/ddyo/ddyo_451.wav, segment:1
# Dataset/Train/ddyo/ddyo_588.wav, segment:1
# Dataset/Train/ddyo/ddyo_222.wav, segment:1
# Dataset/Train/ddyo/ddyo_584.wav, segment:1
# Dataset/Train/ddyo/ddyo_1518.wav, segment:1
# Dataset/Train/ddyo/ddyo_238.wav, segment:1
# Dataset/Train/ddyo/ddyo_1289.wav, segment:1
# Dataset/Train/ddyo/ddyo_1301.wav, segment:1
# Dataset/Train/ddyo/ddyo_237.wav, segment:1
# Dataset/Train/ddyo/ddyo_1506.wav, segment:1
# Dataset/Train/ddyo/ddyo_1052.wav, segment:1
# Dataset/Train/ddyo/ddyo_438.wav, segment:1
# Dataset/Train/ddyo/ddyo_1116.wav, segment:1
# Dataset/Train/ddyo/ddyo_984.wav, segment:1
# Dataset/Train/ddyo/ddyo_557.wav, segment:1
# Dataset/Train/ddyo/ddyo_616.wav, segment:1
# Dataset/Train/ddyo/ddyo_536.wav, segment:1
# Dataset/Train/ddyo/ddyo_453.wav, segment:1
# Dataset/Train/ddyo/ddyo_1395.wav, segment:1
# Dataset/Train/ddyo/ddyo_631.wav, segment:1
# Dataset/Train/ddyo/ddyo_1433.wav, segment:1
# Dataset/Train/ddyo/ddyo_763.wav, segment:1
# Dataset/Train/ddyo/ddyo_044.wav, segment:1
# Dataset/Train/ddyo/ddyo_1255.wav, segment:1
# Dataset/Train/ddyo/ddyo_914.wav, segment:1
# Dataset/Train/ddyo/ddyo_466.wav, segment:1
# Dataset/Train/ddyo/ddyo_256.wav, segment:1
# Dataset/Train/ddyo/ddyo_1070.wav, segment:1
# Dataset/Train/ddyo/ddyo_1407.wav, segment:1
# Dataset/Train/ddyo/ddyo_1566.wav, segment:1
# Dataset/Train/ddyo/ddyo_775.wav, segment:1
# Dataset/Train/ddyo/ddyo_626.wav, segment:1
# Dataset/Train/ddyo/ddyo_1559.wav, segment:1
# Dataset/Train/ddyo/ddyo_233.wav, segment:1
# Dataset/Train/ddyo/ddyo_940.wav, segment:1
# Dataset/Train/ddyo/ddyo_607.wav, segment:1
# Dataset/Train/ddyo/ddyo_038.wav, segment:1
# Dataset/Train/ddyo/ddyo_1170.wav, segment:1
# Dataset/Train/ddyo/ddyo_470.wav, segment:1
# Dataset/Train/ddyo/ddyo_1308.wav, segment:1
# Dataset/Train/ddyo/ddyo_964.wav, segment:1
# Dataset/Train/ddyo/ddyo_132.wav, segment:1
# Dataset/Train/ddyo/ddyo_717.wav, segment:1
# Dataset/Train/ddyo/ddyo_1267.wav, segment:1
# Dataset/Train/ddyo/ddyo_440.wav, segment:1
# Dataset/Train/ddyo/ddyo_331.wav, segment:1
# Dataset/Train/ddyo/ddyo_156.wav, segment:1
# Dataset/Train/ddyo/ddyo_1319.wav, segment:1
# Dataset/Train/ddyo/ddyo_385.wav, segment:1
# Dataset/Train/ddyo/ddyo_218.wav, segment:1
# Dataset/Train/ddyo/ddyo_1539.wav, segment:1
# Dataset/Train/ddyo/ddyo_710.wav, segment:1
# Dataset/Train/ddyo/ddyo_1164.wav, segment:1
# Dataset/Train/ddyo/ddyo_1029.wav, segment:1
# Dataset/Train/ddyo/ddyo_853.wav, segment:1
# Dataset/Train/ddyo/ddyo_052.wav, segment:1
# Dataset/Train/ddyo/ddyo_525.wav, segment:1
# Dataset/Train/ddyo/ddyo_1102.wav, segment:1
# Dataset/Train/ddyo/ddyo_182.wav, segment:1
# Dataset/Train/ddyo/ddyo_1232.wav, segment:1
# Dataset/Train/ddyo/ddyo_1212.wav, segment:1
# Dataset/Train/ddyo/ddyo_891.wav, segment:1
# Dataset/Train/ddyo/ddyo_1069.wav, segment:1
# Dataset/Train/ddyo/ddyo_783.wav, segment:1
# Dataset/Train/ddyo/ddyo_844.wav, segment:1
# Dataset/Train/ddyo/ddyo_1139.wav, segment:1
# Dataset/Train/ddyo/ddyo_1280.wav, segment:1
# Dataset/Train/ddyo/ddyo_522.wav, segment:1
# Dataset/Train/ddyo/ddyo_108.wav, segment:1
# Dataset/Train/ddyo/ddyo_999.wav, segment:1
# Dataset/Train/ddyo/ddyo_1134.wav, segment:1
# Dataset/Train/ddyo/ddyo_137.wav, segment:1
# Dataset/Train/ddyo/ddyo_604.wav, segment:1
# Dataset/Train/ddyo/ddyo_589.wav, segment:1
# Dataset/Train/ddyo/ddyo_1050.wav, segment:1
# Dataset/Train/ddyo/ddyo_1312.wav, segment:1
# Dataset/Train/ddyo/ddyo_1016.wav, segment:1
# Dataset/Train/ddyo/ddyo_1228.wav, segment:1
# Dataset/Train/ddyo/ddyo_1120.wav, segment:1
# Dataset/Train/ddyo/ddyo_650.wav, segment:1
# Dataset/Train/ddyo/ddyo_1349.wav, segment:1
# Dataset/Train/ddyo/ddyo_1155.wav, segment:1
# Dataset/Train/ddyo/ddyo_958.wav, segment:1
# Dataset/Train/ddyo/ddyo_1177.wav, segment:1
# Dataset/Train/ddyo/ddyo_985.wav, segment:1
# Dataset/Train/ddyo/ddyo_771.wav, segment:1
# Dataset/Train/ddyo/ddyo_782.wav, segment:1
# Dataset/Train/ddyo/ddyo_1457.wav, segment:1
# Dataset/Train/ddyo/ddyo_1329.wav, segment:1
# Dataset/Train/ddyo/ddyo_066.wav, segment:1
# Dataset/Train/ddyo/ddyo_1091.wav, segment:1
# Dataset/Train/ddyo/ddyo_1372.wav, segment:1
# Dataset/Train/ddyo/ddyo_531.wav, segment:1
# Dataset/Train/ddyo/ddyo_1334.wav, segment:1
# Dataset/Train/ddyo/ddyo_990.wav, segment:1
# Dataset/Train/ddyo/ddyo_390.wav, segment:1
# Dataset/Train/ddyo/ddyo_1229.wav, segment:1
# Dataset/Train/ddyo/ddyo_902.wav, segment:1
# Dataset/Train/ddyo/ddyo_1015.wav, segment:1
# Dataset/Train/ddyo/ddyo_1110.wav, segment:1
# Dataset/Train/ddyo/ddyo_586.wav, segment:1
# Dataset/Train/ddyo/ddyo_1476.wav, segment:1
# Dataset/Train/ddyo/ddyo_602.wav, segment:1
# Dataset/Train/ddyo/ddyo_036.wav, segment:1
# Dataset/Train/ddyo/ddyo_1404.wav, segment:1
# Dataset/Train/ddyo/ddyo_482.wav, segment:1
# Dataset/Train/ddyo/ddyo_605.wav, segment:1
# Dataset/Train/ddyo/ddyo_718.wav, segment:1
# Dataset/Train/ddyo/ddyo_1095.wav, segment:1
# Dataset/Train/ddyo/ddyo_654.wav, segment:1
# Dataset/Train/ddyo/ddyo_591.wav, segment:1
# Dataset/Train/ddyo/ddyo_297.wav, segment:1
# Dataset/Train/ddyo/ddyo_1218.wav, segment:1
# Dataset/Train/ddyo/ddyo_1213.wav, segment:1
# Dataset/Train/ddyo/ddyo_828.wav, segment:1
# Dataset/Train/ddyo/ddyo_429.wav, segment:1
# Dataset/Train/ddyo/ddyo_115.wav, segment:1
# Dataset/Train/ddyo/ddyo_366.wav, segment:1
# Dataset/Train/ddyo/ddyo_1511.wav, segment:1
# Dataset/Train/ddyo/ddyo_259.wav, segment:1
# Dataset/Train/ddyo/ddyo_1321.wav, segment:1
# Dataset/Train/ddyo/ddyo_1211.wav, segment:1
# Dataset/Train/ddyo/ddyo_404.wav, segment:1
# Dataset/Train/ddyo/ddyo_1527.wav, segment:1
# Dataset/Train/ddyo/ddyo_1025.wav, segment:1
# Dataset/Train/ddyo/ddyo_235.wav, segment:1
# Dataset/Train/ddyo/ddyo_338.wav, segment:1
# Dataset/Train/ddyo/ddyo_1067.wav, segment:1
# Dataset/Train/ddyo/ddyo_641.wav, segment:1
# Dataset/Train/ddyo/ddyo_123.wav, segment:1
# Dataset/Train/ddyo/ddyo_938.wav, segment:1
# Dataset/Train/ddyo/ddyo_1274.wav, segment:1
# Dataset/Train/ddyo/ddyo_511.wav, segment:1
# Dataset/Train/ddyo/ddyo_969.wav, segment:1
# Dataset/Train/ddyo/ddyo_344.wav, segment:1
# Dataset/Train/ddyo/ddyo_1097.wav, segment:1
# Dataset/Train/ddyo/ddyo_1133.wav, segment:1
# Dataset/Train/ddyo/ddyo_1356.wav, segment:1
# Dataset/Train/ddyo/ddyo_1525.wav, segment:1
# Dataset/Train/ddyo/ddyo_1555.wav, segment:1
# Dataset/Train/ddyo/ddyo_551.wav, segment:1
# Dataset/Train/ddyo/ddyo_193.wav, segment:1
# Dataset/Train/ddyo/ddyo_1322.wav, segment:1
# Dataset/Train/ddyo/ddyo_277.wav, segment:1
# Dataset/Train/ddyo/ddyo_621.wav, segment:1
# Dataset/Train/ddyo/ddyo_487.wav, segment:1
# Dataset/Train/ddyo/ddyo_197.wav, segment:1
# Dataset/Train/ddyo/ddyo_560.wav, segment:1
# Dataset/Train/ddyo/ddyo_006.wav, segment:1
# Dataset/Train/ddyo/ddyo_117.wav, segment:1
# Dataset/Train/ddyo/ddyo_1346.wav, segment:1
# Dataset/Train/ddyo/ddyo_1088.wav, segment:1
# Dataset/Train/ddyo/ddyo_1093.wav, segment:1
# Dataset/Train/ddyo/ddyo_058.wav, segment:1
# Dataset/Train/ddyo/ddyo_905.wav, segment:1
# Dataset/Train/ddyo/ddyo_181.wav, segment:1
# Dataset/Train/ddyo/ddyo_045.wav, segment:1
# Dataset/Train/ddyo/ddyo_1230.wav, segment:1
# Dataset/Train/ddyo/ddyo_963.wav, segment:1
# Dataset/Train/ddyo/ddyo_1279.wav, segment:1
# Dataset/Train/ddyo/ddyo_1042.wav, segment:1
# Dataset/Train/ddyo/ddyo_493.wav, segment:1
# Dataset/Train/ddyo/ddyo_792.wav, segment:1
# Dataset/Train/ddyo/ddyo_1350.wav, segment:1
# Dataset/Train/ddyo/ddyo_881.wav, segment:1
# Dataset/Train/ddyo/ddyo_232.wav, segment:1
# Dataset/Train/ddyo/ddyo_762.wav, segment:1
# Dataset/Train/ddyo/ddyo_239.wav, segment:1
# Dataset/Train/ddyo/ddyo_356.wav, segment:1
# Dataset/Train/ddyo/ddyo_1010.wav, segment:1
# Dataset/Train/ddyo/ddyo_183.wav, segment:1
# Dataset/Train/ddyo/ddyo_1173.wav, segment:1
# Dataset/Train/ddyo/ddyo_730.wav, segment:1
# Dataset/Train/ddyo/ddyo_323.wav, segment:1
# Dataset/Train/ddyo/ddyo_1183.wav, segment:1
# Dataset/Train/ddyo/ddyo_1194.wav, segment:1
# Dataset/Train/ddyo/ddyo_228.wav, segment:1
# Dataset/Train/ddyo/ddyo_854.wav, segment:1
# Dataset/Train/ddyo/ddyo_1037.wav, segment:1
# Dataset/Train/ddyo/ddyo_1383.wav, segment:1
# Dataset/Train/ddyo/ddyo_363.wav, segment:1
# Dataset/Train/ddyo/ddyo_091.wav, segment:1
# Dataset/Train/ddyo/ddyo_1307.wav, segment:1
# Dataset/Train/ddyo/ddyo_050.wav, segment:1
# Dataset/Train/ddyo/ddyo_508.wav, segment:1
# Dataset/Train/ddyo/ddyo_389.wav, segment:1
# Dataset/Train/ddyo/ddyo_365.wav, segment:1
# Dataset/Train/ddyo/ddyo_418.wav, segment:1
# Dataset/Train/ddyo/ddyo_899.wav, segment:1
# Dataset/Train/ddyo/ddyo_270.wav, segment:1
# Dataset/Train/ddyo/ddyo_734.wav, segment:1
# Dataset/Train/ddyo/ddyo_695.wav, segment:1
# Dataset/Train/ddyo/ddyo_1209.wav, segment:1
# Dataset/Train/ddyo/ddyo_1259.wav, segment:1
# Dataset/Train/ddyo/ddyo_221.wav, segment:1
# Dataset/Train/ddyo/ddyo_794.wav, segment:1
# Dataset/Train/ddyo/ddyo_010.wav, segment:1
# Dataset/Train/ddyo/ddyo_1317.wav, segment:1
# Dataset/Train/ddyo/ddyo_1222.wav, segment:1
# Dataset/Train/ddyo/ddyo_027.wav, segment:1
# Dataset/Train/ddyo/ddyo_1382.wav, segment:1
# Dataset/Train/ddyo/ddyo_579.wav, segment:1
# Dataset/Train/ddyo/ddyo_732.wav, segment:1
# Dataset/Train/ddyo/ddyo_810.wav, segment:1
# Dataset/Train/ddyo/ddyo_023.wav, segment:1
# Dataset/Train/ddyo/ddyo_1244.wav, segment:1
# Dataset/Train/ddyo/ddyo_153.wav, segment:1
# Dataset/Train/ddyo/ddyo_1497.wav, segment:1
# Dataset/Train/ddyo/ddyo_1532.wav, segment:1
# Dataset/Train/ddyo/ddyo_345.wav, segment:1
# Dataset/Train/ddyo/ddyo_1114.wav, segment:1
# Dataset/Train/ddyo/ddyo_847.wav, segment:1
# Dataset/Train/ddyo/ddyo_047.wav, segment:1
# Dataset/Train/ddyo/ddyo_1305.wav, segment:1
# Dataset/Train/ddyo/ddyo_1197.wav, segment:1
# Dataset/Train/ddyo/ddyo_296.wav, segment:1
# Dataset/Train/ddyo/ddyo_481.wav, segment:1
# Dataset/Train/ddyo/ddyo_041.wav, segment:1
# Dataset/Train/ddyo/ddyo_205.wav, segment:1
# Dataset/Train/ddyo/ddyo_1474.wav, segment:1
# Dataset/Train/ddyo/ddyo_213.wav, segment:1
# Dataset/Train/ddyo/ddyo_1526.wav, segment:1
# Dataset/Train/ddyo/ddyo_1310.wav, segment:1
# Dataset/Train/ddyo/ddyo_1063.wav, segment:1
# Dataset/Train/ddyo/ddyo_1020.wav, segment:1
# Dataset/Train/ddyo/ddyo_1366.wav, segment:1
# Dataset/Train/ddyo/ddyo_890.wav, segment:1
# Dataset/Train/ddyo/ddyo_1294.wav, segment:1
# Dataset/Train/ddyo/ddyo_1367.wav, segment:1
# Dataset/Train/ddyo/ddyo_075.wav, segment:1
# Dataset/Train/ddyo/ddyo_1030.wav, segment:1
# Dataset/Train/ddyo/ddyo_916.wav, segment:1
# Dataset/Train/ddyo/ddyo_1503.wav, segment:1
# Dataset/Train/ddyo/ddyo_1480.wav, segment:1
# Dataset/Train/ddyo/ddyo_1174.wav, segment:1
# Dataset/Train/ddyo/ddyo_736.wav, segment:1
# Dataset/Train/ddyo/ddyo_700.wav, segment:1
# Dataset/Train/ddyo/ddyo_393.wav, segment:1
# Dataset/Train/ddyo/ddyo_1303.wav, segment:1
# Dataset/Train/ddyo/ddyo_484.wav, segment:1
# Dataset/Train/ddyo/ddyo_1171.wav, segment:1
# Dataset/Train/ddyo/ddyo_1054.wav, segment:1
# Dataset/Train/ddyo/ddyo_1507.wav, segment:1
# Dataset/Train/ddyo/ddyo_110.wav, segment:1
# Dataset/Train/ddyo/ddyo_624.wav, segment:1
# Dataset/Train/ddyo/ddyo_003.wav, segment:1
# Dataset/Train/ddyo/ddyo_475.wav, segment:1
# Dataset/Train/ddyo/ddyo_478.wav, segment:1
# Dataset/Train/ddyo/ddyo_1486.wav, segment:1
# Dataset/Train/ddyo/ddyo_1141.wav, segment:1
# Dataset/Train/ddyo/ddyo_895.wav, segment:1
# Dataset/Train/ddyo/ddyo_986.wav, segment:1
# Dataset/Train/ddyo/ddyo_1381.wav, segment:1
# Dataset/Train/ddyo/ddyo_509.wav, segment:1
# Dataset/Train/ddyo/ddyo_1472.wav, segment:1
# Dataset/Train/ddyo/ddyo_757.wav, segment:1
# Dataset/Train/ddyo/ddyo_1429.wav, segment:1
# Dataset/Train/ddyo/ddyo_925.wav, segment:1
# Dataset/Train/ddyo/ddyo_1047.wav, segment:1
# Dataset/Train/ddyo/ddyo_051.wav, segment:1
# Dataset/Train/ddyo/ddyo_1543.wav, segment:1
# Dataset/Train/ddyo/ddyo_1064.wav, segment:1
# Dataset/Train/ddyo/ddyo_162.wav, segment:1
# Dataset/Train/ddyo/ddyo_1206.wav, segment:1
# Dataset/Train/ddyo/ddyo_1019.wav, segment:1
# Dataset/Train/ddyo/ddyo_1458.wav, segment:1
# Dataset/Train/ddyo/ddyo_343.wav, segment:1
# Dataset/Train/ddyo/ddyo_858.wav, segment:1
# Dataset/Train/ddyo/ddyo_715.wav, segment:1
# Dataset/Train/ddyo/ddyo_649.wav, segment:1
# Dataset/Train/ddyo/ddyo_016.wav, segment:1
# Dataset/Train/ddyo/ddyo_682.wav, segment:1
# Dataset/Train/ddyo/ddyo_374.wav, segment:1
# Dataset/Train/ddyo/ddyo_870.wav, segment:1
# Dataset/Train/ddyo/ddyo_265.wav, segment:1
# Dataset/Train/ddyo/ddyo_1238.wav, segment:1
# Dataset/Train/ddyo/ddyo_685.wav, segment:1
# Dataset/Train/ddyo/ddyo_1315.wav, segment:1
# Dataset/Train/ddyo/ddyo_1121.wav, segment:1
# Dataset/Train/ddyo/ddyo_617.wav, segment:1
# Dataset/Train/ddyo/ddyo_1247.wav, segment:1
# Dataset/Train/ddyo/ddyo_1550.wav, segment:1
# Dataset/Train/ddyo/ddyo_1414.wav, segment:1
# Dataset/Train/ddyo/ddyo_1493.wav, segment:1
# Dataset/Train/ddyo/ddyo_982.wav, segment:1
# Dataset/Train/ddyo/ddyo_1376.wav, segment:1
# Dataset/Train/ddyo/ddyo_210.wav, segment:1
# Dataset/Train/ddyo/ddyo_348.wav, segment:1
# Dataset/Train/ddyo/ddyo_034.wav, segment:1
# Dataset/Train/ddyo/ddyo_1066.wav, segment:1
# Dataset/Train/ddyo/ddyo_349.wav, segment:1
# Dataset/Train/ddyo/ddyo_1024.wav, segment:1
# Dataset/Train/ddyo/ddyo_030.wav, segment:1
# Dataset/Train/ddyo/ddyo_742.wav, segment:1
# Dataset/Train/ddyo/ddyo_566.wav, segment:1
# Dataset/Train/ddyo/ddyo_548.wav, segment:1
# Dataset/Train/ddyo/ddyo_917.wav, segment:1
# Dataset/Train/ddyo/ddyo_852.wav, segment:1
# Dataset/Train/ddyo/ddyo_1135.wav, segment:1
# Dataset/Train/ddyo/ddyo_1463.wav, segment:1
# Dataset/Train/ddyo/ddyo_637.wav, segment:1
# Dataset/Train/ddyo/ddyo_601.wav, segment:1
# Dataset/Train/ddyo/ddyo_1398.wav, segment:1
# Dataset/Train/ddyo/ddyo_594.wav, segment:1
# Dataset/Train/ddyo/ddyo_587.wav, segment:1
# Dataset/Train/ddyo/ddyo_1328.wav, segment:1
# Dataset/Train/ddyo/ddyo_121.wav, segment:1
# Dataset/Train/ddyo/ddyo_119.wav, segment:1
# Dataset/Train/ddyo/ddyo_394.wav, segment:1
# Dataset/Train/ddyo/ddyo_1358.wav, segment:1
# Dataset/Train/ddyo/ddyo_817.wav, segment:1
# Dataset/Train/ddyo/ddyo_878.wav, segment:1
# Dataset/Train/ddyo/ddyo_1013.wav, segment:1
# Dataset/Train/ddyo/ddyo_092.wav, segment:1
# Dataset/Train/ddyo/ddyo_078.wav, segment:1
# Dataset/Train/ddyo/ddyo_064.wav, segment:1
# Dataset/Train/ddyo/ddyo_709.wav, segment:1
# Dataset/Train/ddyo/ddyo_837.wav, segment:1
# Dataset/Train/ddyo/ddyo_415.wav, segment:1
# Dataset/Train/ddyo/ddyo_1251.wav, segment:1
# Dataset/Train/ddyo/ddyo_1000.wav, segment:1
# Dataset/Train/ddyo/ddyo_008.wav, segment:1
# Dataset/Train/ddyo/ddyo_688.wav, segment:1
# Dataset/Train/ddyo/ddyo_071.wav, segment:1
# Dataset/Train/ddyo/ddyo_784.wav, segment:1
# Dataset/Train/ddyo/ddyo_1369.wav, segment:1
# Dataset/Train/ddyo/ddyo_945.wav, segment:1
# Dataset/Train/ddyo/ddyo_1342.wav, segment:1
# Dataset/Train/ddyo/ddyo_410.wav, segment:1
# Dataset/Train/ddyo/ddyo_278.wav, segment:1
# Dataset/Train/ddyo/ddyo_1437.wav, segment:1
# Dataset/Train/ddyo/ddyo_192.wav, segment:1
# Dataset/Train/ddyo/ddyo_505.wav, segment:1
# Dataset/Train/ddyo/ddyo_247.wav, segment:1
# Dataset/Train/ddyo/ddyo_912.wav, segment:1
# Dataset/Train/ddyo/ddyo_1053.wav, segment:1
# Dataset/Train/ddyo/ddyo_419.wav, segment:1
# Dataset/Train/ddyo/ddyo_261.wav, segment:1
# Dataset/Train/ddyo/ddyo_1330.wav, segment:1
# Dataset/Train/ddyo/ddyo_085.wav, segment:1
# Dataset/Train/ddyo/ddyo_1420.wav, segment:1
# Dataset/Train/ddyo/ddyo_576.wav, segment:1
# Dataset/Train/ddyo/ddyo_287.wav, segment:1
# Dataset/Train/ddyo/ddyo_062.wav, segment:1
# Dataset/Train/ddyo/ddyo_107.wav, segment:1
# Dataset/Train/ddyo/ddyo_1165.wav, segment:1
# Dataset/Train/ddyo/ddyo_500.wav, segment:1
# Dataset/Train/ddyo/ddyo_059.wav, segment:1
# Dataset/Train/ddyo/ddyo_759.wav, segment:1
# Dataset/Train/ddyo/ddyo_1390.wav, segment:1
# Dataset/Train/ddyo/ddyo_1162.wav, segment:1
# Dataset/Train/ddyo/ddyo_726.wav, segment:1
# Dataset/Train/ddyo/ddyo_569.wav, segment:1
# Dataset/Train/ddyo/ddyo_664.wav, segment:1
# Dataset/Train/ddyo/ddyo_779.wav, segment:1
# Dataset/Train/ddyo/ddyo_992.wav, segment:1
# Dataset/Train/ddyo/ddyo_669.wav, segment:1
# Dataset/Train/ddyo/ddyo_170.wav, segment:1
# Dataset/Train/ddyo/ddyo_1534.wav, segment:1
# Dataset/Train/ddyo/ddyo_074.wav, segment:1
# Dataset/Train/ddyo/ddyo_620.wav, segment:1
# Dataset/Train/ddyo/ddyo_728.wav, segment:1
# Dataset/Train/ddyo/ddyo_923.wav, segment:1
# Dataset/Train/ddyo/ddyo_1417.wav, segment:1
# Dataset/Train/ddyo/ddyo_1169.wav, segment:1
# Dataset/Train/ddyo/ddyo_818.wav, segment:1
# Dataset/Train/ddyo/ddyo_163.wav, segment:1
# Dataset/Train/ddyo/ddyo_088.wav, segment:1
# Dataset/Train/ddyo/ddyo_516.wav, segment:1
# Dataset/Train/ddyo/ddyo_1424.wav, segment:1
# Dataset/Train/ddyo/ddyo_1239.wav, segment:1
# Dataset/Train/ddyo/ddyo_1080.wav, segment:1
# Dataset/Train/ddyo/ddyo_1357.wav, segment:1
# Dataset/Train/ddyo/ddyo_1340.wav, segment:1
# Dataset/Train/ddyo/ddyo_217.wav, segment:1
# Dataset/Train/ddyo/ddyo_321.wav, segment:1
# Dataset/Train/ddyo/ddyo_1478.wav, segment:1
# Dataset/Train/ddyo/ddyo_175.wav, segment:1
# Dataset/Train/ddyo/ddyo_1439.wav, segment:1
# Dataset/Train/ddyo/ddyo_315.wav, segment:1
# Dataset/Train/ddyo/ddyo_883.wav, segment:1
# Dataset/Train/ddyo/ddyo_1494.wav, segment:1
# Dataset/Train/ddyo/ddyo_701.wav, segment:1
# Dataset/Train/ddyo/ddyo_1234.wav, segment:1
# Dataset/Train/ddyo/ddyo_1161.wav, segment:1
# Dataset/Train/ddyo/ddyo_644.wav, segment:1
# Dataset/Train/ddyo/ddyo_1055.wav, segment:1
# Dataset/Train/ddyo/ddyo_1201.wav, segment:1
# Dataset/Train/ddyo/ddyo_960.wav, segment:1
# Dataset/Train/ddyo/ddyo_322.wav, segment:1
# Dataset/Train/ddyo/ddyo_1556.wav, segment:1
# Dataset/Train/ddyo/ddyo_396.wav, segment:1
# Dataset/Train/ddyo/ddyo_1374.wav, segment:1
# Dataset/Train/ddyo/ddyo_1296.wav, segment:1
# Dataset/Train/ddyo/ddyo_1378.wav, segment:1
# Dataset/Train/ddyo/ddyo_994.wav, segment:1
# Dataset/Train/ddyo/ddyo_894.wav, segment:1
# Dataset/Train/ddyo/ddyo_1006.wav, segment:1
# Dataset/Train/ddyo/ddyo_1421.wav, segment:1
# Dataset/Train/ddyo/ddyo_1273.wav, segment:1
# Dataset/Train/ddyo/ddyo_1039.wav, segment:1
# Dataset/Train/ddyo/ddyo_1175.wav, segment:1
# Dataset/Train/ddyo/ddyo_799.wav, segment:1
# Dataset/Train/ddyo/ddyo_1271.wav, segment:1
# Dataset/Train/ddyo/ddyo_910.wav, segment:1
# Dataset/Train/ddyo/ddyo_666.wav, segment:1
# Dataset/Train/ddyo/ddyo_1265.wav, segment:1
# Dataset/Train/ddyo/ddyo_090.wav, segment:1
# Dataset/Train/ddyo/ddyo_988.wav, segment:1
# Dataset/Train/ddyo/ddyo_790.wav, segment:1
# Dataset/Train/ddyo/ddyo_609.wav, segment:1
# Dataset/Train/ddyo/ddyo_506.wav, segment:1
# Dataset/Train/ddyo/ddyo_743.wav, segment:1
# Dataset/Train/ddyo/ddyo_820.wav, segment:1
# Dataset/Train/ddyo/ddyo_670.wav, segment:1
# Dataset/Train/ddyo/ddyo_1221.wav, segment:1
# Dataset/Train/ddyo/ddyo_1246.wav, segment:1
# Dataset/Train/ddyo/ddyo_069.wav, segment:1
# Dataset/Train/ddyo/ddyo_1495.wav, segment:1
# Dataset/Train/ddyo/ddyo_1270.wav, segment:1
# Dataset/Train/ddyo/ddyo_711.wav, segment:1
# Dataset/Train/ddyo/ddyo_1140.wav, segment:1
# Dataset/Train/ddyo/ddyo_1535.wav, segment:1
# Dataset/Train/ddyo/ddyo_011.wav, segment:1
# Dataset/Train/ddyo/ddyo_856.wav, segment:1
# Dataset/Train/ddyo/ddyo_731.wav, segment:1
# Dataset/Train/ddyo/ddyo_1018.wav, segment:1
# Dataset/Train/ddyo/ddyo_1261.wav, segment:1
# Dataset/Train/ddyo/ddyo_1219.wav, segment:1
# Dataset/Train/ddyo/ddyo_271.wav, segment:1
# Dataset/Train/ddyo/ddyo_1563.wav, segment:1
# Dataset/Train/ddyo/ddyo_1081.wav, segment:1
# Dataset/Train/ddyo/ddyo_1467.wav, segment:1
# Dataset/Train/ddyo/ddyo_1260.wav, segment:1
# Dataset/Train/ddyo/ddyo_941.wav, segment:1
# Dataset/Train/ddyo/ddyo_1453.wav, segment:1
# Dataset/Train/ddyo/ddyo_177.wav, segment:1
# Dataset/Train/ddyo/ddyo_1115.wav, segment:1
# Dataset/Train/ddyo/ddyo_582.wav, segment:1
# Dataset/Train/ddyo/ddyo_1009.wav, segment:1
# Dataset/Train/ddyo/ddyo_1500.wav, segment:1
# Dataset/Train/ddyo/ddyo_1392.wav, segment:1
# Dataset/Train/ddyo/ddyo_1190.wav, segment:1
# Dataset/Train/ddyo/ddyo_645.wav, segment:1
# Dataset/Train/ddyo/ddyo_1026.wav, segment:1
# Dataset/Train/ddyo/ddyo_357.wav, segment:1
# Dataset/Train/ddyo/ddyo_948.wav, segment:1
# Dataset/Train/ddyo/ddyo_979.wav, segment:1
# Dataset/Train/ddyo/ddyo_755.wav, segment:1
# Dataset/Train/ddyo/ddyo_1057.wav, segment:1
# Dataset/Train/ddyo/ddyo_1370.wav, segment:1
# Dataset/Train/ddyo/ddyo_915.wav, segment:1
# Dataset/Train/ddyo/ddyo_004.wav, segment:1
# Dataset/Train/ddyo/ddyo_1311.wav, segment:1
# Dataset/Train/ddyo/ddyo_1150.wav, segment:1
# Dataset/Train/ddyo/ddyo_292.wav, segment:1
# Dataset/Train/ddyo/ddyo_312.wav, segment:1
# Dataset/Train/ddyo/ddyo_147.wav, segment:1
# Dataset/Train/ddyo/ddyo_1136.wav, segment:1
# Dataset/Train/ddyo/ddyo_1502.wav, segment:1
# Dataset/Train/ddyo/ddyo_276.wav, segment:1
# Dataset/Train/ddyo/ddyo_770.wav, segment:1
# Dataset/Train/ddyo/ddyo_845.wav, segment:1
# Dataset/Train/ddyo/ddyo_702.wav, segment:1
# Dataset/Train/ddyo/ddyo_1275.wav, segment:1
# Dataset/Train/ddyo/ddyo_165.wav, segment:1
# Dataset/Train/ddyo/ddyo_187.wav, segment:1
# Dataset/Train/ddyo/ddyo_180.wav, segment:1
# Dataset/Train/ddyo/ddyo_1405.wav, segment:1
# Dataset/Train/ddyo/ddyo_1561.wav, segment:1
# Dataset/Train/ddyo/ddyo_198.wav, segment:1
# Dataset/Train/ddyo/ddyo_1553.wav, segment:1
# Dataset/Train/ddyo/ddyo_530.wav, segment:1
# Dataset/Train/ddyo/ddyo_150.wav, segment:1
# Dataset/Train/ddyo/ddyo_1233.wav, segment:1
# Dataset/Train/ddyo/ddyo_1299.wav, segment:1
# Dataset/Train/ddyo/ddyo_336.wav, segment:1
# Dataset/Train/ddyo/ddyo_1105.wav, segment:1
# Dataset/Train/ddyo/ddyo_962.wav, segment:1
# Dataset/Train/ddyo/ddyo_774.wav, segment:1
# Dataset/Train/ddyo/ddyo_236.wav, segment:1
# Dataset/Train/ddyo/ddyo_1434.wav, segment:1
# Dataset/Train/ddyo/ddyo_570.wav, segment:1
# Dataset/Train/ddyo/ddyo_285.wav, segment:1
# Dataset/Train/ddyo/ddyo_333.wav, segment:1
# Dataset/Train/ddyo/ddyo_1452.wav, segment:1
# Dataset/Train/ddyo/ddyo_880.wav, segment:1
# Dataset/Train/ddyo/ddyo_1393.wav, segment:1
# Dataset/Train/ddyo/ddyo_1513.wav, segment:1
# Dataset/Train/ddyo/ddyo_311.wav, segment:1
# Dataset/Train/ddyo/ddyo_1298.wav, segment:1
# Dataset/Train/ddyo/ddyo_172.wav, segment:1
# Dataset/Train/ddyo/ddyo_383.wav, segment:1
# Dataset/Train/ddyo/ddyo_865.wav, segment:1
# Dataset/Train/ddyo/ddyo_174.wav, segment:1
# Dataset/Train/ddyo/ddyo_227.wav, segment:1
# Dataset/Train/ddyo/ddyo_655.wav, segment:1
# Dataset/Train/ddyo/ddyo_248.wav, segment:1
# Dataset/Train/ddyo/ddyo_758.wav, segment:1
# Dataset/Train/ddyo/ddyo_1499.wav, segment:1
# Dataset/Train/ddyo/ddyo_541.wav, segment:1
# Dataset/Train/ddyo/ddyo_1235.wav, segment:1
# Dataset/Train/ddyo/ddyo_1388.wav, segment:1
# Dataset/Train/ddyo/ddyo_305.wav, segment:1
# Dataset/Train/ddyo/ddyo_351.wav, segment:1
# Dataset/Train/ddyo/ddyo_126.wav, segment:1
# Dataset/Train/ddyo/ddyo_350.wav, segment:1
# Dataset/Train/ddyo/ddyo_464.wav, segment:1
# Dataset/Train/ddyo/ddyo_029.wav, segment:1
# Dataset/Train/ddyo/ddyo_1415.wav, segment:1
# Dataset/Train/ddyo/ddyo_1554.wav, segment:1
# Dataset/Train/ddyo/ddyo_689.wav, segment:1
# Dataset/Train/ddyo/ddyo_696.wav, segment:1
# Dataset/Train/ddyo/ddyo_1466.wav, segment:1
# Dataset/Train/ddyo/ddyo_690.wav, segment:1
# Dataset/Train/ddyo/ddyo_1454.wav, segment:1
# Dataset/Train/ddyo/ddyo_465.wav, segment:1
# Dataset/Train/ddyo/ddyo_1483.wav, segment:1
# Dataset/Train/ddyo/ddyo_152.wav, segment:1
# Dataset/Train/ddyo/ddyo_1103.wav, segment:1
# Dataset/Train/ddyo/ddyo_433.wav, segment:1
# Dataset/Train/ddyo/ddyo_888.wav, segment:1
# Dataset/Train/ddyo/ddyo_211.wav, segment:1
# Dataset/Train/ddyo/ddyo_533.wav, segment:1
# Dataset/Train/ddyo/ddyo_1517.wav, segment:1
# Dataset/Train/ddyo/ddyo_904.wav, segment:1
# Dataset/Train/ddyo/ddyo_1509.wav, segment:1
# Dataset/Train/ddyo/ddyo_377.wav, segment:1
# Dataset/Train/ddyo/ddyo_298.wav, segment:1
# Dataset/Train/ddyo/ddyo_1086.wav, segment:1
# Dataset/Train/ddyo/ddyo_1354.wav, segment:1
# Dataset/Train/ddyo/ddyo_319.wav, segment:1
# Dataset/Train/ddyo/ddyo_752.wav, segment:1
# Dataset/Train/ddyo/ddyo_942.wav, segment:1
# Dataset/Train/ddyo/ddyo_545.wav, segment:1
# Dataset/Train/ddyo/ddyo_279.wav, segment:1
# Dataset/Train/ddyo/ddyo_577.wav, segment:1
# Dataset/Train/ddyo/ddyo_723.wav, segment:1
# Dataset/Train/ddyo/ddyo_638.wav, segment:1
# Dataset/Train/ddyo/ddyo_1101.wav, segment:1
# Dataset/Train/ddyo/ddyo_1344.wav, segment:1
# Dataset/Train/ddyo/ddyo_524.wav, segment:1
# Dataset/Train/ddyo/ddyo_469.wav, segment:1
# Dataset/Train/ddyo/ddyo_1269.wav, segment:1
# Dataset/Train/ddyo/ddyo_623.wav, segment:1
# Dataset/Train/ddyo/ddyo_674.wav, segment:1
# Dataset/Train/ddyo/ddyo_639.wav, segment:1
# Dataset/Train/ddyo/ddyo_831.wav, segment:1
# Dataset/Train/ddyo/ddyo_691.wav, segment:1
# Dataset/Train/ddyo/ddyo_827.wav, segment:1
# Dataset/Train/ddyo/ddyo_1435.wav, segment:1
# Dataset/Train/ddyo/ddyo_116.wav, segment:1
# Dataset/Train/ddyo/ddyo_1491.wav, segment:1
# Dataset/Train/ddyo/ddyo_838.wav, segment:1
# Dataset/Train/ddyo/ddyo_224.wav, segment:1
# Dataset/Train/ddyo/ddyo_155.wav, segment:1
# Dataset/Train/ddyo/ddyo_1565.wav, segment:1
# Dataset/Train/ddyo/ddyo_249.wav, segment:1
# Dataset/Train/ddyo/ddyo_502.wav, segment:1
# Dataset/Train/ddyo/ddyo_781.wav, segment:1
# Dataset/Train/ddyo/ddyo_920.wav, segment:1
# Dataset/Train/ddyo/ddyo_628.wav, segment:1
# Dataset/Train/ddyo/ddyo_568.wav, segment:1
# Dataset/Train/ddyo/ddyo_098.wav, segment:1
# Dataset/Train/ddyo/ddyo_347.wav, segment:1
# Dataset/Train/ddyo/ddyo_1210.wav, segment:1
# Dataset/Train/ddyo/ddyo_1451.wav, segment:1
# Dataset/Train/ddyo/ddyo_705.wav, segment:1
# Dataset/Train/ddyo/ddyo_1557.wav, segment:1
# Dataset/Train/ddyo/ddyo_082.wav, segment:1
# Dataset/Train/ddyo/ddyo_989.wav, segment:1
# Dataset/Train/ddyo/ddyo_054.wav, segment:1
# Dataset/Train/ddyo/ddyo_454.wav, segment:1
# Dataset/Train/ddyo/ddyo_1479.wav, segment:1
# Dataset/Train/ddyo/ddyo_161.wav, segment:1
# Dataset/Train/ddyo/ddyo_1406.wav, segment:1
# Dataset/Train/ddyo/ddyo_653.wav, segment:1
# Dataset/Train/ddyo/ddyo_1061.wav, segment:1
# Dataset/Train/ddyo/ddyo_746.wav, segment:1
# Dataset/Train/ddyo/ddyo_1243.wav, segment:1
# Dataset/Train/ddyo/ddyo_1192.wav, segment:1
# Dataset/Train/ddyo/ddyo_614.wav, segment:1
# Dataset/Train/ddyo/ddyo_129.wav, segment:1
# Dataset/Train/ddyo/ddyo_804.wav, segment:1
# Dataset/Train/ddyo/ddyo_788.wav, segment:1
# Dataset/Train/ddyo/ddyo_1570.wav, segment:1
# Dataset/Train/ddyo/ddyo_719.wav, segment:1
# Dataset/Train/ddyo/ddyo_906.wav, segment:1
# Dataset/Train/ddyo/ddyo_444.wav, segment:1
# Dataset/Train/ddyo/ddyo_1546.wav, segment:1
# Dataset/Train/ddyo/ddyo_761.wav, segment:1
# Dataset/Train/ddyo/ddyo_495.wav, segment:1
# Dataset/Train/ddyo/ddyo_738.wav, segment:1
# Dataset/Train/ddyo/ddyo_886.wav, segment:1
# Dataset/Train/ddyo/ddyo_095.wav, segment:1
# Dataset/Train/ddyo/ddyo_1062.wav, segment:1
# Dataset/Train/ddyo/ddyo_1046.wav, segment:1
# Dataset/Train/ddyo/ddyo_372.wav, segment:1
# Dataset/Train/ddyo/ddyo_671.wav, segment:1
# Dataset/Train/ddyo/ddyo_080.wav, segment:1
# Dataset/Train/ddyo/ddyo_077.wav, segment:1
# Dataset/Train/ddyo/ddyo_529.wav, segment:1
# Dataset/Train/ddyo/ddyo_1207.wav, segment:1
# Dataset/Train/ddyo/ddyo_380.wav, segment:1
# Dataset/Train/ddyo/ddyo_313.wav, segment:1
# Dataset/Train/ddyo/ddyo_1058.wav, segment:1
# Dataset/Train/ddyo/ddyo_032.wav, segment:1
# Dataset/Train/ddyo/ddyo_1320.wav, segment:1
# Dataset/Train/ddyo/ddyo_965.wav, segment:1
# Dataset/Train/ddyo/ddyo_544.wav, segment:1
# Dataset/Train/ddyo/ddyo_922.wav, segment:1
# Dataset/Train/ddyo/ddyo_1331.wav, segment:1
# Dataset/Train/ddyo/ddyo_517.wav, segment:1
# Dataset/Train/ddyo/ddyo_1409.wav, segment:1
# Dataset/Train/ddyo/ddyo_093.wav, segment:1
# Dataset/Train/ddyo/ddyo_212.wav, segment:1
# Dataset/Train/ddyo/ddyo_1125.wav, segment:1
# Dataset/Train/ddyo/ddyo_504.wav, segment:1
# Dataset/Train/ddyo/ddyo_1096.wav, segment:1
# Dataset/Train/ddyo/ddyo_417.wav, segment:1
# Dataset/Train/ddyo/ddyo_1371.wav, segment:1
# Dataset/Train/ddyo/ddyo_720.wav, segment:1
# Dataset/Train/ddyo/ddyo_1468.wav, segment:1
# Dataset/Train/ddyo/ddyo_864.wav, segment:1
# Dataset/Train/ddyo/ddyo_243.wav, segment:1
# Dataset/Train/ddyo/ddyo_663.wav, segment:1
# Dataset/Train/ddyo/ddyo_428.wav, segment:1
# Dataset/Train/ddyo/ddyo_836.wav, segment:1
# Dataset/Train/ddyo/ddyo_993.wav, segment:1
# Dataset/Train/ddyo/ddyo_1035.wav, segment:1
# Dataset/Train/ddyo/ddyo_1130.wav, segment:1
# Dataset/Train/ddyo/ddyo_1109.wav, segment:1
# Dataset/Train/ddyo/ddyo_665.wav, segment:1
# Dataset/Train/ddyo/ddyo_1400.wav, segment:1
# Dataset/Train/ddyo/ddyo_903.wav, segment:1
# Dataset/Train/ddyo/ddyo_1447.wav, segment:1
# Dataset/Train/ddyo/ddyo_583.wav, segment:1
# Dataset/Train/ddyo/ddyo_1208.wav, segment:1
# Dataset/Train/ddyo/ddyo_458.wav, segment:1
# Dataset/Train/ddyo/ddyo_974.wav, segment:1
# Dataset/Train/ddyo/ddyo_778.wav, segment:1
# Dataset/Train/ddyo/ddyo_519.wav, segment:1
# Dataset/Train/ddyo/ddyo_512.wav, segment:1
# Dataset/Train/ddyo/ddyo_1332.wav, segment:1
# Dataset/Train/ddyo/ddyo_149.wav, segment:1
# Dataset/Train/ddyo/ddyo_1108.wav, segment:1
# Dataset/Train/ddyo/ddyo_807.wav, segment:1
# Dataset/Train/ddyo/ddyo_622.wav, segment:1
# Dataset/Train/ddyo/ddyo_414.wav, segment:1
# Dataset/Train/ddyo/ddyo_1252.wav, segment:1
# Dataset/Train/ddyo/ddyo_1223.wav, segment:1
# Dataset/Train/ddyo/ddyo_1353.wav, segment:1
# Dataset/Train/ddyo/ddyo_048.wav, segment:1
# Dataset/Train/ddyo/ddyo_1205.wav, segment:1
# Dataset/Train/ddyo/ddyo_441.wav, segment:1
# Dataset/Train/ddyo/ddyo_929.wav, segment:1
# Dataset/Train/ddyo/ddyo_1123.wav, segment:1
# Dataset/Train/ddyo/ddyo_812.wav, segment:1
# Dataset/Train/ddyo/ddyo_1248.wav, segment:1
# Dataset/Train/ddyo/ddyo_882.wav, segment:1
# Dataset/Train/ddyo/ddyo_382.wav, segment:1
# Dataset/Train/ddyo/ddyo_168.wav, segment:1
# Dataset/Train/ddyo/ddyo_1335.wav, segment:1
# Dataset/Train/ddyo/ddyo_1263.wav, segment:1
# Dataset/Train/ddyo/ddyo_141.wav, segment:1
# Dataset/Train/ddyo/ddyo_142.wav, segment:1
# Dataset/Train/ddyo/ddyo_1396.wav, segment:1
# Dataset/Train/ddyo/ddyo_1352.wav, segment:1
# Dataset/Train/ddyo/ddyo_1068.wav, segment:1
# Dataset/Train/ddyo/ddyo_302.wav, segment:1
# Dataset/Train/ddyo/ddyo_241.wav, segment:1
# Dataset/Train/ddyo/ddyo_947.wav, segment:1
# Dataset/Train/ddyo/ddyo_957.wav, segment:1
# Dataset/Train/ddyo/ddyo_946.wav, segment:1
# Dataset/Train/ddyo/ddyo_395.wav, segment:1
# Dataset/Train/ddyo/ddyo_1460.wav, segment:1
# Dataset/Train/ddyo/ddyo_869.wav, segment:1
# Dataset/Train/ddyo/ddyo_160.wav, segment:1
# Dataset/Train/ddyo/ddyo_1365.wav, segment:1
# Dataset/Train/ddyo/ddyo_1056.wav, segment:1
# Dataset/Train/ddyo/ddyo_1032.wav, segment:1
# Dataset/Train/ddyo/ddyo_559.wav, segment:1
# Dataset/Train/ddyo/ddyo_1428.wav, segment:1
# Dataset/Train/ddyo/ddyo_403.wav, segment:1
# Dataset/Train/ddyo/ddyo_520.wav, segment:1
# Dataset/Train/ddyo/ddyo_1051.wav, segment:1
# Dataset/Train/ddyo/ddyo_980.wav, segment:1
# Dataset/Train/ddyo/ddyo_230.wav, segment:1
# Dataset/Train/ddyo/ddyo_978.wav, segment:1
# Dataset/Train/ddyo/ddyo_244.wav, segment:1
# Dataset/Train/ddyo/ddyo_353.wav, segment:1
# Dataset/Train/ddyo/ddyo_154.wav, segment:1
# Dataset/Train/ddyo/ddyo_120.wav, segment:1
# Dataset/Train/ddyo/ddyo_618.wav, segment:1
# Dataset/Train/ddyo/ddyo_1425.wav, segment:1
# Dataset/Train/ddyo/ddyo_1542.wav, segment:1
# Dataset/Train/ddyo/ddyo_981.wav, segment:1
# Dataset/Train/ddyo/ddyo_918.wav, segment:1
# Dataset/Train/ddyo/ddyo_756.wav, segment:1
# Dataset/Train/ddyo/ddyo_263.wav, segment:1
# Dataset/Train/ddyo/ddyo_1038.wav, segment:1
# Dataset/Train/ddyo/ddyo_1172.wav, segment:1
# Dataset/Train/ddyo/ddyo_872.wav, segment:1
# Dataset/Train/ddyo/ddyo_595.wav, segment:1
# Dataset/Train/ddyo/ddyo_1182.wav, segment:1
# Dataset/Train/ddyo/ddyo_503.wav, segment:1
# Dataset/Train/ddyo/ddyo_708.wav, segment:1
# Dataset/Train/ddyo/ddyo_1122.wav, segment:1
# Dataset/Train/ddyo/ddyo_1512.wav, segment:1
# Dataset/Train/ddyo/ddyo_499.wav, segment:1
# Dataset/Train/ddyo/ddyo_592.wav, segment:1
# Dataset/Train/ddyo/ddyo_483.wav, segment:1
# Dataset/Train/ddyo/ddyo_191.wav, segment:1
# Dataset/Train/ddyo/ddyo_229.wav, segment:1
# Dataset/Train/ddyo/ddyo_005.wav, segment:1
# Dataset/Train/ddyo/ddyo_630.wav, segment:1
# Dataset/Train/ddyo/ddyo_1082.wav, segment:1
# Dataset/Train/ddyo/ddyo_1253.wav, segment:1
# Dataset/Train/ddyo/ddyo_273.wav, segment:1
# Dataset/Train/ddyo/ddyo_1385.wav, segment:1
# Dataset/Train/ddyo/ddyo_1002.wav, segment:1
# Dataset/Train/ddyo/ddyo_826.wav, segment:1
# Dataset/Train/ddyo/ddyo_1090.wav, segment:1
# Dataset/Train/ddyo/ddyo_766.wav, segment:1
# Dataset/Train/ddyo/ddyo_1104.wav, segment:1
# Dataset/Train/ddyo/ddyo_1516.wav, segment:1
# Dataset/Train/ddyo/ddyo_737.wav, segment:1
# Dataset/Train/ddyo/ddyo_1281.wav, segment:1
# Dataset/Train/ddyo/ddyo_815.wav, segment:1
# Dataset/Train/ddyo/ddyo_327.wav, segment:1
# Dataset/Train/ddyo/ddyo_1482.wav, segment:1
# Dataset/Train/ddyo/ddyo_1292.wav, segment:1
# Dataset/Train/ddyo/ddyo_426.wav, segment:1
# Dataset/Train/ddyo/ddyo_1214.wav, segment:1
# Dataset/Train/ddyo/ddyo_787.wav, segment:1
# Dataset/Train/ddyo/ddyo_1413.wav, segment:1
# Dataset/Train/ddyo/ddyo_189.wav, segment:1
# Dataset/Train/ddyo/ddyo_490.wav, segment:1
# Dataset/Train/ddyo/ddyo_282.wav, segment:1
# Dataset/Train/ddyo/ddyo_1394.wav, segment:1
# Dataset/Train/ddyo/ddyo_1266.wav, segment:1
# Dataset/Train/ddyo/ddyo_1309.wav, segment:1
# Dataset/Train/ddyo/ddyo_242.wav, segment:1
# Dataset/Train/ddyo/ddyo_1515.wav, segment:1
# Dataset/Train/ddyo/ddyo_558.wav, segment:1
# Dataset/Train/ddyo/ddyo_507.wav, segment:1
# Dataset/Train/ddyo/ddyo_927.wav, segment:1
# Dataset/Train/ddyo/ddyo_330.wav, segment:1
# Dataset/Train/ddyo/ddyo_909.wav, segment:1
# Dataset/Train/ddyo/ddyo_863.wav, segment:1
# Dataset/Train/ddyo/ddyo_474.wav, segment:1
# Dataset/Train/ddyo/ddyo_1012.wav, segment:1
# Dataset/Train/ddyo/ddyo_747.wav, segment:1
# Dataset/Train/ddyo/ddyo_1551.wav, segment:1
# Dataset/Train/ddyo/ddyo_951.wav, segment:1
# Dataset/Train/ddyo/ddyo_1178.wav, segment:1
# Dataset/Train/ddyo/ddyo_987.wav, segment:1
# Dataset/Train/ddyo/ddyo_1514.wav, segment:1
# Dataset/Train/ddyo/ddyo_713.wav, segment:1
# Dataset/Train/ddyo/ddyo_1145.wav, segment:1
# Dataset/Train/ddyo/ddyo_1548.wav, segment:1
# Dataset/Train/ddyo/ddyo_1163.wav, segment:1
# Dataset/Train/ddyo/ddyo_1034.wav, segment:1
# Dataset/Train/ddyo/ddyo_371.wav, segment:1
# Dataset/Train/ddyo/ddyo_106.wav, segment:1
# Dataset/Train/ddyo/ddyo_408.wav, segment:1
# Dataset/Train/ddyo/ddyo_896.wav, segment:1
# Dataset/Train/ddyo/ddyo_897.wav, segment:1
# Dataset/Train/ddyo/ddyo_1127.wav, segment:1
# Dataset/Train/ddyo/ddyo_851.wav, segment:1
# Dataset/Train/ddyo/ddyo_860.wav, segment:1
# Dataset/Train/ddyo/ddyo_1202.wav, segment:1
# Dataset/Train/ddyo/ddyo_1272.wav, segment:1
# Dataset/Train/ddyo/ddyo_046.wav, segment:1
# Dataset/Train/ddyo/ddyo_921.wav, segment:1
# Dataset/Train/ddyo/ddyo_369.wav, segment:1
# Dataset/Train/ddyo/ddyo_136.wav, segment:1
# Dataset/Train/ddyo/ddyo_535.wav, segment:1
# Dataset/Train/ddyo/ddyo_898.wav, segment:1
# Dataset/Train/ddyo/ddyo_1498.wav, segment:1
# Dataset/Train/ddyo/ddyo_434.wav, segment:1
# Dataset/Train/ddyo/ddyo_1427.wav, segment:1
# Dataset/Train/ddyo/ddyo_1167.wav, segment:1
# Dataset/Train/ddyo/ddyo_849.wav, segment:1
# Dataset/Train/ddyo/ddyo_219.wav, segment:1
# Dataset/Train/ddyo/ddyo_673.wav, segment:1
# Dataset/Train/ddyo/ddyo_332.wav, segment:1
# Dataset/Train/ddyo/ddyo_627.wav, segment:1
# Dataset/Train/ddyo/ddyo_749.wav, segment:1
# Dataset/Train/ddyo/ddyo_1159.wav, segment:1
# Dataset/Train/ddyo/ddyo_169.wav, segment:1
# Dataset/Train/ddyo/ddyo_477.wav, segment:1
# Dataset/Train/ddyo/ddyo_253.wav, segment:1
# Dataset/Train/ddyo/ddyo_1375.wav, segment:1
# Dataset/Train/ddyo/ddyo_1533.wav, segment:1
# Dataset/Train/ddyo/ddyo_703.wav, segment:1
# Dataset/Train/ddyo/ddyo_1359.wav, segment:1
# Dataset/Train/ddyo/ddyo_318.wav, segment:1
# Dataset/Train/ddyo/ddyo_097.wav, segment:1
# Dataset/Train/ddyo/ddyo_777.wav, segment:1
# Dataset/Train/ddyo/ddyo_954.wav, segment:1
# Dataset/Train/ddyo/ddyo_245.wav, segment:1
# Dataset/Train/ddyo/ddyo_1505.wav, segment:1
# Dataset/Train/ddyo/ddyo_1241.wav, segment:1
# Dataset/Train/ddyo/ddyo_216.wav, segment:1
# Dataset/Train/ddyo/ddyo_201.wav, segment:1
# Dataset/Train/ddyo/ddyo_061.wav, segment:1
# Dataset/Train/ddyo/ddyo_1118.wav, segment:1
# Dataset/Train/ddyo/ddyo_364.wav, segment:1
# Dataset/Train/ddyo/ddyo_800.wav, segment:1
# Dataset/Train/ddyo/ddyo_733.wav, segment:1
# Dataset/Train/ddyo/ddyo_334.wav, segment:1
# Dataset/Train/ddyo/ddyo_463.wav, segment:1
# Dataset/Train/ddyo/ddyo_1185.wav, segment:1
# Dataset/Train/ddyo/ddyo_367.wav, segment:1
# Dataset/Train/ddyo/ddyo_683.wav, segment:1
# Dataset/Train/ddyo/ddyo_084.wav, segment:1
# Dataset/Train/ddyo/ddyo_1117.wav, segment:1
# Dataset/Train/ddyo/ddyo_721.wav, segment:1
# Dataset/Train/ddyo/ddyo_035.wav, segment:1
# Dataset/Train/ddyo/ddyo_635.wav, segment:1
# Dataset/Train/ddyo/ddyo_785.wav, segment:1
# Dataset/Train/ddyo/ddyo_359.wav, segment:1
# Dataset/Train/ddyo/ddyo_975.wav, segment:1
# Dataset/Train/ddyo/ddyo_1284.wav, segment:1
# Dataset/Train/ddyo/ddyo_1043.wav, segment:1
# Dataset/Train/ddyo/ddyo_684.wav, segment:1
# Dataset/Train/ddyo/ddyo_1060.wav, segment:1
# Dataset/Train/ddyo/ddyo_571.wav, segment:1
# Dataset/Train/ddyo/ddyo_694.wav, segment:1
# Dataset/Train/ddyo/ddyo_1285.wav, segment:1
# Dataset/Train/ddyo/ddyo_317.wav, segment:1
# Dataset/Train/ddyo/ddyo_1519.wav, segment:1
# Dataset/Train/ddyo/ddyo_874.wav, segment:1
# Dataset/Train/ddyo/ddyo_1410.wav, segment:1
# Dataset/Train/ddyo/ddyo_1436.wav, segment:1
# Dataset/Train/ddyo/ddyo_1017.wav, segment:1
# Dataset/Train/ddyo/ddyo_1225.wav, segment:1
# Dataset/Train/ddyo/ddyo_514.wav, segment:1
# Dataset/Train/ddyo/ddyo_675.wav, segment:1
# Dataset/Train/ddyo/ddyo_1475.wav, segment:1
# Dataset/Train/ddyo/ddyo_437.wav, segment:1
# Dataset/Train/ddyo/ddyo_471.wav, segment:1
# Dataset/Train/ddyo/ddyo_1079.wav, segment:1
# Dataset/Train/ddyo/ddyo_824.wav, segment:1
# Dataset/Train/ddyo/ddyo_867.wav, segment:1
# Dataset/Train/ddyo/ddyo_320.wav, segment:1
# Dataset/Train/ddyo/ddyo_488.wav, segment:1
# Dataset/Train/ddyo/ddyo_258.wav, segment:1
# Dataset/Train/ddyo/ddyo_1113.wav, segment:1
# Dataset/Train/ddyo/ddyo_1137.wav, segment:1
# Dataset/Train/ddyo/ddyo_494.wav, segment:1
# Dataset/Train/ddyo/ddyo_1446.wav, segment:1
# Dataset/Train/ddyo/ddyo_1471.wav, segment:1
# Dataset/Train/ddyo/ddyo_1059.wav, segment:1
# Dataset/Train/ddyo/ddyo_452.wav, segment:1
# Dataset/Train/ddyo/ddyo_875.wav, segment:1
# Dataset/Train/ddyo/ddyo_681.wav, segment:1
# Dataset/Train/ddyo/ddyo_397.wav, segment:1
# Dataset/Train/ddyo/ddyo_139.wav, segment:1
# Dataset/Train/ddyo/ddyo_538.wav, segment:1
# Dataset/Train/ddyo/ddyo_599.wav, segment:1
# Dataset/Train/ddyo/ddyo_1361.wav, segment:1
# Dataset/Train/ddyo/ddyo_821.wav, segment:1
# Dataset/Train/ddyo/ddyo_977.wav, segment:1
# Dataset/Train/ddyo/ddyo_686.wav, segment:1
# Dataset/Train/ddyo/ddyo_1227.wav, segment:1
# Dataset/Train/ddyo/ddyo_255.wav, segment:1
# Dataset/Train/ddyo/ddyo_1277.wav, segment:1
# Dataset/Train/ddyo/ddyo_431.wav, segment:1
# Dataset/Train/ddyo/ddyo_435.wav, segment:1
# Dataset/Train/ddyo/ddyo_1504.wav, segment:1
# Dataset/Train/ddyo/ddyo_949.wav, segment:1
# Dataset/Train/ddyo/ddyo_729.wav, segment:1
# Dataset/Train/ddyo/ddyo_125.wav, segment:1
# Dataset/Train/ddyo/ddyo_468.wav, segment:1
# Dataset/Train/ddyo/ddyo_908.wav, segment:1
# Dataset/Train/ddyo/ddyo_658.wav, segment:1
# Dataset/Train/ddyo/ddyo_1338.wav, segment:1
# Dataset/Train/ddyo/ddyo_932.wav, segment:1
# Dataset/Train/ddyo/ddyo_392.wav, segment:1
# Dataset/Train/ddyo/ddyo_796.wav, segment:1
# Dataset/Train/ddyo/ddyo_1112.wav, segment:1
# Dataset/Train/ddyo/ddyo_151.wav, segment:1
# Dataset/Train/ddyo/ddyo_448.wav, segment:1
# Dataset/Train/ddyo/ddyo_1351.wav, segment:1
# Dataset/Train/ddyo/ddyo_399.wav, segment:1
# Dataset/Train/ddyo/ddyo_547.wav, segment:1
# Dataset/Train/ddyo/ddyo_983.wav, segment:1
# Dataset/Train/ddyo/ddyo_597.wav, segment:1
# Dataset/Train/ddyo/ddyo_436.wav, segment:1
# Dataset/Train/ddyo/ddyo_937.wav, segment:1
# Dataset/Train/ddyo/ddyo_606.wav, segment:1
# Dataset/Train/ddyo/ddyo_220.wav, segment:1
# Dataset/Train/ddyo/ddyo_931.wav, segment:1
# Dataset/Train/ddyo/ddyo_809.wav, segment:1
# Dataset/Train/ddyo/ddyo_829.wav, segment:1
# Dataset/Train/ddyo/ddyo_1044.wav, segment:1
# Dataset/Train/ddyo/ddyo_1031.wav, segment:1
# Dataset/Train/ddyo/ddyo_823.wav, segment:1
# Dataset/Train/ddyo/ddyo_1477.wav, segment:1
# Dataset/Train/ddyo/ddyo_600.wav, segment:1
# Dataset/Train/ddyo/ddyo_967.wav, segment:1
# Dataset/Train/ddyo/ddyo_185.wav, segment:1
# Dataset/Train/ddyo/ddyo_667.wav, segment:1
# Dataset/Train/ddyo/ddyo_1355.wav, segment:1
# Dataset/Train/ddyo/ddyo_1085.wav, segment:1
# Dataset/Train/ddyo/ddyo_972.wav, segment:1
# Dataset/Train/ddyo/ddyo_450.wav, segment:1
# Dataset/Train/ddyo/ddyo_1347.wav, segment:1
# Dataset/Train/ddyo/ddyo_753.wav, segment:1
# Dataset/Train/ddyo/ddyo_1168.wav, segment:1
# Dataset/Train/ddyo/ddyo_1336.wav, segment:1
# Dataset/Train/ddyo/ddyo_808.wav, segment:1
# Dataset/Train/ddyo/ddyo_676.wav, segment:1
# Dataset/Train/ddyo/ddyo_1049.wav, segment:1
# Dataset/Train/ddyo/ddyo_1075.wav, segment:1
# Dataset/Train/ddyo/ddyo_1379.wav, segment:1
# Dataset/Train/ddyo/ddyo_811.wav, segment:1
# Dataset/Train/ddyo/ddyo_114.wav, segment:1
# Dataset/Train/ddyo/ddyo_1027.wav, segment:1
# Dataset/Train/ddyo/ddyo_998.wav, segment:1
# Dataset/Train/ddyo/ddyo_1007.wav, segment:1
# Dataset/Train/ddyo/ddyo_300.wav, segment:1
# Dataset/Train/ddyo/ddyo_1399.wav, segment:1
# Dataset/Train/ddyo/ddyo_358.wav, segment:1
# Dataset/Train/ddyo/ddyo_340.wav, segment:1
# Dataset/Train/ddyo/ddyo_1540.wav, segment:1
# Dataset/Train/ddyo/ddyo_613.wav, segment:1
# Dataset/Train/ddyo/ddyo_063.wav, segment:1
# Dataset/Train/ddyo/ddyo_086.wav, segment:1
# Dataset/Train/ddyo/ddyo_714.wav, segment:1
# Dataset/Train/ddyo/ddyo_574.wav, segment:1
# Dataset/Train/ddyo/ddyo_725.wav, segment:1
# Dataset/Train/ddyo/ddyo_1001.wav, segment:1
# Dataset/Train/ddyo/ddyo_554.wav, segment:1
# Dataset/Train/ddyo/ddyo_1562.wav, segment:1
# Dataset/Train/ddyo/ddyo_552.wav, segment:1
# Dataset/Train/ddyo/ddyo_928.wav, segment:1
# Dataset/Train/ddyo/ddyo_009.wav, segment:1
# Dataset/Train/ddyo/ddyo_515.wav, segment:1
# Dataset/Train/ddyo/ddyo_398.wav, segment:1
# Dataset/Train/ddyo/ddyo_1107.wav, segment:1
# Dataset/Train/ddyo/ddyo_1151.wav, segment:1
# Dataset/Train/ddyo/ddyo_1041.wav, segment:1
# Dataset/Train/ddyo/ddyo_610.wav, segment:1
# Dataset/Train/ddyo/ddyo_1438.wav, segment:1
# Dataset/Train/ddyo/ddyo_754.wav, segment:1
# Dataset/Train/ddyo/ddyo_1286.wav, segment:1
# Dataset/Train/ddyo/ddyo_1180.wav, segment:1
# Dataset/Train/ddyo/ddyo_930.wav, segment:1
# Dataset/Train/ddyo/ddyo_518.wav, segment:1
# Dataset/Train/ddyo/ddyo_057.wav, segment:1
# Dataset/Train/ddyo/ddyo_901.wav, segment:1
# Dataset/Train/ddyo/ddyo_950.wav, segment:1
# Dataset/Train/ddyo/ddyo_580.wav, segment:1
# Dataset/Train/ddyo/ddyo_1465.wav, segment:1
# Dataset/Train/ddyo/ddyo_497.wav, segment:1
# Dataset/Train/ddyo/ddyo_1076.wav, segment:1
# Dataset/Train/ddyo/ddyo_021.wav, segment:1
# Dataset/Train/ddyo/ddyo_1545.wav, segment:1
# Dataset/Train/ddyo/ddyo_268.wav, segment:1
# Dataset/Train/ddyo/ddyo_445.wav, segment:1
# Dataset/Train/ddyo/ddyo_472.wav, segment:1
# Dataset/Train/ddyo/ddyo_830.wav, segment:1
# Dataset/Train/ddyo/ddyo_286.wav, segment:1
# Dataset/Train/ddyo/ddyo_456.wav, segment:1
# Dataset/Train/ddyo/ddyo_1231.wav, segment:1
# Dataset/Train/ddyo/ddyo_1411.wav, segment:1
# Dataset/Train/ddyo/ddyo_567.wav, segment:1
# Dataset/Train/ddyo/ddyo_871.wav, segment:1
# Dataset/Train/ddyo/ddyo_1401.wav, segment:1
# Dataset/Train/ddyo/ddyo_190.wav, segment:1
# Dataset/Train/ddyo/ddyo_314.wav, segment:1
# Dataset/Train/ddyo/ddyo_262.wav, segment:1
# Dataset/Train/ddyo/ddyo_877.wav, segment:1
# Dataset/Train/ddyo/ddyo_542.wav, segment:1
# Dataset/Train/ddyo/ddyo_293.wav, segment:1
# Dataset/Train/ddyo/ddyo_1099.wav, segment:1
# Dataset/Train/ddyo/ddyo_575.wav, segment:1
# Dataset/Train/ddyo/ddyo_443.wav, segment:1
# Dataset/Train/ddyo/ddyo_1430.wav, segment:1
# Dataset/Train/ddyo/ddyo_636.wav, segment:1
# Dataset/Train/ddyo/ddyo_1343.wav, segment:1
# Dataset/Train/ddyo/ddyo_179.wav, segment:1
# Dataset/Train/ddyo/ddyo_534.wav, segment:1
# Dataset/Train/ddyo/ddyo_1524.wav, segment:1
# Dataset/Train/ddyo/ddyo_633.wav, segment:1
# Dataset/Train/ddyo/ddyo_1283.wav, segment:1
# Dataset/Train/ddyo/ddyo_446.wav, segment:1
# Dataset/Train/ddyo/ddyo_1003.wav, segment:1
# Dataset/Train/ddyo/ddyo_1028.wav, segment:1
# Dataset/Train/ddyo/ddyo_835.wav, segment:1
# Dataset/Train/ddyo/ddyo_199.wav, segment:1
# Dataset/Train/ddyo/ddyo_769.wav, segment:1
# Dataset/Train/ddyo/ddyo_1156.wav, segment:1
# Dataset/Train/ddyo/ddyo_750.wav, segment:1
# Dataset/Train/ddyo/ddyo_384.wav, segment:1
# Dataset/Train/ddyo/ddyo_555.wav, segment:1
# Dataset/Train/ddyo/ddyo_1184.wav, segment:1
# Dataset/Train/ddyo/ddyo_789.wav, segment:1
# Dataset/Train/ddyo/ddyo_596.wav, segment:1
# Dataset/Train/ddyo/ddyo_186.wav, segment:1
# Dataset/Train/ddyo/ddyo_1242.wav, segment:1
# Dataset/Train/ddyo/ddyo_540.wav, segment:1
# Dataset/Train/ddyo/ddyo_798.wav, segment:1
# Dataset/Train/ddyo/ddyo_209.wav, segment:1
# Dataset/Train/ddyo/ddyo_528.wav, segment:1
# Dataset/Train/ddyo/ddyo_498.wav, segment:1
# Dataset/Train/ddyo/ddyo_1048.wav, segment:1
# Dataset/Train/ddyo/ddyo_1402.wav, segment:1
# Dataset/Train/ddyo/ddyo_099.wav, segment:1
# Dataset/Train/ddyo/ddyo_1092.wav, segment:1
# Dataset/Train/ddyo/ddyo_089.wav, segment:1
# Dataset/Train/ddyo/ddyo_226.wav, segment:1
# Dataset/Train/ddyo/ddyo_933.wav, segment:1
# Dataset/Train/ddyo/ddyo_668.wav, segment:1
# Dataset/Train/ddyo/ddyo_1254.wav, segment:1
# Dataset/Train/ddyo/ddyo_328.wav, segment:1
# Dataset/Train/ddyo/ddyo_608.wav, segment:1
# Dataset/Train/ddyo/ddyo_855.wav, segment:1
# Dataset/Train/ddyo/ddyo_968.wav, segment:1
# Dataset/Train/ddyo/ddyo_067.wav, segment:1
# Dataset/Train/ddyo/ddyo_822.wav, segment:1
# Dataset/Train/ddyo/ddyo_699.wav, segment:1
# Dataset/Train/ddyo/ddyo_442.wav, segment:1
# Dataset/Train/ddyo/ddyo_1217.wav, segment:1
# Dataset/Train/ddyo/ddyo_884.wav, segment:1
# Dataset/Train/ddyo/ddyo_765.wav, segment:1
# Dataset/Train/ddyo/ddyo_1083.wav, segment:1
# Dataset/Train/ddyo/ddyo_816.wav, segment:1
# Dataset/Train/ddyo/ddyo_1496.wav, segment:1
# ...
# Dataset/Test/yimirira/yimirira_223.wav, segment:1
# Dataset/Test/yimirira/yimirira_159.wav, segment:1
# Dataset/Test/yimirira/yimirira_101.wav, segment:1
# Dataset/Test/yimirira/yimirira_319.wav, segment:1
# Dataset/Test/yimirira/yimirira_199.wav, segment:1
# Dataset/Test/yimirira/yimirira_062.wav, segment:1
# Dataset/Test/yimirira/yimirira_166.wav, segment:1
# Dataset/Test/yimirira/yimirira_365.wav, segment:1
# Dataset/Test/yimirira/yimirira_088.wav, segment:1
# Dataset/Test/yimirira/yimirira_053.wav, segment:1
# Dataset/Test/yimirira/yimirira_383.wav, segment:1
# Dataset/Test/yimirira/yimirira_186.wav, segment:1
# Dataset/Test/yimirira/yimirira_016.wav, segment:1
# Dataset/Test/yimirira/yimirira_433.wav, segment:1
# Dataset/Test/yimirira/yimirira_058.wav, segment:1
# Dataset/Test/yimirira/yimirira_423.wav, segment:1
# Dataset/Test/yimirira/yimirira_020.wav, segment:1
# Dataset/Test/yimirira/yimirira_029.wav, segment:1
# Dataset/Test/yimirira/yimirira_333.wav, segment:1
# Dataset/Test/yimirira/yimirira_343.wav, segment:1
# Dataset/Test/yimirira/yimirira_409.wav, segment:1
# Dataset/Test/yimirira/yimirira_338.wav, segment:1
# Dataset/Test/yimirira/yimirira_393.wav, segment:1
# Dataset/Test/yimirira/yimirira_114.wav, segment:1
# Dataset/Test/yimirira/yimirira_235.wav, segment:1
# Dataset/Test/yimirira/yimirira_356.wav, segment:1
# Dataset/Test/yimirira/yimirira_126.wav, segment:1
# Dataset/Test/yimirira/yimirira_239.wav, segment:1
# Dataset/Test/yimirira/yimirira_202.wav, segment:1
# Dataset/Test/yimirira/yimirira_384.wav, segment:1
# Dataset/Test/yimirira/yimirira_219.wav, segment:1
# Dataset/Test/yimirira/yimirira_181.wav, segment:1
# Dataset/Test/yimirira/yimirira_425.wav, segment:1
# Dataset/Test/yimirira/yimirira_359.wav, segment:1
# Dataset/Test/yimirira/yimirira_247.wav, segment:1
# Dataset/Test/yimirira/yimirira_093.wav, segment:1
# Dataset/Test/yimirira/yimirira_315.wav, segment:1
# Dataset/Test/yimirira/yimirira_293.wav, segment:1
# Dataset/Test/yimirira/yimirira_214.wav, segment:1
# Dataset/Test/yimirira/yimirira_230.wav, segment:1
# Dataset/Test/yimirira/yimirira_191.wav, segment:1
# Dataset/Test/yimirira/yimirira_339.wav, segment:1
# Dataset/Test/yimirira/yimirira_205.wav, segment:1
# Dataset/Test/yimirira/yimirira_299.wav, segment:1
# Dataset/Test/yimirira/yimirira_264.wav, segment:1
# Dataset/Test/yimirira/yimirira_148.wav, segment:1
# Dataset/Test/yimirira/yimirira_156.wav, segment:1
# Dataset/Test/yimirira/yimirira_204.wav, segment:1
# Dataset/Test/yimirira/yimirira_335.wav, segment:1
# Dataset/Test/yimirira/yimirira_137.wav, segment:1
# Dataset/Test/yimirira/yimirira_036.wav, segment:1
# Dataset/Test/yimirira/yimirira_323.wav, segment:1
# Dataset/Test/yimirira/yimirira_375.wav, segment:1
# Dataset/Test/yimirira/yimirira_262.wav, segment:1
# Dataset/Test/yimirira/yimirira_194.wav, segment:1
# Dataset/Test/yimirira/yimirira_269.wav, segment:1
# Dataset/Test/yimirira/yimirira_035.wav, segment:1
# Dataset/Test/yimirira/yimirira_301.wav, segment:1
# Dataset/Test/yimirira/yimirira_290.wav, segment:1
# Dataset/Test/yimirira/yimirira_213.wav, segment:1
# Dataset/Test/yimirira/yimirira_184.wav, segment:1
# Dataset/Test/yimirira/yimirira_431.wav, segment:1
# Dataset/Test/yimirira/yimirira_192.wav, segment:1
# Dataset/Test/yimirira/yimirira_059.wav, segment:1
# Dataset/Test/yimirira/yimirira_347.wav, segment:1
# Dataset/Test/yimirira/yimirira_327.wav, segment:1
# Dataset/Test/yimirira/yimirira_060.wav, segment:1
# Dataset/Test/yimirira/yimirira_250.wav, segment:1
# Dataset/Test/yimirira/yimirira_222.wav, segment:1
# Dataset/Test/yimirira/yimirira_258.wav, segment:1
# Dataset/Test/yimirira/yimirira_188.wav, segment:1
# Dataset/Test/yimirira/yimirira_119.wav, segment:1
# Dataset/Test/yimirira/yimirira_174.wav, segment:1
# Dataset/Test/yimirira/yimirira_203.wav, segment:1
# Dataset/Test/yimirira/yimirira_014.wav, segment:1
# Dataset/Test/yimirira/yimirira_195.wav, segment:1
# Dataset/Test/yimirira/yimirira_389.wav, segment:1
# Dataset/Test/yimirira/yimirira_248.wav, segment:1
# Dataset/Test/yimirira/yimirira_083.wav, segment:1
# Dataset/Test/yimirira/yimirira_041.wav, segment:1
# Dataset/Test/yimirira/yimirira_325.wav, segment:1
# Dataset/Test/yimirira/yimirira_402.wav, segment:1
# Dataset/Test/yimirira/yimirira_334.wav, segment:1
# Dataset/Test/yimirira/yimirira_094.wav, segment:1
# Dataset/Test/yimirira/yimirira_373.wav, segment:1
# Dataset/Test/yimirira/yimirira_311.wav, segment:1
# Dataset/Test/yimirira/yimirira_401.wav, segment:1
# Dataset/Test/yimirira/yimirira_132.wav, segment:1
# Dataset/Test/yimirira/yimirira_169.wav, segment:1
# Dataset/Test/yimirira/yimirira_133.wav, segment:1
# Dataset/Test/yimirira/yimirira_143.wav, segment:1
# Dataset/Test/yimirira/yimirira_371.wav, segment:1
# Dataset/Test/yimirira/yimirira_276.wav, segment:1
# Dataset/Test/yimirira/yimirira_151.wav, segment:1
# Dataset/Test/yimirira/yimirira_027.wav, segment:1
# Dataset/Test/yimirira/yimirira_178.wav, segment:1
# Dataset/Test/yimirira/yimirira_103.wav, segment:1
# Dataset/Test/yimirira/yimirira_028.wav, segment:1
# Dataset/Test/yimirira/yimirira_106.wav, segment:1
# Dataset/Test/yimirira/yimirira_165.wav, segment:1
# Dataset/Test/yimirira/yimirira_417.wav, segment:1
# Dataset/Test/yimirira/yimirira_021.wav, segment:1
# Dataset/Test/yimirira/yimirira_140.wav, segment:1
# Dataset/Test/yimirira/yimirira_117.wav, segment:1
# Dataset/Test/yimirira/yimirira_207.wav, segment:1
# Dataset/Test/yimirira/yimirira_318.wav, segment:1
# Dataset/Test/yimirira/yimirira_180.wav, segment:1
# Dataset/Test/yimirira/yimirira_370.wav, segment:1
# Dataset/Test/yimirira/yimirira_145.wav, segment:1
# Dataset/Test/yimirira/yimirira_257.wav, segment:1
# Dataset/Test/yimirira/yimirira_071.wav, segment:1
# Dataset/Test/yimirira/yimirira_187.wav, segment:1
# Dataset/Test/yimirira/yimirira_122.wav, segment:1
# Dataset/Test/yimirira/yimirira_056.wav, segment:1
# Dataset/Test/yimirira/yimirira_275.wav, segment:1
# Dataset/Test/yimirira/yimirira_089.wav, segment:1
# Dataset/Test/yimirira/yimirira_387.wav, segment:1
# Dataset/Test/yimirira/yimirira_206.wav, segment:1
# Dataset/Test/yimirira/yimirira_006.wav, segment:1
# Dataset/Test/yimirira/yimirira_255.wav, segment:1
# Dataset/Test/yimirira/yimirira_360.wav, segment:1
# Dataset/Test/yimirira/yimirira_070.wav, segment:1
# Dataset/Test/yimirira/yimirira_298.wav, segment:1
# Dataset/Test/yimirira/yimirira_362.wav, segment:1
# Dataset/Test/yimirira/yimirira_350.wav, segment:1
# Dataset/Test/yimirira/yimirira_361.wav, segment:1
# Dataset/Test/yimirira/yimirira_120.wav, segment:1
# Dataset/Test/yimirira/yimirira_430.wav, segment:1
# Dataset/Test/yimirira/yimirira_292.wav, segment:1
# Dataset/Test/yimirira/yimirira_260.wav, segment:1
# Dataset/Test/yimirira/yimirira_428.wav, segment:1
# Dataset/Test/yimirira/yimirira_009.wav, segment:1
# Dataset/Test/yimirira/yimirira_051.wav, segment:1
# Dataset/Test/yimirira/yimirira_265.wav, segment:1
# Dataset/Test/yimirira/yimirira_017.wav, segment:1
# Dataset/Test/yimirira/yimirira_245.wav, segment:1
# Dataset/Test/yimirira/yimirira_210.wav, segment:1
# Dataset/Test/yimirira/yimirira_422.wav, segment:1
# Dataset/Test/yimirira/yimirira_090.wav, segment:1
# Dataset/Test/yimirira/yimirira_003.wav, segment:1
# Dataset/Test/yimirira/yimirira_069.wav, segment:1
# Dataset/Test/yimirira/yimirira_252.wav, segment:1
# Dataset/Test/yimirira/yimirira_287.wav, segment:1
# Dataset/Test/yimirira/yimirira_392.wav, segment:1
# Dataset/Test/yimirira/yimirira_231.wav, segment:1
# Dataset/Test/yimirira/yimirira_336.wav, segment:1
# Dataset/Test/yimirira/yimirira_037.wav, segment:1
# Dataset/Test/yimirira/yimirira_369.wav, segment:1
# Dataset/Test/yimirira/yimirira_314.wav, segment:1
# Dataset/Test/yimirira/yimirira_023.wav, segment:1
# Dataset/Test/yimirira/yimirira_158.wav, segment:1
# Dataset/Test/yimirira/yimirira_424.wav, segment:1
# Dataset/Test/yimirira/yimirira_218.wav, segment:1
# Dataset/Test/yimirira/yimirira_305.wav, segment:1
# Dataset/Test/yimirira/yimirira_355.wav, segment:1
# Dataset/Test/yimirira/yimirira_183.wav, segment:1
# Dataset/Test/yimirira/yimirira_403.wav, segment:1
# Dataset/Test/yimirira/yimirira_092.wav, segment:1
# Dataset/Test/yimirira/yimirira_102.wav, segment:1
# Dataset/Test/yimirira/yimirira_045.wav, segment:1
# Dataset/Test/yimirira/yimirira_011.wav, segment:1
# Dataset/Test/yimirira/yimirira_297.wav, segment:1
# Dataset/Test/yimirira/yimirira_405.wav, segment:1
# Dataset/Test/yimirira/yimirira_224.wav, segment:1
# Dataset/Test/yimirira/yimirira_080.wav, segment:1
# Dataset/Test/yimirira/yimirira_281.wav, segment:1
# Dataset/Test/yimirira/yimirira_176.wav, segment:1
# Dataset/Test/yimirira/yimirira_068.wav, segment:1
# Dataset/Test/yimirira/yimirira_118.wav, segment:1
# Dataset/Test/yimirira/yimirira_421.wav, segment:1
# Dataset/Test/yimirira/yimirira_416.wav, segment:1
# Dataset/Test/yimirira/yimirira_357.wav, segment:1
# Dataset/Test/yimirira/yimirira_326.wav, segment:1
# Dataset/Test/yimirira/yimirira_229.wav, segment:1
# Dataset/Test/yimirira/yimirira_026.wav, segment:1
# Dataset/Test/yimirira/yimirira_173.wav, segment:1
# Dataset/Test/yimirira/yimirira_330.wav, segment:1
# Dataset/Test/yimirira/yimirira_354.wav, segment:1
# Dataset/Test/yimirira/yimirira_107.wav, segment:1
# Dataset/Test/yimirira/yimirira_304.wav, segment:1
# Dataset/Test/yimirira/yimirira_144.wav, segment:1
# Dataset/Test/yimirira/yimirira_279.wav, segment:1
# Dataset/Test/yimirira/yimirira_147.wav, segment:1
# Dataset/Test/yimirira/yimirira_426.wav, segment:1
# Dataset/Test/yimirira/yimirira_413.wav, segment:1
# Dataset/Test/yimirira/yimirira_082.wav, segment:1
# Dataset/Test/yimirira/yimirira_099.wav, segment:1
# Dataset/Test/yimirira/yimirira_130.wav, segment:1
# Dataset/Test/yimirira/yimirira_201.wav, segment:1
# Dataset/Test/yimirira/yimirira_225.wav, segment:1
# Dataset/Test/yimirira/yimirira_177.wav, segment:1
# Dataset/Test/yimirira/yimirira_396.wav, segment:1
# Dataset/Test/yimirira/yimirira_300.wav, segment:1
# Dataset/Test/yimirira/yimirira_057.wav, segment:1
# Dataset/Test/yimirira/yimirira_303.wav, segment:1
# Dataset/Test/yimirira/yimirira_138.wav, segment:1
# Dataset/Test/yimirira/yimirira_391.wav, segment:1
# Dataset/Test/yimirira/yimirira_236.wav, segment:1
# Dataset/Test/yimirira/yimirira_162.wav, segment:1
# Dataset/Test/yimirira/yimirira_135.wav, segment:1
# Dataset/Test/yimirira/yimirira_152.wav, segment:1
# Dataset/Test/yimirira/yimirira_254.wav, segment:1
# Dataset/Test/yimirira/yimirira_171.wav, segment:1
# Dataset/Test/yimirira/yimirira_112.wav, segment:1
# Dataset/Test/yimirira/yimirira_341.wav, segment:1
# Dataset/Test/yimirira/yimirira_251.wav, segment:1
# Dataset/Test/yimirira/yimirira_038.wav, segment:1
# Dataset/Test/yimirira/yimirira_216.wav, segment:1
# Dataset/Test/yimirira/yimirira_351.wav, segment:1
# Dataset/Test/yimirira/yimirira_172.wav, segment:1
# Dataset/Test/yimirira/yimirira_378.wav, segment:1
# Dataset/Test/yimirira/yimirira_429.wav, segment:1
# Dataset/Test/yimirira/yimirira_004.wav, segment:1
# Dataset/Test/yimirira/yimirira_113.wav, segment:1
# Dataset/Test/yimirira/yimirira_084.wav, segment:1
# Dataset/Test/yimirira/yimirira_277.wav, segment:1
# Dataset/Test/yimirira/yimirira_353.wav, segment:1
# Dataset/Test/yimirira/yimirira_295.wav, segment:1
# Dataset/Test/yimirira/yimirira_237.wav, segment:1
# Dataset/Test/yimirira/yimirira_400.wav, segment:1
# Dataset/Test/yimirira/yimirira_015.wav, segment:1
# Dataset/Test/yimirira/yimirira_238.wav, segment:1
# Dataset/Test/yimirira/yimirira_367.wav, segment:1
# Dataset/Test/yimirira/yimirira_067.wav, segment:1
# Dataset/Test/yimirira/yimirira_034.wav, segment:1
# Dataset/Test/yimirira/yimirira_160.wav, segment:1
# Dataset/Test/yimirira/yimirira_087.wav, segment:1
# Dataset/Test/yimirira/yimirira_352.wav, segment:1
# Dataset/Test/yimirira/yimirira_073.wav, segment:1
# Dataset/Test/yimirira/yimirira_123.wav, segment:1
# Dataset/Test/yimirira/yimirira_234.wav, segment:1
# Dataset/Test/yimirira/yimirira_104.wav, segment:1
# Dataset/Test/yimirira/yimirira_271.wav, segment:1
# Dataset/Test/yimirira/yimirira_001.wav, segment:1
# Dataset/Test/yimirira/yimirira_215.wav, segment:1
# Dataset/Test/yimirira/yimirira_296.wav, segment:1
# Dataset/Test/yimirira/yimirira_244.wav, segment:1
# Dataset/Test/yimirira/yimirira_289.wav, segment:1
# Dataset/Test/yimirira/yimirira_414.wav, segment:1
# Dataset/Test/yimirira/yimirira_346.wav, segment:1
# Dataset/Test/yimirira/yimirira_420.wav, segment:1
# Dataset/Test/yimirira/yimirira_142.wav, segment:1
# Dataset/Test/yimirira/yimirira_381.wav, segment:1
# Dataset/Test/yimirira/yimirira_046.wav, segment:1
# Dataset/Test/yimirira/yimirira_397.wav, segment:1
# Dataset/Test/yimirira/yimirira_047.wav, segment:1
# Dataset/Test/yimirira/yimirira_374.wav, segment:1
# Dataset/Test/yimirira/yimirira_376.wav, segment:1
# Dataset/Test/yimirira/yimirira_328.wav, segment:1
# Dataset/Test/yimirira/yimirira_313.wav, segment:1
# Dataset/Test/yimirira/yimirira_307.wav, segment:1
# Dataset/Test/yimirira/yimirira_372.wav, segment:1
# Dataset/Test/yimirira/yimirira_226.wav, segment:1
# Dataset/Test/yimirira/yimirira_032.wav, segment:1
# Dataset/Test/yimirira/yimirira_150.wav, segment:1
# Dataset/Test/yimirira/yimirira_052.wav, segment:1
# Dataset/Test/yimirira/yimirira_302.wav, segment:1
# Dataset/Test/yimirira/yimirira_418.wav, segment:1
# Dataset/Test/yimirira/yimirira_193.wav, segment:1
# Dataset/Test/yimirira/yimirira_055.wav, segment:1
# Dataset/Test/yimirira/yimirira_310.wav, segment:1
# Dataset/Test/yimirira/yimirira_175.wav, segment:1
# Dataset/Test/yimirira/yimirira_324.wav, segment:1
# Dataset/Test/yimirira/yimirira_308.wav, segment:1
# Dataset/Test/yimirira/yimirira_274.wav, segment:1
# Dataset/Test/yimirira/yimirira_030.wav, segment:1
# Dataset/Test/yimirira/yimirira_105.wav, segment:1
# Dataset/Test/yimirira/yimirira_086.wav, segment:1
# Dataset/Test/yimirira/yimirira_076.wav, segment:1
# Dataset/Test/yimirira/yimirira_128.wav, segment:1
# Dataset/Test/yimirira/yimirira_390.wav, segment:1
# Dataset/Test/yimirira/yimirira_398.wav, segment:1
# Dataset/Test/yimirira/yimirira_404.wav, segment:1
# Dataset/Test/yimirira/yimirira_161.wav, segment:1
# Dataset/Test/yimirira/yimirira_097.wav, segment:1
# Dataset/Test/yimirira/yimirira_115.wav, segment:1
# Dataset/Test/yimirira/yimirira_408.wav, segment:1
# Dataset/Test/yimirira/yimirira_320.wav, segment:1
# Dataset/Test/yimirira/yimirira_072.wav, segment:1
# Dataset/Test/yimirira/yimirira_065.wav, segment:1
# Dataset/Test/yimirira/yimirira_198.wav, segment:1
# Dataset/Test/yimirira/yimirira_344.wav, segment:1
# Dataset/Test/yimirira/yimirira_380.wav, segment:1
# Dataset/Test/yimirira/yimirira_363.wav, segment:1
# Dataset/Test/yimirira/yimirira_434.wav, segment:1
# Dataset/Test/yimirira/yimirira_110.wav, segment:1
# Dataset/Test/yimirira/yimirira_081.wav, segment:1
# Dataset/Test/yimirira/yimirira_157.wav, segment:1
# Dataset/Test/yimirira/yimirira_116.wav, segment:1
# Dataset/Test/yimirira/yimirira_282.wav, segment:1
# Dataset/Test/yimirira/yimirira_410.wav, segment:1
# Dataset/Test/yimirira/yimirira_272.wav, segment:1
# Dataset/Test/yimirira/yimirira_322.wav, segment:1
# Dataset/Test/yimirira/yimirira_331.wav, segment:1
# Dataset/Test/yimirira/yimirira_208.wav, segment:1
# Dataset/Test/yimirira/yimirira_306.wav, segment:1
# Dataset/Test/yimirira/yimirira_388.wav, segment:1
# Dataset/Test/yimirira/yimirira_263.wav, segment:1
# Dataset/Test/yimirira/yimirira_312.wav, segment:1
# Dataset/Test/yimirira/yimirira_163.wav, segment:1
# Dataset/Test/yimirira/yimirira_267.wav, segment:1
# Dataset/Test/yimirira/yimirira_394.wav, segment:1
# Dataset/Test/yimirira/yimirira_321.wav, segment:1
# Dataset/Test/yimirira/yimirira_345.wav, segment:1
# Dataset/Test/yimirira/yimirira_309.wav, segment:1
# Dataset/Test/yimirira/yimirira_217.wav, segment:1
# Dataset/Test/yimirira/yimirira_153.wav, segment:1
# Dataset/Test/yimirira/yimirira_266.wav, segment:1
# Dataset/Test/yimirira/yimirira_415.wav, segment:1
# Dataset/Test/yimirira/yimirira_358.wav, segment:1
# Dataset/Test/yimirira/yimirira_013.wav, segment:1
# Dataset/Test/yimirira/yimirira_419.wav, segment:1
# Dataset/Test/yimirira/yimirira_342.wav, segment:1
# Dataset/Test/yimirira/yimirira_108.wav, segment:1
# Dataset/Test/yimirira/yimirira_228.wav, segment:1
# Dataset/Test/yimirira/yimirira_209.wav, segment:1
# Dataset/Test/yimirira/yimirira_075.wav, segment:1
# Dataset/Test/yimirira/yimirira_185.wav, segment:1
# Dataset/Test/yimirira/yimirira_078.wav, segment:1
# Dataset/Test/yimirira/yimirira_283.wav, segment:1

# %% [markdown]
# ## Train and validation Datasets

# %%
# Function to load train and validation datasets
def load_train_dataset(json_path, batch_size, validation_split=0.2):
    # Load MFCCs from JSON and create TensorFlow dataset
    with open(json_path, "r") as fp:
        data = json.load(fp)

    mfccs = np.array(data["mfcc"])
    labels = np.array(data["labels"])

    dataset = tf.data.Dataset.from_tensor_slices((mfccs, labels))
    dataset = dataset.shuffle(len(mfccs)).batch(batch_size)

    train_size = int((1 - validation_split) * len(mfccs))
    train_ds = dataset.take(train_size)
    val_ds = dataset.skip(train_size)

    train_ds = train_ds.cache().prefetch(tf.data.AUTOTUNE)
    val_ds = val_ds.cache().prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds, data["mapping"]

# %%
train_mfcc_ds, val_mfcc_ds, mapping = load_train_dataset(TRAIN_JSON_PATH, BATCH_SIZE, VALIDATION_SPLIT)

# %% [markdown]
# ## Test dataset

# %%
# Function to load test dataset
def load_test_dataset(json_path, batch_size):
    # Load MFCCs from JSON and create TensorFlow dataset
    with open(json_path, "r") as fp:
        data = json.load(fp)

    mfccs = np.array(data["mfcc"])
    labels = np.array(data["labels"])

    dataset = tf.data.Dataset.from_tensor_slices((mfccs, labels))
    dataset = dataset.shuffle(len(mfccs)).batch(batch_size)

    test_ds = dataset.cache().prefetch(tf.data.AUTOTUNE)

    return test_ds, data["mapping"]

# %%
test_mfcc_ds, mapping = load_test_dataset(TEST_JSON_PATH, BATCH_SIZE)

# %% [markdown]
# # Model 1

# %% [markdown]
# ### Input shape

# %%
example_spectrograms = next(iter(train_mfcc_ds))[0]
input_shape = example_spectrograms.shape[1:]

print('Input shape:', input_shape)
num_labels = len(mapping)
# Out:
# Input shape: (32, 13)

# %%
print(f'Labels {mapping}')
print(f'Number of labels: {num_labels}')
# Out:
# Labels ['Test', 'ddyo', 'mumaaso', 'unknown', 'kkono', 'emabega', 'yimirira']
# Number of labels: 7

# %%
# Model artitecture 1
def model(input_shape, num_labels):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(16, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu', padding='same'),
        layers.GlobalMaxPooling2D(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_labels, activation='softmax')
    ])

    return model

model = model(input_shape, num_labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 20
#       3     model = models.Sequential([
#       4         layers.Input(shape=input_shape),
#       5         layers.Conv2D(16, 3, activation='relu', padding='same'),
#    (...)
#      15         layers.Dense(num_labels, activation='softmax')
#      16     ])
#      18     return model
# ---> 20 model = model(input_shape, num_labels)
#
# Cell In[19], line 3, in model(input_shape, num_labels)
#       2 def model(input_shape, num_labels):
# ----> 3     model = models.Sequential([
#       4         layers.Input(shape=input_shape),
#       5         layers.Conv2D(16, 3, activation='relu', padding='same'),
#       6         layers.MaxPooling2D(),
#       7         layers.Conv2D(32, 3, activation='relu', padding='same'),
#       8         layers.MaxPooling2D(),
#       9         layers.Conv2D(64, 3, activation='relu', padding='same'),
#      10         layers.MaxPooling2D(),
#      11         layers.Conv2D(128, 3, activation='relu', padding='same'),
#      12         layers.GlobalMaxPooling2D(),
#      13         layers.Dense(128, activation='relu'),
#      14         layers.Dropout(0.5),
#      15         layers.Dense(num_labels, activation='softmax')
#      16     ])
#      18     return model
#
# File ~/project/lib/python3.11/site-packages/keras/src/models/sequential.py:74, in Sequential.__init__(self, layers, trainable, name)
#      72 for layer in layers:
#      73     self.add(layer, rebuild=False)
# ---> 74 self._maybe_rebuild()
#
# File ~/project/lib/python3.11/site-packages/keras/src/models/sequential.py:139, in Sequential._maybe_rebuild(self)
#     137 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     138     input_shape = self._layers[0].batch_shape
# --> 139     self.build(input_shape)
#
# File ~/project/lib/python3.11/site-packages/keras/src/layers/layer.py:223, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     220 @wraps(original_build_method)
#     221 def build_wrapper(*args, **kwargs):
#     222     with obj._open_name_scope():
# --> 223         original_build_method(*args, **kwargs)
#     224     # Record build config.
#     225     signature = inspect.signature(original_build_method)
#
# File ~/project/lib/python3.11/site-packages/keras/src/models/sequential.py:183, in Sequential.build(self, input_shape)
#     181 for layer in self._layers[1:]:
#     182     try:
# --> 183         x = layer(x)
#     184     except NotImplementedError:
#     185         # Can happen if shape inference is not implemented.
#     186         # TODO: consider reverting inbound nodes on layers processed.
#     187         return
#
# File ~/project/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/project/lib/python3.11/site-packages/keras/src/layers/input_spec.py:202, in assert_input_compatibility(input_spec, inputs, layer_name)
#     200 if spec.min_ndim is not None:
#     201     if ndim is not None and ndim < spec.min_ndim:
# --> 202         raise ValueError(
#     203             f'Input {input_index} of layer "{layer_name}" '
#     204             "is incompatible with the layer: "
#     205             f"expected min_ndim={spec.min_ndim}, "
#     206             f"found ndim={ndim}. "
#     207             f"Full shape received: {shape}"
#     208         )
#     209 # Check dtype.
#     210 if spec.dtype is not None:
#
# ValueError: Input 0 of layer "conv2d" is incompatible with the layer: expected min_ndim=4, found ndim=3. Full shape received: (None, 32, 13)

# %% [markdown]
# ### Model Architecture

# %%
model.summary()

# %% [markdown]
# ### Compile and Train the model

# %%
Epochs = 35
patience = 10
learning_rate = 0.001
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

# %%
# Function to compile and train the model
def compile_and_train_model(model, train_ds, val_ds, learning_rate=learning_rate):
    try:
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
        early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=patience, min_lr=1e-6)
        history = model.fit(train_ds, validation_data=val_ds, epochs=Epochs, callbacks=[early_stopping, reduce_lr])
        return history
    except Exception as e:
        print(f"An error occurred during model compilation and training: {str(e)}")

# %%
history = compile_and_train_model(model, train_mfcc_ds, val_mfcc_ds)

# %% [markdown]
# ### Plot Accuracy and Loss

# %%
# Function to plot the training history
def plot_training_history(history):
    try:
        acc = history.history['accuracy']
        val_acc = history.history['val_accuracy']
        loss = history.history['loss']
        val_loss = history.history['val_loss']

        epochs = range(len(acc))

        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1)
        plt.plot(epochs, acc, 'r', label='Training accuracy')
        plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs, loss, 'r', label='Training loss')
        plt.plot(epochs, val_loss, 'b', label='Validation loss')
        plt.title('Training and validation loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"An error occurred during plotting the training history: {str(e)}")

# %%
plot_training_history(history)

# %% [markdown]
# ### Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
# Function to evaluate the model on the test dataset
def evaluate_model(model, test_ds):
    try:
        y_true = []
        y_pred = []
        for audio, labels in test_ds:
            predictions = model.predict(audio, verbose=0)
            y_true.extend(labels.numpy())
            y_pred.extend(tf.argmax(predictions, axis=1).numpy())

        loss, accuracy = model.evaluate(test_ds, verbose=0)
        precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
        recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
        f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

        print(f"Test accuracy:      {int(accuracy * 100)}%")
        print(f"Test loss:          {loss}")
        print(f"Precision:          {precision}")
        print(f"Recall:             {recall}")
        print(f"F1-score:           {f1}")
    except Exception as e:
        print(f"An error occurred during model evaluation: {str(e)}")

# %%
evaluate_model(model, test_mfcc_ds)

# %% [markdown]
# ## Confusion matrix

# %%
y_pred = model.predict(test_mfcc_ds)
y_pred = tf.argmax(y_pred, axis=1)
y_true = tf.concat(list(test_mfcc_ds.map(lambda s,lab: lab)), axis=0)
label_names_slice = ['ddyo', 'emabega', 'gaali', 'kkono', 'mumaaso', 'unknown', 'yimirira']

# %%
# Function to plot the confusion matrix
def plot_confusion_matrix(y_true, y_pred, label_names):
    try:
        confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(confusion_mtx,
                    xticklabels=label_names,
                    yticklabels=label_names,
                    annot=True, fmt='g')
        plt.xlabel('Prediction')
        plt.ylabel('Label')
        plt.title('Confusion Matrix')
        plt.show()
    except Exception as e:
        print(f"An error occurred during plotting the confusion matrix: {str(e)}")

# %%
plot_confusion_matrix(y_true, y_pred, label_names_slice)

# %% [markdown]
# ## save the Keras model

# %%
KERAS_MODEL_PATH = "model/mfcc_model_1.keras"

# %%
model.save(KERAS_MODEL_PATH)

# %% [markdown]
# ## Size of the keras model

# %%
# Function to get the file size
def get_and_convert_file_size(file_path, unit=None):
    size = os.path.getsize(file_path)
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
keras_model_size = get_and_convert_file_size(KERAS_MODEL_PATH, 'MB')

# %%
model.save(KERAS_MODEL_PATH)
keras_model_size = get_and_convert_file_size(KERAS_MODEL_PATH, 'KB')

# %%
# Assuming you have a Keras model named 'model'
# import tensorflow as tf

# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()
# with open('model.tflite', 'wb') as f:
#     f.write(tflite_model)

# %% [markdown]
# # Run an inference

# %%
from tensorflow.keras.models import load_model

KERAS_MODEL_PATH = "model/model_1.keras"
model = load_model(KERAS_MODEL_PATH)

# %%
from modules.inference import predict_audio

# %%
# file_path_inference = kkono_file_path
file_path_inference = 'ras1.wav'
predicted_label, probability = predict_audio(file_path_inference, model, SAMPLE_RATE)
print(f"Predicted label: {predicted_label}, Probability: {probability}")

# %%
file_path_inference = ddyo_file_path
predicted_label, probability = predict_audio(file_path_inference, model, SAMPLE_RATE)
print(f"Predicted label: {predicted_label}, Probability: {probability}")

# %%
file_path_inference = gaali_file_path
predicted_label, probability = predict_audio(file_path_inference, model, SAMPLE_RATE)
print(f"Predicted label: {predicted_label}, Probability: {probability}")

# %%
file_path_inference = yimirira_file_path
predicted_label, probability = predict_audio(file_path_inference, model, SAMPLE_RATE)
print(f"Predicted label: {predicted_label}, Probability: {probability}")

# %%
file_path_inference = emabega_file_path
predicted_label, probability = predict_audio(file_path_inference, model, SAMPLE_RATE)
print(f"Predicted label: {predicted_label}, Probability: {probability}")

# %%
file_path_inference = mumasso_file_path
predicted_label, probability = predict_audio(file_path_inference, model, SAMPLE_RATE)
print(f"Predicted label: {predicted_label}, Probability: {probability}")
